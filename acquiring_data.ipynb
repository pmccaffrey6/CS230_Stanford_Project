# %%
import glob

import pandas as pd

import os

# %% [markdown]
# # Acquiring Data
#
# As authors mention in the paper, they used 4 training and 2 holdout datasets.
#
# ### 4 Training datasets:
#
# * MetaHIT error-free (n=264)
#
# * Sample-specific assemblies for CAMI2 Airways (n=10), Oral (n=10), and Urogenital (n=9)
#
# ### 2 Hold-out datasets:
#
# * CAMI2 Skin (n=10), Gastrointestinal (n=10)

# %% [markdown]
# ## MetaHIT Dataset
#
# As the authors describe, they obtained the MetaHIT assembly from https://portal.nersc.gov/dna/RD/Metagenome_RD/MetaBAT/Files/, specifically downloading the files named `depth.txt.gz` and `assembly-filtered.fa.gz`. These have been placed in the MetaHIT_data folder.

# %%
metahit_urls = ['https://portal.nersc.gov/dna/RD/Metagenome_RD/MetaBAT/Files/depth.txt.gz',
                'https://portal.nersc.gov/dna/RD/Metagenome_RD/MetaBAT/Files/assembly-filtered.fa.gz']


for metahit_url in metahit_urls:
    # !wget $metahit_url -P example_input_data/MetaHIT_data/
# Out:
# --2021-02-25 12:59:18--  https://portal.nersc.gov/dna/RD/Metagenome_RD/MetaBAT/Files/depth.txt.gz
# Resolving portal.nersc.gov (portal.nersc.gov)... 128.55.206.28, 128.55.206.24
# Connecting to portal.nersc.gov (portal.nersc.gov)|128.55.206.28|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 142739748 (136M) [application/x-gzip]
# Saving to: ‘example_input_data/MetaHIT_data/depth.txt.gz.2’
#
# depth.txt.gz.2        9%[>                   ]  12.41M  3.34MB/s    eta 48s    ^C
# --2021-02-25 12:59:24--  https://portal.nersc.gov/dna/RD/Metagenome_RD/MetaBAT/Files/assembly-filtered.fa.gz
# Resolving portal.nersc.gov (portal.nersc.gov)... 128.55.206.28, 128.55.206.24
# Connecting to portal.nersc.gov (portal.nersc.gov)|128.55.206.28|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 333460075 (318M) [application/x-gzip]
# Saving to: ‘example_input_data/MetaHIT_data/assembly-filtered.fa.gz.2’
#
#      assembly-filte   0%[                    ]   1.65M  1.50MB/s               ^C

# %% [markdown]
# Note that the abundance table used for VAMB was obtained from the Kang et al MetaBAT publication (https://peerj.com/articles/1165/) and it looks like this is the file `depth.txt` that we have here which is generated typically from a BAM file using the MetaBAT2 script `jgi_summarize_bam_contig_depths`.

# %%
#!gzip -dk example_input_data/MetaHIT_data/depth.txt.gz

contig_depths = pd.read_csv('example_input_data/MetaHIT_data/depth.txt', sep='\t')
contig_depths.head(3)
# Out:
#                                           contigName  contigLen  \
# 0  gi|224815735|ref|NZ_ACGB01000001.1|_[Acidamino...       5871
# 1  gi|224815735|ref|NZ_ACGB01000001.1|_[Acidamino...       2500
# 2  gi|224815735|ref|NZ_ACGB01000001.1|_[Acidamino...       2500
#
#    totalAvgDepth  \
# 0        97.1261
# 1        98.2171
# 2       102.3390
#
#    all_291-shred_2500_31_rand_94521.fa-ERR011087.fastq.fix.fastq.sam.bam  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    all_291-shred_2500_31_rand_94521.fa-ERR011087.fastq.fix.fastq.sam.bam-var  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    all_291-shred_2500_31_rand_94521.fa-ERR011088.fastq.fix.fastq.sam.bam  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    all_291-shred_2500_31_rand_94521.fa-ERR011088.fastq.fix.fastq.sam.bam-var  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    all_291-shred_2500_31_rand_94521.fa-ERR011089.fastq.fix.fastq.sam.bam  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    all_291-shred_2500_31_rand_94521.fa-ERR011089.fastq.fix.fastq.sam.bam-var  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    all_291-shred_2500_31_rand_94521.fa-ERR011090.fastq.fix.fastq.sam.bam  ...  \
# 0                                                0.0                      ...
# 1                                                0.0                      ...
# 2                                                0.0                      ...
#
#    all_291-shred_2500_31_rand_94521.fa-ERR011346.fastq.fix.fastq.sam.bam  \
# 0                                            1.42251
# 1                                            2.51658
# 2                                            1.11267
#
#    all_291-shred_2500_31_rand_94521.fa-ERR011346.fastq.fix.fastq.sam.bam-var  \
# 0                                            2.25269
# 1                                            5.72159
# 2                                            1.98925
#
#    all_291-shred_2500_31_rand_94521.fa-ERR011347.fastq.fix.fastq.sam.bam  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    all_291-shred_2500_31_rand_94521.fa-ERR011347.fastq.fix.fastq.sam.bam-var  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    all_291-shred_2500_31_rand_94521.fa-ERR011348.fastq.fix.fastq.sam.bam  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    all_291-shred_2500_31_rand_94521.fa-ERR011348.fastq.fix.fastq.sam.bam-var  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    all_291-shred_2500_31_rand_94521.fa-ERR011349.fastq.fix.fastq.sam.bam  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    all_291-shred_2500_31_rand_94521.fa-ERR011349.fastq.fix.fastq.sam.bam-var  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    all_291-shred_2500_31_rand_94521.fa-ERR011350.fastq.fix.fastq.sam.bam  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
#    all_291-shred_2500_31_rand_94521.fa-ERR011350.fastq.fix.fastq.sam.bam-var
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
# [3 rows x 531 columns]

# %% [markdown]
# ## CAMI Datasets
#
# As described on the CAMI page [here](https://data.cami-challenge.org/participate), there are 4 URLs from which we can procure CAMI datasets
#
# Airways: https://openstack.cebitec.uni-bielefeld.de:8080/swift/v1/CAMI_Airways
#
# Gastrointestinal tract: https://openstack.cebitec.uni-bielefeld.de:8080/swift/v1/CAMI_Gastrointestinal_tract
#
# Oral cavity: https://openstack.cebitec.uni-bielefeld.de:8080/swift/v1/CAMI_Oral
#
# Skin: https://openstack.cebitec.uni-bielefeld.de:8080/swift/v1/CAMI_Skin
#
# Urogenital tract: https://openstack.cebitec.uni-bielefeld.de:8080/swift/v1/CAMI_Urogenital_tract
#
#
# ### A note about how data is organized within CAMI:
#
# * Sample folders start with the date of creation and end with the sample number: yyyy.mm.dd_hh.mm.ss_sample_#
#
# * In every sample folder there are three subfolders, bam, contigs and reads. The bam folder contains the mapping of all the created reads to the input genomes:
#
# * Inside this folder is a bam file for every genome for which at least one read was produced, which is uniquely indicated by a combination of OTU and a running ID counter for the number of genomes included in that OTU in the sample: OTU_ID.bam.
#
# * The contigs folder contains the gold standard assembly for that particular sample. It contains two files, the gold standard in fasta format, anonymous_gsa.fasta.gz, and the mapping for each contigs to its genome/taxon id and position in this genome, gsa_mapping.tsv.gz.
#
# * The reads folder contains the created reads for that sample. It contains two files, one with the fq reads themselves, containing both ends for paired end sequencing and with anonymised names, anonymous_reads.fq.gz, and the second one is a mapping of every single read to the genome it originated from and the original read ID (pre anonymisation), reads_mapping.tsv.gz.
#
# * Every data set contains one abundance file per sample mapping OTUs to genomes: abundance#.tsv
#
# * Every data set contains the pooled gold standard assembly over all samples in the folder: anonymous_gsa_pooled.fasta.gz

# %%
cami_urls = {
    'Airways': 'https://openstack.cebitec.uni-bielefeld.de:8080/swift/v1/CAMI_Airways',
    'Gastrointestinal tract': 'https://openstack.cebitec.uni-bielefeld.de:8080/swift/v1/CAMI_Gastrointestinal_tract',
    'Oral cavity': 'https://openstack.cebitec.uni-bielefeld.de:8080/swift/v1/CAMI_Oral',
    'Skin: https': '//openstack.cebitec.uni-bielefeld.de:8080/swift/v1/CAMI_Skin',
    'Urogenital tract': 'https://openstack.cebitec.uni-bielefeld.de:8080/swift/v1/CAMI_Urogenital_tract'
}

# %%
# List Files
url = cami_urls['Airways']

#!java -jar example_input_data/cami_challenge/camiClient.jar -l $url

# %%
# !java -jar util/camiClient.jar -d $url example_input_data/cami_challenge/airways -p short_read
# Out:
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000466785.3_ASM46678v3.fa
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_12/bam/OTU_97.45281.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_9/bam/OTU_97.34725.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_27/bam/OTU_97.25219.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_10/bam/OTU_97.40239.1.bam
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.196.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_4/bam/OTU_97.38699.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_4/bam/OTU_97.30815.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_7/contigs/gsa_mapping.tsv.gz
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_4/bam/OTU_97.45028.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_9/bam/OTU_97.34808.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_4/bam/OTU_97
1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000931625.1_ASM93162v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_27/bam/OTU_97.34702.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_27/bam/OTU_97.34821.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000934545.1_ASM93454v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000934625.1_ASM93462v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000935025.1_ASM93502v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_4/bam/OTU_97.36530.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_4/bam/OTU_97.370.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000939415.2_HGAP_assembly_of_Acinetobacter_baumannii_ORAB01.fa
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_4/bam/OTU_97.370.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_4/bam/OTU_97.37206.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000940845.1_ASM94084v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000940995.1_ASM94099v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_4/bam/OTU_97.37206.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_4/bam/OTU_97.37290.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_4/bam/OTU_97.37290.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_4/bam/OTU_97.37297.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000943805.1_ASM94380v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.29883.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.30026.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.30026.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.30026.1.bam
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.30026.1.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.30055.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.30055.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.30815.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000952975.1_D1G.fa
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000953215.1_DG5.fa
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.30815.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.30815.1.bam
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000953255.1_Staphylococcus_aureus_Sa_ILRI_217.fa
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000953275.1_CD630DERM.fa
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000953535.1_E5B.fa
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000953575.1_Staphylococcus_xylosus_C2a.fa
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_27/bam/OTU_97.34821.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_27/bam/OTU_97.34832.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000959165.1_ASM95916v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000959265.1_ASM95926v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.30815.1.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.30996.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.30996.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.31167.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000959325.1_ASM95932v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.31167.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.31167.1.bam
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.31167.1.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.31175.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_27/bam/OTU_97.34832.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_27/bam/OTU_97.34908.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.31175.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.31350.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000959605.1_ASM95960v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.31350.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.3136.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.3136.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.31374.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.31374.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.31374.1.bam
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.31374.1.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.31837.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.31837.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.31837.1.bam
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_27/bam/OTU_97.34908.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_27/bam/OTU_97.34913.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000961015.1_ASM96101v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.31837.1.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.32148.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.32148.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.32419.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_10/bam/OTU_97.44585.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_10/bam/OTU_97.44678.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000963635.1_ASM96363v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_4/bam/OTU_97.37297.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_4/bam/OTU_97.37297.1.bam
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_10/bam/OTU_97.44678.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_10/bam/OTU_97.44712.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000963675.1_ASM96367v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.32419.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.32419.1.bam
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000963865.1_ASM96386v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000965785.1_ASM96578v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_27/bam/OTU_97.34913.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_27/bam/OTU_97.34967.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000967325.1_ASM96732v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000967345.1_ASM96734v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000967365.1_ASM96736v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.32419.1.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.3350.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000967385.1_ASM96738v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.3350.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.33610.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000967405.1_ASM96740v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_10/bam/OTU_97.44712.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_10/bam/OTU_97.45246.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.33610.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_26/bam/OTU_97.3377.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_27/bam/OTU_97.34967.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_27/bam/OTU_97.34998.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000967445.1_ASM96744v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000968335.1_ASM96833v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000968375.1_ASM96837v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000968945.1_ASM96894v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000969225.1_ASM96922v1.fa
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_10/bam/OTU_97.45246.0.bam.bai
# Downloading example_input_data/cami_challenge/airways/short_read/2017.12.04_18.56.22_sample_10/bam/OTU_97.45281.0.bam
# Downloading example_input_data/cami_challenge/airways/short_read/genomes/GCA_000970665.2_ASM97066v2.fa

# %% [markdown]
# ## General Workflow for Adding New Data
#
# We can use CAMSIM to generate new synthetic metagenome files.
#
# Generally, we should have installed the cami Docker container: `docker pull cami/camisim:latest`
#
# CAMSIM can take many types of simulation parameters but we can keep it simple, simulating single-timepoint examples for now and we'll do it *de novo*.
#
# ### Steps for genome simulation:
#
# * Data processing: CAMISIM will remove any sequences from provided assemblies that are shorter than 1000 bases and will check that sequences only contain valid characters being A,C,T,G and certain ambiguous base encodings: RYWSMKHBVDN.
#
# * The input we need to provide is a taxonomic profile in .biom format or .ini format

# %%
input_folder = os.path.join(os.getcwd(), 'example_input_data/new_simulations/camisim_inputs')
output_folder = os.path.join(os.getcwd(), 'example_input_data/new_simulations/camisim_outputs')

input_directory = f"{input_folder}:/input:rw"
output_directory = f"{output_folder}:/output:rw"

# !echo UTMBpath123 | sudo -S docker run --rm -v $input_directory -v $output_directory  \
    cami/camisim:latest  metagenomesimulation.py /input/mini_config.ini
# Out:
# [sudo] password for pathinformatics: 2021-02-25 19:02:04 INFO: [MetagenomeSimulationPipeline] Metagenome simulation starting
# 2021-02-25 19:02:04 INFO: [MetagenomeSimulationPipeline] Validating Genomes
# 2021-02-25 19:02:04 INFO: [MetadataReader] Reading file: '/input/genome_to_id.tsv'
# 2021-02-25 19:02:25 INFO: [MetagenomeSimulationPipeline] Design Communities
# 2021-02-25 19:02:25 INFO: [CommunityDesign] Drawing strains.
# 2021-02-25 19:02:25 INFO: [MetadataReader 82380310288] Reading file: '/input/metadata.tsv'
# 2021-02-25 19:02:25 INFO: [MetadataReader 28547833133] Reading file: '/input/genome_to_id.tsv'
# 2021-02-25 19:02:25 INFO: [CommunityDesign] Validating raw sequence files!
# 2021-02-25 19:02:47 INFO: [NcbiTaxonomy] Building taxonomy tree...
# 2021-02-25 19:02:47 INFO: [NcbiTaxonomy] Reading 'nodes' file:	'/tmp/tmpsBgzMr/NCBI/nodes.dmp'
# 2021-02-25 19:02:58 INFO: [NcbiTaxonomy] Reading 'names' file:	'/tmp/tmpsBgzMr/NCBI/names.dmp'
# 2021-02-25 19:02:59 INFO: [NcbiTaxonomy] Reading 'merged' file:	'/tmp/tmpsBgzMr/NCBI/merged.dmp'
# 2021-02-25 19:02:59 INFO: [NcbiTaxonomy] Done (13.0s)
# 2021-02-25 19:02:59 INFO: [MetagenomeSimulationPipeline] Move Genomes
# 2021-02-25 19:02:59 WARNING: [GenomePreparation 93306492971] File /output/source_genomes/GCA_000227705.3_ASM22770v3.fa existing, skipping
# 2021-02-25 19:02:59 WARNING: [GenomePreparation 93306492971] File /output/source_genomes/GCA_000006785.2_ASM678v2.fa existing, skipping
# 2021-02-25 19:02:59 WARNING: [GenomePreparation 93306492971] File /output/source_genomes/GCA_000255115.3_ASM25511v3.fa existing, skipping
# 2021-02-25 19:02:59 WARNING: [GenomePreparation 93306492971] File /output/source_genomes/GCA_000025905.1_ASM2590v1.fa existing, skipping
# 2021-02-25 19:02:59 WARNING: [GenomePreparation 93306492971] File /output/source_genomes/GCA_000231385.3_ASM23138v3.fa existing, skipping
# 2021-02-25 19:02:59 WARNING: [GenomePreparation 93306492971] File /output/source_genomes/GCA_000023785.1_ASM2378v1.fa existing, skipping
# 2021-02-25 19:02:59 WARNING: [GenomePreparation 93306492971] File /output/source_genomes/GCA_000242255.3_ASM24225v3.fa existing, skipping
# 2021-02-25 19:02:59 WARNING: [GenomePreparation 93306492971] File /output/source_genomes/GCA_000445015.1_ASM44501v1.fa existing, skipping
# 2021-02-25 19:02:59 WARNING: [GenomePreparation 93306492971] File /output/source_genomes/GCA_000022345.1_ASM2234v1.fa existing, skipping
# 2021-02-25 19:02:59 WARNING: [GenomePreparation 93306492971] File /output/source_genomes/GCA_000013785.1_ASM1378v1.fa existing, skipping
# 2021-02-25 19:02:59 WARNING: [GenomePreparation 93306492971] File /output/source_genomes/GCA_001877055.1_ASM187705v1.fa existing, skipping
# 2021-02-25 19:02:59 WARNING: [GenomePreparation 93306492971] File /output/source_genomes/GCA_000092985.1_ASM9298v1.fa existing, skipping
# 2021-02-25 19:02:59 WARNING: [GenomePreparation 93306492971] File /output/source_genomes/GCA_000143845.1_ASM14384v1.fa existing, skipping
# 2021-02-25 19:02:59 WARNING: [GenomePreparation 93306492971] File /output/source_genomes/GCA_000265425.1_ASM26542v1.fa existing, skipping
# 2021-02-25 19:02:59 WARNING: [GenomePreparation 93306492971] File /output/source_genomes/GCA_000439255.1_ASM43925v1.fa existing, skipping
# 2021-02-25 19:02:59 WARNING: [GenomePreparation 93306492971] File /output/source_genomes/GCA_000092825.1_ASM9282v1.fa existing, skipping
# 2021-02-25 19:03:00 WARNING: [GenomePreparation 93306492971] File /output/source_genomes/GCA_000235405.3_ASM23540v3.fa existing, skipping
# 2021-02-25 19:03:00 WARNING: [GenomePreparation 93306492971] File /output/source_genomes/GCA_000013285.1_ASM1328v1.fa existing, skipping
# 2021-02-25 19:03:00 WARNING: [GenomePreparation 93306492971] File /output/source_genomes/GCA_000325705.1_ASM32570v1.fa existing, skipping
# 2021-02-25 19:03:00 WARNING: [GenomePreparation 93306492971] File /output/source_genomes/GCA_000233715.3_ASM23371v3.fa existing, skipping
# 2021-02-25 19:03:00 WARNING: [GenomePreparation 93306492971] File /output/source_genomes/GCA_001692755.1_ASM169275v1.fa existing, skipping
# 2021-02-25 19:03:00 WARNING: [GenomePreparation 93306492971] File /output/source_genomes/GCA_000015865.1_ASM1586v1.fa existing, skipping
# 2021-02-25 19:03:00 WARNING: [GenomePreparation 93306492971] File /output/source_genomes/GCA_000092125.1_ASM9212v1.fa existing, skipping
# 2021-02-25 19:03:00 WARNING: [GenomePreparation 93306492971] File /output/source_genomes/GCA_000143985.1_ASM14398v1.fa existing, skipping
# 2021-02-25 19:03:00 INFO: [MetagenomeSimulationPipeline] Read simulation
# 2021-02-25 19:03:00 INFO: [GenomePreparation 75339803532] Using 'mbarc' error profile.
# 2021-02-25 19:03:00 INFO: [GenomePreparation 75339803532] Reading distribution file
# 2021-02-25 19:03:00 INFO: [GenomePreparation 75339803532] Reading genome location file
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads using ReadSimulationArtIllumina readsimulator...
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads from Genome15.0: '/output/source_genomes/GCA_000227705.3_ASM22770v3.fa'
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads from Genome14.0: '/output/source_genomes/GCA_000006785.2_ASM678v2.fa'
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads from Genome11.0: '/output/source_genomes/GCA_000255115.3_ASM25511v3.fa'
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads from Genome24.0: '/output/source_genomes/GCA_000025905.1_ASM2590v1.fa'
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads from Genome12.0: '/output/source_genomes/GCA_000231385.3_ASM23138v3.fa'
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads from Genome18.0: '/output/source_genomes/GCA_000023785.1_ASM2378v1.fa'
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads from Genome17.0: '/output/source_genomes/GCA_000242255.3_ASM24225v3.fa'
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads from Genome16.0: '/output/source_genomes/GCA_000022345.1_ASM2234v1.fa'
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads from Genome19.0: '/output/source_genomes/GCA_000013785.1_ASM1378v1.fa'
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads from Genome2.0: '/output/source_genomes/GCA_000445015.1_ASM44501v1.fa'
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads from Genome4.0: '/output/source_genomes/GCA_001877055.1_ASM187705v1.fa'
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads from Genome4.1: '/output/source_genomes/GCA_000092985.1_ASM9298v1.fa'
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads from Genome5.0: '/output/source_genomes/GCA_000143845.1_ASM14384v1.fa'
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads from Genome3.0: '/output/source_genomes/GCA_000265425.1_ASM26542v1.fa'
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads from Genome20.0: '/output/source_genomes/GCA_000439255.1_ASM43925v1.fa'
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads from Genome6.0: '/output/source_genomes/GCA_000092825.1_ASM9282v1.fa'
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads from Genome23.0: '/output/source_genomes/GCA_000235405.3_ASM23540v3.fa'
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads from Genome9.0: '/output/source_genomes/GCA_000013285.1_ASM1328v1.fa'
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads from Genome7.0: '/output/source_genomes/GCA_000325705.1_ASM32570v1.fa'
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads from Genome13.0: '/output/source_genomes/GCA_000233715.3_ASM23371v3.fa'
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads from Genome10.0: '/output/source_genomes/GCA_001692755.1_ASM169275v1.fa'
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads from Genome10.1: '/output/source_genomes/GCA_000015865.1_ASM1586v1.fa'
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads from Genome8.0: '/output/source_genomes/GCA_000092125.1_ASM9212v1.fa'
# 2021-02-25 19:03:21 INFO: [GenomePreparation 75339803532] Simulating reads from Genome22.0: '/output/source_genomes/GCA_000143985.1_ASM14398v1.fa'
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.08
#
# The random seed for the run: 2129338277
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.00393366X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome17.01.fq
# 	 the 2nd reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome17.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome17.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.08
#
# The random seed for the run: 65634987
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.000858841X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome24.01.fq
# 	 the 2nd reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome24.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome24.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.1
#
# The random seed for the run: 1847505585
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.00282778X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome11.01.fq
# 	 the 2nd reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome11.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome11.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.19
#
# The random seed for the run: 1778994461
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.142863X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome15.01.fq
# 	 the 2nd reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome15.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome15.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.18
#
# The random seed for the run: 170568346
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.129003X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome16.01.fq
# 	 the 2nd reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome16.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome16.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.12
#
# The random seed for the run: 1661055960
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.123599X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome2.01.fq
# 	 the 2nd reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome2.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome2.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.29
#
# The random seed for the run: 573380147
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.35959X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome18.01.fq
# 	 the 2nd reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome18.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome18.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.13
#
# The random seed for the run: 1703660943
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0637858X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome19.01.fq
# 	 the 2nd reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome19.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome19.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.05
#
# The random seed for the run: 49814198
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.00333326X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome5.01.fq
# 	 the 2nd reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome5.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome5.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.18
#
# The random seed for the run: 1577639001
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0701932X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome4.01.fq
# 	 the 2nd reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome4.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome4.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.07
#
# The random seed for the run: 1168871082
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0295773X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome6.01.fq
# 	 the 2nd reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome6.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome6.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.12
#
# The random seed for the run: 1557933274
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0130767X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome3.01.fq
# 	 the 2nd reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome3.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome3.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.17
#
# The random seed for the run: 1550755105
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0737184X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome7.01.fq
# 	 the 2nd reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome7.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome7.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.1
#
# The random seed for the run: 1923521921
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0416875X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome10.01.fq
# 	 the 2nd reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome10.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome10.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.94
#
# The random seed for the run: 540968737
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            3.16878X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome14.01.fq
# 	 the 2nd reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome14.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome14.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.5
#
# The random seed for the run: 923704085
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.849941X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome9.01.fq
# 	 the 2nd reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome9.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome9.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.11
#
# The random seed for the run: 2102807139
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0217379X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome22.01.fq
# 	 the 2nd reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome22.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome22.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.79
#
# The random seed for the run: 1992431107
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.87858X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome13.01.fq
# 	 the 2nd reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome13.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome13.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.38
#
# The random seed for the run: 854832072
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.488406X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome10.11.fq
# 	 the 2nd reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome10.12.fq
#
#   SAM Alignment File:
# 	/tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome10.1.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 1.59
#
# The random seed for the run: 1294107793
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            1.97133X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome12.01.fq
# 	 the 2nd reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome12.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome12.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 1.7
#
# The random seed for the run: 1713385206
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            1.5751X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome4.11.fq
# 	 the 2nd reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome4.12.fq
#
#   SAM Alignment File:
# 	/tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome4.1.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 1.88
#
# The random seed for the run: 1961570421
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            5.64344X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome23.01.fq
# 	 the 2nd reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome23.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome23.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 1.62
#
# The random seed for the run: 689939719
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            2.94338X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome8.01.fq
# 	 the 2nd reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome8.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome8.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 5.13
#
# The random seed for the run: 1329514041
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            7.8854X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome20.01.fq
# 	 the 2nd reads: /tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome20.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpGT4yEG/2021.02.25_19.02.04_sample_0/reads/Genome20.0.sam
#
# 2021-02-25 19:03:27 INFO: [GenomePreparation 75339803532] Simulating reads finished
# 2021-02-25 19:03:35 INFO: [MetagenomeSimulationPipeline] Generate gold standard assembly
# 2021-02-25 19:03:35 INFO: [MetadataReader 34032287823] Reading file: '/output/internal/genome_locations.tsv'
# 2021-02-25 19:03:59 INFO: [MetagenomeSimulationPipeline] Generate pooled strains gold standard assembly
# 2021-02-25 19:03:59 INFO: [MetadataReader 4894055056] Reading file: '/output/internal/genome_locations.tsv'
# 2021-02-25 19:03:59 INFO: [MetagenomeSimulationPipeline] Samples used for pooled assembly: '2021.01.26_15.46.45_sample_0', '2021.02.25_19.02.04_sample_0'
# 2021-02-25 19:03:59 INFO: [Validator 58498923446] Creating pooled gold standard
# 2021-02-25 19:03:59 INFO: [Validator 58498923446] Merging bam files.
# 2021-02-25 19:04:30 INFO: [MetagenomeSimulationPipeline] Anonymize Data
# 2021-02-25 19:04:30 INFO: [FastaAnonymizer] Interweave shuffle and anonymize
# 2021-02-25 19:05:37 INFO: [MetadataReader 95355206315] Reading file: '/output/internal/genome_locations.tsv'
# 2021-02-25 19:05:38 INFO: [MetadataReader 72802808290] Reading file: '/output/internal/meta_data.tsv'
# 2021-02-25 19:05:38 INFO: [MetadataReader 47315449936] Reading file: '/tmp/tmpGT4yEG/tmpdwnmgb'
# 2021-02-25 19:05:41 INFO: [FastaAnonymizer 29536160358] Shuffle and anonymize '/tmp/tmpGT4yEG/tmpsWJJ6F'
# 2021-02-25 19:05:47 INFO: [MetadataReader 71873526544] Reading file: '/output/internal/genome_locations.tsv'
# 2021-02-25 19:05:48 INFO: [MetadataReader 45105173502] Reading file: '/output/internal/meta_data.tsv'
# 2021-02-25 19:05:48 INFO: [MetadataReader 84613406616] Reading file: '/tmp/tmpGT4yEG/read_start_positionstDuoM4'
# 2021-02-25 19:05:50 INFO: [MetadataReader 10674074437] Reading file: '/tmp/tmpGT4yEG/tmp7UZtLc'
# 2021-02-25 19:07:45 INFO: [FastaAnonymizer 86623674311] Shuffle and anonymize '/tmp/tmpGT4yEG/tmpgEXa89'
# 2021-02-25 19:07:52 INFO: [MetadataReader 15345066727] Reading file: '/output/internal/genome_locations.tsv'
# 2021-02-25 19:07:53 INFO: [MetadataReader 77753400540] Reading file: '/output/internal/meta_data.tsv'
# 2021-02-25 19:07:53 INFO: [MetadataReader 12266665971] Reading file: '/tmp/tmpGT4yEG/read_start_positionsvvxyhD'
# 2021-02-25 19:07:54 INFO: [MetadataReader 42355547664] Reading file: '/tmp/tmpGT4yEG/tmpnJ3RJ7'
# 2021-02-25 19:09:50 INFO: [MetagenomeSimulationPipeline] Compress Data
# 2021-02-25 19:09:50 INFO: [Compress 404727422] Compressing 'tmpoXidKo'
# 2021-02-25 19:09:50 INFO: [Compress 49882469301] Compressing 'anonymous_gs_mappingujvrNx'
# 2021-02-25 19:09:50 INFO: [Compress 12990985329] Compressing 'tmpxGEq9Y'
# 2021-02-25 19:09:50 INFO: [Compress 21005259633] Compressing 'anonymous_gsa_pooled_mappingt50K8d'
# 2021-02-25 19:09:50 INFO: [Compress 77093841160] Compressing 'anonymous_gsa_mappingnTb8dC'
# 2021-02-25 19:09:50 INFO: [Compress 68303086242] Compressing 'tmpaGkIMU'
# 2021-02-25 19:09:50 INFO: [Compress 21005259633] Done compressing 'gsa_pooled_mapping.tsv_1.gz' in 0:00:00s.
# 2021-02-25 19:09:50 INFO: [Compress 77093841160] Done compressing 'gsa_mapping.tsv.gz' in 0:00:00s.
# 2021-02-25 19:09:52 INFO: [Compress 49882469301] Done compressing 'reads_mapping.tsv.gz' in 0:00:02s.
# 2021-02-25 19:09:52 INFO: [Compress 12990985329] Done compressing 'anonymous_gsa.fasta.gz' in 0:00:02s.
# 2021-02-25 19:09:52 INFO: [Compress 68303086242] Done compressing 'anonymous_gsa_pooled.fasta_1.gz' in 0:00:02s.
# 2021-02-25 19:09:59 INFO: [Compress 404727422] Done compressing 'anonymous_reads.fq.gz' in 0:00:09s.
# 2021-02-25 19:09:59 INFO: [MetagenomeSimulationPipeline] Metagenome simulation finished

# %% [markdown]
# # Notes on CAMISIM Inputs in this example
#
# ## Simulation Input Files
# CAMISIM expects to have a set of .fasta files and a genomes_to_id.tsv file provided to it in the config file. Here, we're defining those tables elswhere and bringing them into the CAMISIM inputs folder for simulation but, otherwise, we would have to generate these files. Similarly, it requires a metadata.tsv file which we also bring in here as shown in the log output:
#
# ```
# [sudo] password for pathinformatics: 2021-02-25 19:02:04 INFO: [MetagenomeSimulationPipeline] Metagenome simulation starting
# 2021-02-25 19:02:04 INFO: [MetagenomeSimulationPipeline] Validating Genomes
# 2021-02-25 19:02:04 INFO: [MetadataReader] Reading file: '/input/genome_to_id.tsv'
# 2021-02-25 19:02:25 INFO: [MetagenomeSimulationPipeline] Design Communities
# 2021-02-25 19:02:25 INFO: [CommunityDesign] Drawing strains.
# 2021-02-25 19:02:25 INFO: [MetadataReader 82380310288] Reading file: '/input/metadata.tsv'
# 2021-02-25 19:02:25 INFO: [MetadataReader 28547833133] Reading file: '/input/genome_to_id.tsv'
# 2021-02-25 19:02:25 INFO: [CommunityDesign] Validating raw sequence files!
# 2021-02-25 19:02:47 INFO: [NcbiTaxonomy] Building taxonomy tree...
# 2021-02-25 19:02:47 INFO: [NcbiTaxonomy] Reading 'nodes' file:	'/tmp/tmpsBgzMr/NCBI/nodes.dmp'
# 2021-02-25 19:02:58 INFO: [NcbiTaxonomy] Reading 'names' file:	'/tmp/tmpsBgzMr/NCBI/names.dmp'
# 2021-02-25 19:02:59 INFO: [NcbiTaxonomy] Reading 'merged' file:	'/tmp/tmpsBgzMr/NCBI/merged.dmp'
# 2021-02-25 19:02:59 INFO: [NcbiTaxonomy] Done (13.0s)
# 2021-02-25 19:02:59 INFO: [MetagenomeSimulationPipeline] Move Genomes
# ```
#
# Just note that, otherwise we would have to define these from a collection of new strain genomes.
#
# ## Running Reads Simulation
#
# As a second point, running read simulation is--as with many bioinformatics tools--fastidious with regard to its dependencies so we run this in a Docker container with the following command:
#
# ```
# docker run --rm -v $input_directory -v $output_directory  \
#     cami/camisim:latest  metagenomesimulation.py /input/mini_config.ini
# ```
#
# Note that we map the host folder for `camisim_inputs` to the internal folder `/input` in Docker and we also map the host folder `camisim_outputs` to the internal folder `/output`:
#
# ```
# input_folder = os.path.join(os.getcwd(), 'example_input_data/new_simulations/camisim_inputs')
# output_folder = os.path.join(os.getcwd(), 'example_input_data/new_simulations/camisim_outputs')
#
# input_directory = f"{input_folder}:/input:rw"
# output_directory = f"{output_folder}:/output:rw"
# ```
#
# And this is why the config file references `/input` folders for the genome_to_id and metadata files.
#
# ## Final Note on Input Files
#
# Note the structure of the genomes_to_id.tsv file. Whatever genomes we select, we need a column that starts with the correct path, being /input/genomes and, second, we actually want to write this to file WITHOUT headers OR indexes or it will throw an error with CAMISIM.
#
# This produces a bunch of output files but really we just want the contigs file and the reads files. Importantly, note that this will produce an alignment BAM file for each of the input genomes used.

# %%
pd.read_csv('example_input_data/new_simulations/camisim_inputs/genome_to_id.tsv', sep='\t').head(3)
# Out:
#    Genome15.0  /input/genomes/GCA_000227705.3_ASM22770v3.fa
# 0  Genome14.0    /input/genomes/GCA_000006785.2_ASM678v2.fa
# 1  Genome11.0  /input/genomes/GCA_000255115.3_ASM25511v3.fa
# 2  Genome24.0   /input/genomes/GCA_000025905.1_ASM2590v1.fa

# %%
pd.read_csv('example_input_data/new_simulations/camisim_inputs/metadata.tsv', sep='\t').head(3)
# Out:
#     genome_ID     OTU  NCBI_ID novelty_category
# 0  Genome15.0  377615   717605     known_strain
# 1  Genome14.0    1314   160490     known_strain
# 2  Genome11.0  885581   646529     known_strain

# %%
# !cat .gitignore
# Out:
# .DS_Store
# benchmark_data/
# example_input_data/cami_challenge/
# example_input_data/MetaHIT_data/
# example_input_data/mosaic_challenge/
# example_input_data/new_simulations/camisim_outputs/
# example_input_data/new_simulations/catalogue.mmi

# %%
# %bash
