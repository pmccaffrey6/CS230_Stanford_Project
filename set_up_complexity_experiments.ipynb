# %%
import pandas as pd
import numpy as np

import dendropy

import os

import pysam
import vamb

import glob

import pickle

# %% [markdown]
# # Purpose of this Notebook
#
# In order to test the relevant impact of tuning the beta parameter for out disentangled autoencoder, I want to set up some compelling experiments. These will consist of a small grid search methodology where we modify both the number of genomes in a simulation as well as the phylogenetic distance between those genomes. That strategy would look something like this:
#
#
#
# |     | 2   |  10 | 50  |
# |-----|-----|-----|-----|
# | 5   |     |     |     |
# | 50  |     |     |     |
# | 250 |     |     |     |
#
#
# In order do do this, I'm going to set up these simulations first by deciding how I'll collect input reference genomes of varying levels of phylogenetic similarity.

# %% [markdown]
# ## 1. Gathering Genomes and Adjusting Similarity
#
# We'll start by obtaining the complete list of bacterial genomes present in the NCBI Genome database:

# %%
# !wget ftp://ftp.ncbi.nlm.nih.gov/genomes/genbank/bacteria/assembly_summary.txt
# Out:
# --2021-03-14 00:32:06--  ftp://ftp.ncbi.nlm.nih.gov/genomes/genbank/bacteria/assembly_summary.txt
#            => ‘assembly_summary.txt’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.13, 130.14.250.12, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.13|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/genbank/bacteria ... done.
# ==> SIZE assembly_summary.txt ... 276853487
# ==> PASV ... done.    ==> RETR assembly_summary.txt ... done.
# Length: 276853487 (264M) (unauthoritative)
#
# assembly_summary.tx 100%[===================>] 264.03M  23.2MB/s    in 12s
#
# 2021-03-14 00:32:19 (21.4 MB/s) - ‘assembly_summary.txt’ saved [276853487]

# %%
all_ncbi_genomes = pd.read_csv('assembly_summary.txt', sep='\t', skiprows=1)
all_complete_genomes = all_ncbi_genomes
#all_complete_genomes = all_ncbi_genomes[all_ncbi_genomes['assembly_level']=='Complete Genome']
all_complete_genomes = all_complete_genomes[(~all_complete_genomes['organism_name'].str.contains('sp.')) & 
                                            (~all_complete_genomes['organism_name'].str.contains('endosymbiont')) & 
                                            (~all_complete_genomes['organism_name'].str.contains('candidate'))]
all_complete_genomes = all_complete_genomes[pd.notna(all_complete_genomes['excluded_from_refseq'])]

all_complete_genomes = all_complete_genomes[['# assembly_accession','wgs_master','taxid','organism_name',
                                             'infraspecific_name','ftp_path']].drop_duplicates()

all_complete_genomes = all_complete_genomes.groupby('organism_name').first().reset_index()
# Out:
# /home/pathinformatics/miniconda3/envs/vamb_env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
all_complete_genomes.head(2)
# Out:
#                             organism_name # assembly_accession  \
# 0            'Brassica napus' phytoplasma      GCA_003181115.1
# 1  'Candidatus Kapabacteria' thiocyanatum      GCA_001899175.1
#
#        wgs_master    taxid infraspecific_name  \
# 0  QGKT00000000.1   469009               None
# 1  MKVH00000000.1  1895771               None
#
#                                             ftp_path
# 0  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/003...
# 1  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/001...

# %% [markdown]
# Having this, I've also obtained a reference phylogenetic tree which we can use to group genome by differing levels of phylogenetic similarity. The particular tree I'll be using is one we obtained from the [Web Of Life (WOL)](https://biocore.github.io/wol/start) project. I read this in with dendropy and then convert this into a phylogenetic distance matrix `pdm`. This is calculated using the patristic distances between items in the tree and, thus, necessitates a pairwise calculation which can take quite a bit. Moreover, this creates a pretty big pickle file (several GB).

# %%
# with open('astral.cons.nid.e5p50.nwk', 'r') as treefile:
#     tree = dendropy.Tree.get(
#             data=treefile.read(),
#             schema="newick",
#             )
    
#     pdm = tree.phylogenetic_distance_matrix()

# %%
#with open('bacteria_pdm.pickle', 'wb') as f:
#    pickle.dump(pdm, f, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# I will then use this distance matrix to grab a collection of genomes relevant to each of our experiments. This will be a collection of genomes from 1 genus, from 5 genera, and from 10 genera. I'll first select which genera these are and then I'll create three specimens for each genera set: one with 25 genomes, one with 50 genomes, and one with 250 genomes genomes.
#
# So we start with our genera list which represent both common bacterial genera and things that are not totally unique giving us the ability to demonstrate similar vs un-similar genomes.

# %%
genus_set_1 = 'Escherichia'
genus_set_2, genus_set_3, genus_set_4, genus_set_5 = 'Vibrio', 'Bacteroides', 'Clostridium', 'Listeria'
genus_set_6, genus_set_7, genus_set_8, genus_set_9, genus_set_10 = 'Lactobacillus', 'Staphylococcus', 'Shigella', 'Pseudomonas', 'Bifidobacterium'

# %% [markdown]
# So finally, I can use these genera labels to create the actual genome lists to use for sample simulation.

# %%
for idx, genus_set in enumerate([[genus_set_1], 
                  [genus_set_1, genus_set_2, genus_set_3, genus_set_4, genus_set_5], 
                  [genus_set_1, genus_set_2, genus_set_3, genus_set_4, genus_set_5, genus_set_6, genus_set_7, genus_set_8, genus_set_9, genus_set_10]]):
    
    for num_genomes in [25, 50, 250]:
        if idx == 0:
            num_genera = 1
        else:
            num_genera = idx*5
        complexity_sim_folder = os.path.join(os.getcwd(), f"example_input_data/new_simulations/complexity_sim_{num_genera}_genera_{num_genomes}_genomes")
        if not os.path.exists(complexity_sim_folder):
            os.mkdir(complexity_sim_folder)
            os.mkdir(os.path.join(complexity_sim_folder, 'genomes'))

            for genus in genus_set:
                genus_subset = all_complete_genomes[all_complete_genomes['organism_name'].str.startswith(genus)]

                per_genus_sample_size = num_genomes/len(genus_set)
                genomes = genus_subset.sample(int(per_genus_sample_size))
                print(genus, per_genus_sample_size, genomes['ftp_path'].nunique())

                for ftp_path in genomes['ftp_path'].values:
                    genome_path = ftp_path + f"/{os.path.basename(ftp_path)}_genomic.fna.gz"
                    genome_folder = os.path.join(complexity_sim_folder, 'genomes')
                    # !wget $genome_path -P $genome_folder
# Out:
# Escherichia 2.5 2
# --2021-03-14 01:23:23--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/397/385/GCA_000397385.1_Ec13_E2F4_TOP293-4_120714/GCA_000397385.1_Ec13_E2F4_TOP293-4_120714_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000397385.1_Ec13_E2F4_TOP293-4_120714_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/000/397/385/GCA_000397385.1_Ec13_E2F4_TOP293-4_120714 ... done.
# ==> SIZE GCA_000397385.1_Ec13_E2F4_TOP293-4_120714_genomic.fna.gz ... 1626284
# ==> PASV ... done.    ==> RETR GCA_000397385.1_Ec13_E2F4_TOP293-4_120714_genomic.fna.gz ... done.
# Length: 1626284 (1.6M) (unauthoritative)
#
# GCA_000397385.1_Ec1 100%[===================>]   1.55M  3.33MB/s    in 0.5s
#
# 2021-03-14 01:23:24 (3.33 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000397385.1_Ec13_E2F4_TOP293-4_120714_genomic.fna.gz’ saved [1626284]
#
# --2021-03-14 01:23:24--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/011/855/365/GCA_011855365.1_PDT000259510.3/GCA_011855365.1_PDT000259510.3_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_011855365.1_PDT000259510.3_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/011/855/365/GCA_011855365.1_PDT000259510.3 ... done.
# ==> SIZE GCA_011855365.1_PDT000259510.3_genomic.fna.gz ... 1574940
# ==> PASV ... done.    ==> RETR GCA_011855365.1_PDT000259510.3_genomic.fna.gz ... done.
# Length: 1574940 (1.5M) (unauthoritative)
#
# GCA_011855365.1_PDT 100%[===================>]   1.50M  2.71MB/s    in 0.6s
#
# 2021-03-14 01:23:25 (2.71 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_011855365.1_PDT000259510.3_genomic.fna.gz’ saved [1574940]
#
# Vibrio 2.5 2
# --2021-03-14 01:23:26--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/001/597/655/GCA_001597655.1_ASM159765v1/GCA_001597655.1_ASM159765v1_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_001597655.1_ASM159765v1_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/001/597/655/GCA_001597655.1_ASM159765v1 ... done.
# ==> SIZE GCA_001597655.1_ASM159765v1_genomic.fna.gz ... 1399787
# ==> PASV ... done.    ==> RETR GCA_001597655.1_ASM159765v1_genomic.fna.gz ... done.
# Length: 1399787 (1.3M) (unauthoritative)
#
# GCA_001597655.1_ASM 100%[===================>]   1.33M  3.51MB/s    in 0.4s
#
# 2021-03-14 01:23:27 (3.51 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_001597655.1_ASM159765v1_genomic.fna.gz’ saved [1399787]
#
# --2021-03-14 01:23:27--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/269/765/GCA_000269765.1_ASM26976v1/GCA_000269765.1_ASM26976v1_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000269765.1_ASM26976v1_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/000/269/765/GCA_000269765.1_ASM26976v1 ... done.
# ==> SIZE GCA_000269765.1_ASM26976v1_genomic.fna.gz ... 1481534
# ==> PASV ... done.    ==> RETR GCA_000269765.1_ASM26976v1_genomic.fna.gz ... done.
# Length: 1481534 (1.4M) (unauthoritative)
#
# GCA_000269765.1_ASM 100%[===================>]   1.41M  3.66MB/s    in 0.4s
#
# 2021-03-14 01:23:28 (3.66 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000269765.1_ASM26976v1_genomic.fna.gz’ saved [1481534]
#
# Bacteroides 2.5 2
# --2021-03-14 01:23:28--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/438/035/GCA_000438035.1_MGS6/GCA_000438035.1_MGS6_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000438035.1_MGS6_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/000/438/035/GCA_000438035.1_MGS6 ... done.
# ==> SIZE GCA_000438035.1_MGS6_genomic.fna.gz ... 1151242
# ==> PASV ... done.    ==> RETR GCA_000438035.1_MGS6_genomic.fna.gz ... done.
# Length: 1151242 (1.1M) (unauthoritative)
#
# GCA_000438035.1_MGS 100%[===================>]   1.10M  2.56MB/s    in 0.4s
#
# 2021-03-14 01:23:29 (2.56 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000438035.1_MGS6_genomic.fna.gz’ saved [1151242]
#
# --2021-03-14 01:23:29--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/433/375/GCA_000433375.1_MGS32/GCA_000433375.1_MGS32_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000433375.1_MGS32_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/000/433/375/GCA_000433375.1_MGS32 ... done.
# ==> SIZE GCA_000433375.1_MGS32_genomic.fna.gz ... 1430411
# ==> PASV ... done.    ==> RETR GCA_000433375.1_MGS32_genomic.fna.gz ... done.
# Length: 1430411 (1.4M) (unauthoritative)
#
# GCA_000433375.1_MGS 100%[===================>]   1.36M  3.23MB/s    in 0.4s
#
# 2021-03-14 01:23:30 (3.23 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000433375.1_MGS32_genomic.fna.gz’ saved [1430411]
#
# Clostridium 2.5 2
# --2021-03-14 01:23:30--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/436/455/GCA_000436455.1_MGS132/GCA_000436455.1_MGS132_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000436455.1_MGS132_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/000/436/455/GCA_000436455.1_MGS132 ... done.
# ==> SIZE GCA_000436455.1_MGS132_genomic.fna.gz ... 1342123
# ==> PASV ... done.    ==> RETR GCA_000436455.1_MGS132_genomic.fna.gz ... done.
# Length: 1342123 (1.3M) (unauthoritative)
#
# GCA_000436455.1_MGS 100%[===================>]   1.28M  3.01MB/s    in 0.4s
#
# 2021-03-14 01:23:31 (3.01 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000436455.1_MGS132_genomic.fna.gz’ saved [1342123]
#
# --2021-03-14 01:23:31--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/016/902/235/GCA_016902235.1_ASM1690223v1/GCA_016902235.1_ASM1690223v1_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_016902235.1_ASM1690223v1_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/016/902/235/GCA_016902235.1_ASM1690223v1 ... done.
# ==> SIZE GCA_016902235.1_ASM1690223v1_genomic.fna.gz ... 678653
# ==> PASV ... done.    ==> RETR GCA_016902235.1_ASM1690223v1_genomic.fna.gz ... done.
# Length: 678653 (663K) (unauthoritative)
#
# GCA_016902235.1_ASM 100%[===================>] 662.75K  2.04MB/s    in 0.3s
#
# 2021-03-14 01:23:32 (2.04 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_016902235.1_ASM1690223v1_genomic.fna.gz’ saved [678653]
#
# Listeria 2.5 2
# --2021-03-14 01:23:33--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/004/710/765/GCA_004710765.1_PDT000030589.4/GCA_004710765.1_PDT000030589.4_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_004710765.1_PDT000030589.4_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/004/710/765/GCA_004710765.1_PDT000030589.4 ... done.
# ==> SIZE GCA_004710765.1_PDT000030589.4_genomic.fna.gz ... 858215
# ==> PASV ... done.    ==> RETR GCA_004710765.1_PDT000030589.4_genomic.fna.gz ... done.
# Length: 858215 (838K) (unauthoritative)
#
# GCA_004710765.1_PDT 100%[===================>] 838.10K  2.49MB/s    in 0.3s
#
# 2021-03-14 01:23:33 (2.49 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_004710765.1_PDT000030589.4_genomic.fna.gz’ saved [858215]
#
# --2021-03-14 01:23:34--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/567/965/GCA_000567965.1_ASM56796v1/GCA_000567965.1_ASM56796v1_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000567965.1_ASM56796v1_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/000/567/965/GCA_000567965.1_ASM56796v1 ... done.
# ==> SIZE GCA_000567965.1_ASM56796v1_genomic.fna.gz ... 879223
# ==> PASV ... done.    ==> RETR GCA_000567965.1_ASM56796v1_genomic.fna.gz ... done.
# Length: 879223 (859K) (unauthoritative)
#
# GCA_000567965.1_ASM 100%[===================>] 858.62K  2.39MB/s    in 0.4s
#
# 2021-03-14 01:23:35 (2.39 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000567965.1_ASM56796v1_genomic.fna.gz’ saved [879223]
#
# Lactobacillus 2.5 2
# --2021-03-14 01:23:35--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/001/311/525/GCA_001311525.1_ASM131152v1/GCA_001311525.1_ASM131152v1_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_001311525.1_ASM131152v1_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/001/311/525/GCA_001311525.1_ASM131152v1 ... done.
# ==> SIZE GCA_001311525.1_ASM131152v1_genomic.fna.gz ... 554526
# ==> PASV ... done.    ==> RETR GCA_001311525.1_ASM131152v1_genomic.fna.gz ... done.
# Length: 554526 (542K) (unauthoritative)
#
# GCA_001311525.1_ASM 100%[===================>] 541.53K  1.68MB/s    in 0.3s
#
# 2021-03-14 01:23:36 (1.68 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_001311525.1_ASM131152v1_genomic.fna.gz’ saved [554526]
#
# --2021-03-14 01:23:36--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/165/775/GCA_000165775.3_ASM16577v3/GCA_000165775.3_ASM16577v3_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000165775.3_ASM16577v3_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/000/165/775/GCA_000165775.3_ASM16577v3 ... done.
# ==> SIZE GCA_000165775.3_ASM16577v3_genomic.fna.gz ... 623427
# ==> PASV ... done.    ==> RETR GCA_000165775.3_ASM16577v3_genomic.fna.gz ... done.
# Length: 623427 (609K) (unauthoritative)
#
# GCA_000165775.3_ASM 100%[===================>] 608.82K  1.82MB/s    in 0.3s
#
# 2021-03-14 01:23:37 (1.82 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000165775.3_ASM16577v3_genomic.fna.gz’ saved [623427]
#
# Staphylococcus 2.5 2
# --2021-03-14 01:23:37--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/002/902/575/GCA_002902575.1_ASM290257v1/GCA_002902575.1_ASM290257v1_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_002902575.1_ASM290257v1_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/002/902/575/GCA_002902575.1_ASM290257v1 ... done.
# ==> SIZE GCA_002902575.1_ASM290257v1_genomic.fna.gz ... 704198
# ==> PASV ... done.    ==> RETR GCA_002902575.1_ASM290257v1_genomic.fna.gz ... done.
# Length: 704198 (688K) (unauthoritative)
#
# GCA_002902575.1_ASM 100%[===================>] 687.69K  1.93MB/s    in 0.3s
#
# 2021-03-14 01:23:38 (1.93 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_002902575.1_ASM290257v1_genomic.fna.gz’ saved [704198]
#
# --2021-03-14 01:23:38--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/555/645/GCA_000555645.1_Stap_aure_M0406_V1/GCA_000555645.1_Stap_aure_M0406_V1_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000555645.1_Stap_aure_M0406_V1_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/000/555/645/GCA_000555645.1_Stap_aure_M0406_V1 ... done.
# ==> SIZE GCA_000555645.1_Stap_aure_M0406_V1_genomic.fna.gz ... 919251
# ==> PASV ... done.    ==> RETR GCA_000555645.1_Stap_aure_M0406_V1_genomic.fna.gz ... done.
# Length: 919251 (898K) (unauthoritative)
#
# GCA_000555645.1_Sta 100%[===================>] 897.71K  2.20MB/s    in 0.4s
#
# 2021-03-14 01:23:39 (2.20 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000555645.1_Stap_aure_M0406_V1_genomic.fna.gz’ saved [919251]
#
# Shigella 2.5 2
# --2021-03-14 01:23:39--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/268/085/GCA_000268085.1_ASM26808v1/GCA_000268085.1_ASM26808v1_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000268085.1_ASM26808v1_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/000/268/085/GCA_000268085.1_ASM26808v1 ... done.
# ==> SIZE GCA_000268085.1_ASM26808v1_genomic.fna.gz ... 1415441
# ==> PASV ... done.    ==> RETR GCA_000268085.1_ASM26808v1_genomic.fna.gz ... done.
# Length: 1415441 (1.3M) (unauthoritative)
#
# GCA_000268085.1_ASM 100%[===================>]   1.35M  3.04MB/s    in 0.4s
#
# 2021-03-14 01:23:40 (3.04 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000268085.1_ASM26808v1_genomic.fna.gz’ saved [1415441]
#
# --2021-03-14 01:23:41--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/268/165/GCA_000268165.1_ASM26816v1/GCA_000268165.1_ASM26816v1_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000268165.1_ASM26816v1_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/000/268/165/GCA_000268165.1_ASM26816v1 ... done.
# ==> SIZE GCA_000268165.1_ASM26816v1_genomic.fna.gz ... 1325670
# ==> PASV ... done.    ==> RETR GCA_000268165.1_ASM26816v1_genomic.fna.gz ... done.
# Length: 1325670 (1.3M) (unauthoritative)
#
# GCA_000268165.1_ASM 100%[===================>]   1.26M  2.67MB/s    in 0.5s
#
# 2021-03-14 01:23:42 (2.67 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000268165.1_ASM26816v1_genomic.fna.gz’ saved [1325670]
#
# Pseudomonas 2.5 2
# --2021-03-14 01:23:42--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/953/455/GCA_000953455.1_Ppseudo_Pac/GCA_000953455.1_Ppseudo_Pac_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000953455.1_Ppseudo_Pac_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/000/953/455/GCA_000953455.1_Ppseudo_Pac ... done.
# ==> SIZE GCA_000953455.1_Ppseudo_Pac_genomic.fna.gz ... 1366143
# ==> PASV ... done.    ==> RETR GCA_000953455.1_Ppseudo_Pac_genomic.fna.gz ... done.
# Length: 1366143 (1.3M) (unauthoritative)
#
# GCA_000953455.1_Pps 100%[===================>]   1.30M  2.99MB/s    in 0.4s
#
# 2021-03-14 01:23:43 (2.99 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000953455.1_Ppseudo_Pac_genomic.fna.gz’ saved [1366143]
#
# --2021-03-14 01:23:43--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/009/911/885/GCA_009911885.1_ASM991188v1/GCA_009911885.1_ASM991188v1_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_009911885.1_ASM991188v1_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/009/911/885/GCA_009911885.1_ASM991188v1 ... done.
# ==> SIZE GCA_009911885.1_ASM991188v1_genomic.fna.gz ... 104893
# ==> PASV ... done.    ==> RETR GCA_009911885.1_ASM991188v1_genomic.fna.gz ... done.
# Length: 104893 (102K) (unauthoritative)
#
# GCA_009911885.1_ASM 100%[===================>] 102.43K  --.-KB/s    in 0.1s
#
# 2021-03-14 01:23:44 (742 KB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_009911885.1_ASM991188v1_genomic.fna.gz’ saved [104893]
#
# Bifidobacterium 2.5 2
# --2021-03-14 01:23:44--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/002/311/215/GCA_002311215.1_ASM231121v1/GCA_002311215.1_ASM231121v1_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_002311215.1_ASM231121v1_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/002/311/215/GCA_002311215.1_ASM231121v1 ... done.
# ==> SIZE GCA_002311215.1_ASM231121v1_genomic.fna.gz ... 523383
# ==> PASV ... done.    ==> RETR GCA_002311215.1_ASM231121v1_genomic.fna.gz ... done.
# Length: 523383 (511K) (unauthoritative)
#
# GCA_002311215.1_ASM 100%[===================>] 511.12K  1.57MB/s    in 0.3s
#
# 2021-03-14 01:23:45 (1.57 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_002311215.1_ASM231121v1_genomic.fna.gz’ saved [523383]
#
# --2021-03-14 01:23:45--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/435/235/GCA_000435235.1_MGS119/GCA_000435235.1_MGS119_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000435235.1_MGS119_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/000/435/235/GCA_000435235.1_MGS119 ... done.
# ==> SIZE GCA_000435235.1_MGS119_genomic.fna.gz ... 570236
# ==> PASV ... done.    ==> RETR GCA_000435235.1_MGS119_genomic.fna.gz ... done.
# Length: 570236 (557K) (unauthoritative)
#
# GCA_000435235.1_MGS 100%[===================>] 556.87K  1.74MB/s    in 0.3s
#
# 2021-03-14 01:23:46 (1.74 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000435235.1_MGS119_genomic.fna.gz’ saved [570236]

# %% [markdown]
# I'll also just verify that we got the right number of genomes downloaded and the right number of genera represented in each of these experiments.

# %%
for idx, genus_set in enumerate([[genus_set_1], 
                  [genus_set_1, genus_set_2, genus_set_3, genus_set_4, genus_set_5], 
                  [genus_set_1, genus_set_2, genus_set_3, genus_set_4, genus_set_5, genus_set_6, genus_set_7, genus_set_8, genus_set_9, genus_set_10]]):
    
    for num_genomes in [25, 50, 250]:
        param_thing = f"{len(genus_set)}_genera_{num_genomes}_genomes"
        print(param_thing)

        print(len(glob.glob(f"example_input_data/new_simulations/complexity_sim_{param_thing}/genomes/*")) )

        targets = ['_'.join(i.split('/')[-1].strip('.fna.gz').split('_')[:2]) for 
                   i in glob.glob(f"example_input_data/new_simulations/complexity_sim_{param_thing}/genomes/*")]
        
        assert len(targets) == num_genomes

        all_complete_genomes[all_complete_genomes['# assembly_accession'].isin(targets)]['organism_name'].str.contains(genus_set_1).all()
        
        assert len(set(genus_set).intersection(
            set([i.split(' ')[0] for 
                 i in all_complete_genomes[all_complete_genomes['# assembly_accession'].isin(targets)]['organism_name'].values]))) == len(genus_set)
# Out:
# 1_genera_25_genomes
# 25
# 1_genera_50_genomes
# 50
# 1_genera_250_genomes
# 250
# 5_genera_25_genomes
# 25
# 5_genera_50_genomes
# 50
# 5_genera_250_genomes
# 250
# 10_genera_25_genomes
# 25
# 10_genera_50_genomes
# 50
# 10_genera_250_genomes
# 250

# %% [markdown]
# We also have to set up the genomes and metadata tsv files for simulation

# %%
for complexity_experiment in glob.glob('example_input_data/new_simulations/complexity*'):
    experiment_name = os.path.basename(complexity_experiment)
    
    for fna_file in glob.glob(f"example_input_data/new_simulations/{experiment_name}/genomes/*.gz"):
        # !gzip -d $fna_file
    
    genomes = glob.glob(os.path.join(complexity_experiment,'genomes','*'))
    genomes_mod = [os.path.join('/input/genomes',os.path.basename(i)) for i in genomes]
    
    df = pd.DataFrame(genomes_mod)
    df['genome_ID'] = [ f"Genome{float(i+1)}" for i in range(len(df))]
    df = df[['genome_ID',0]]
    df.to_csv(os.path.join(complexity_experiment,'genome_to_id.tsv'), sep='\t', header=False, index=False)
    
    metadata_df = df
    metadata_df['novelty_category'] = 'known_strain'
    metadata_df['NCBI_ID'] = metadata_df[0].str.split('/', expand=True)[3].str.split('_', expand=True)[[0,1]].agg('_'.join, axis=1)
    
    metadata_df = metadata_df.merge(all_complete_genomes, left_on='NCBI_ID', 
                      right_on='# assembly_accession', 
                      how='inner')
    metadata_df['NCBI_ID'] = metadata_df['ftp_path'].str.split('/', expand=True)[9].str.strip('.fna.gz')
    
    metadata_df = metadata_df[['genome_ID','NCBI_ID','taxid','novelty_category']].rename(columns={'NCBI_ID':'OTU','taxid':'NCBI_ID',})
    metadata_df['NCBI_ID'] = 2
    
    metadata_df.to_csv(os.path.join(complexity_experiment,'metadata.tsv'), sep='\t', index=False)

# %% [markdown]
# And now I can run this to create the simulated samples

# %%
experiments = [os.path.basename(i) for i in glob.glob('example_input_data/new_simulations/complexity*')]

for experiment in experiments:
    if len(glob.glob(os.path.join('example_input_data/new_simulations',experiment,'*','reads','anonymous*'))) == 0:
        print('simulating',experiment)
        
        input_folder = os.path.join(os.getcwd(), f"example_input_data/new_simulations/{experiment}")
        output_folder = os.path.join(os.getcwd(), f"example_input_data/new_simulations/{experiment}")

        input_directory = f"{input_folder}:/input:rw"
        output_directory = f"{output_folder}:/output:rw"

        # !echo UTMBpath123 | sudo -S docker run --rm -v $input_directory -v $output_directory  \
            cami/camisim:latest  metagenomesimulation.py /input/mini_config.ini
# Out:
# simulating complexity_sim_10_genera_250_genomes
# [sudo] password for pathinformatics: 2021-03-14 07:34:03 INFO: [MetagenomeSimulationPipeline] Metagenome simulation starting
# 2021-03-14 07:34:03 INFO: [MetagenomeSimulationPipeline] Validating Genomes
# 2021-03-14 07:34:03 INFO: [MetadataReader] Reading file: '/input/genome_to_id.tsv'
# 2021-03-14 07:37:36 INFO: [MetagenomeSimulationPipeline] Design Communities
# 2021-03-14 07:37:36 INFO: [CommunityDesign] Drawing strains.
# 2021-03-14 07:37:36 INFO: [MetadataReader 82380310288] Reading file: '/input/metadata.tsv'
# 2021-03-14 07:37:36 INFO: [MetadataReader 28782960663] Reading file: '/input/genome_to_id.tsv'
# 2021-03-14 07:37:36 INFO: [CommunityDesign] Validating raw sequence files!
# 2021-03-14 07:37:55 INFO: [NcbiTaxonomy] Building taxonomy tree...
# 2021-03-14 07:37:55 INFO: [NcbiTaxonomy] Reading 'nodes' file:	'/tmp/tmp6Yt7pz/NCBI/nodes.dmp'
# 2021-03-14 07:38:06 INFO: [NcbiTaxonomy] Reading 'names' file:	'/tmp/tmp6Yt7pz/NCBI/names.dmp'
# 2021-03-14 07:38:08 INFO: [NcbiTaxonomy] Reading 'merged' file:	'/tmp/tmp6Yt7pz/NCBI/merged.dmp'
# 2021-03-14 07:38:08 INFO: [NcbiTaxonomy] Done (13.0s)
# 2021-03-14 07:38:08 INFO: [MetagenomeSimulationPipeline] Move Genomes
# 2021-03-14 07:38:09 INFO: [MetagenomeSimulationPipeline] Read simulation
# 2021-03-14 07:38:09 INFO: [GenomePreparation 82430254076] Using 'mbarc' error profile.
# 2021-03-14 07:38:09 INFO: [GenomePreparation 82430254076] Reading distribution file
# 2021-03-14 07:38:09 INFO: [GenomePreparation 82430254076] Reading genome location file
# 2021-03-14 07:38:12 INFO: [GenomePreparation 82430254076] Genome 'Genome68.0' has sequences below minimum, creating filtered copy.
# 2021-03-14 07:38:16 INFO: [GenomePreparation 82430254076] Genome 'Genome152.0' has sequences below minimum, creating filtered copy.
# 2021-03-14 07:38:27 INFO: [GenomePreparation 82430254076] Genome 'Genome23.0' has sequences below minimum, creating filtered copy.
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads using ReadSimulationArtIllumina readsimulator...
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads from Genome201.0: '/output/source_genomes/GCA_001915595.1_ASM191559v1_genomic.fna'
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads from Genome14.0: '/output/source_genomes/GCA_002741635.1_ASM274163v1_genomic.fna'
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads from Genome68.0: '/tmp/tmpo1x7ji/tmpHykssw'
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads from Genome34.0: '/output/source_genomes/GCA_007813835.1_ASM781383v1_genomic.fna'
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads from Genome25.0: '/output/source_genomes/GCA_000168435.1_ASM16843v1_genomic.fna'
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads from Genome77.0: '/output/source_genomes/GCA_003573955.1_ASM357395v1_genomic.fna'
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads from Genome67.0: '/output/source_genomes/GCA_004710765.1_PDT000030589.4_genomic.fna'
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads from Genome136.0: '/output/source_genomes/GCA_000309585.1_ASM30958v1_genomic.fna'
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads from Genome152.0: '/tmp/tmpo1x7ji/tmpql5fYZ'
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads from Genome149.0: '/output/source_genomes/GCA_003433455.1_ASM343345v1_genomic.fna'
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads from Genome210.0: '/output/source_genomes/GCA_012247505.1_PDT000290375.2_genomic.fna'
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads from Genome174.0: '/output/source_genomes/GCA_012247165.1_PDT000290409.2_genomic.fna'
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads from Genome196.0: '/output/source_genomes/GCA_000439655.1_CFSAN002369_1.0_genomic.fna'
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads from Genome145.0: '/output/source_genomes/GCA_905202165.1_ERR1190858-mag-bin.7_genomic.fna'
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads from Genome62.0: '/output/source_genomes/GCA_000747465.1_O157_08BKT61141_454_genomic.fna'
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads from Genome2.0: '/output/source_genomes/GCA_002339425.1_ASM233942v1_genomic.fna'
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads from Genome221.0: '/output/source_genomes/GCA_004711065.1_PDT000030599.4_genomic.fna'
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads from Genome70.0: '/output/source_genomes/GCA_000431755.1_MGS69_genomic.fna'
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads from Genome232.0: '/output/source_genomes/GCA_004728485.1_PDT000353211.2_genomic.fna'
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads from Genome48.0: '/output/source_genomes/GCA_000092345.1_ASM9234v1_genomic.fna'
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads from Genome49.0: '/output/source_genomes/GCA_016956135.1_PDT000971140.1_genomic.fna'
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads from Genome5.0: '/output/source_genomes/GCA_000237745.2_ASM23774v2_genomic.fna'
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads from Genome23.0: '/tmp/tmpo1x7ji/tmpGsEdPX'
# 2021-03-14 07:38:28 INFO: [GenomePreparation 82430254076] Simulating reads from Genome115.0: '/output/source_genomes/GCA_000382945.1_ASM38294v1_genomic.fna'
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.06
#
# The random seed for the run: 50971974
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0129508X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome67.01.fq
# 	 the 2nd reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome67.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome67.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.09
#
# The random seed for the run: 963059643
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0964866X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome34.01.fq
# 	 the 2nd reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome34.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome34.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.11
#
# The random seed for the run: 507207848
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0250506X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome201.01.fq
# 	 the 2nd reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome201.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome201.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.16
#
# The random seed for the run: 393287511
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.388771X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome25.01.fq
# 	 the 2nd reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome25.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome25.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.1
#
# The random seed for the run: 1414977469
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0199176X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome210.01.fq
# 	 the 2nd reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome210.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome210.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.15
#
# The random seed for the run: 1937464905
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.13405X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome196.01.fq
# 	 the 2nd reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome196.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome196.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.05
#
# The random seed for the run: 411957455
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0447741X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome145.01.fq
# 	 the 2nd reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome145.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome145.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.46
#
# The random seed for the run: 1027999508
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.844945X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome149.01.fq
# 	 the 2nd reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome149.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome149.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.58
#
# The random seed for the run: 2130432890
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.562927X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome174.01.fq
# 	 the 2nd reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome174.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome174.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.86
#
# The random seed for the run: 1594031057
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            1.57076X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome136.01.fq
# 	 the 2nd reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome136.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome136.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.88
#
# The random seed for the run: 1044513605
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            2.35566X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome77.01.fq
# 	 the 2nd reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome77.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome77.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.22
#
# The random seed for the run: 460212766
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.213342X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome2.01.fq
# 	 the 2nd reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome2.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome2.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.09
#
# The random seed for the run: 1097061061
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0567769X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome221.01.fq
# 	 the 2nd reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome221.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome221.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.98
#
# The random seed for the run: 1093218188
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            2.29332X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome68.01.fq
# 	 the 2nd reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome68.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome68.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.06
#
# The random seed for the run: 1669488642
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0619974X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome70.01.fq
# 	 the 2nd reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome70.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome70.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.08
#
# The random seed for the run: 2029296162
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0315956X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome232.01.fq
# 	 the 2nd reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome232.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome232.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.08
#
# The random seed for the run: 642284040
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0652236X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome115.01.fq
# 	 the 2nd reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome115.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome115.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.17
#
# The random seed for the run: 215267604
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.094545X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome49.01.fq
# 	 the 2nd reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome49.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome49.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.36
#
# The random seed for the run: 263232151
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.479189X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome48.01.fq
# 	 the 2nd reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome48.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome48.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.39
#
# The random seed for the run: 370300383
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.511411X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome5.01.fq
# 	 the 2nd reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome5.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome5.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.76
#
# The random seed for the run: 670345468
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.815831X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome62.01.fq
# 	 the 2nd reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome62.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome62.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.43
#
# The random seed for the run: 1940362427
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.586427X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome23.01.fq
# 	 the 2nd reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome23.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome23.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 1.73
#
# The random seed for the run: 1795828534
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            2.17651X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome14.01.fq
# 	 the 2nd reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome14.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome14.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 6.98
#
# The random seed for the run: 941171800
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            9.58414X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome152.01.fq
# 	 the 2nd reads: /tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome152.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpo1x7ji/2021.03.14_07.34.03_sample_0/reads/Genome152.0.sam
#
# 2021-03-14 07:38:35 INFO: [GenomePreparation 82430254076] Simulating reads finished
# 2021-03-14 07:38:46 INFO: [MetagenomeSimulationPipeline] Generate gold standard assembly
# 2021-03-14 07:38:46 INFO: [MetadataReader 87205974322] Reading file: '/output/internal/genome_locations.tsv'
# 2021-03-14 07:39:10 INFO: [MetagenomeSimulationPipeline] Generate pooled strains gold standard assembly
# 2021-03-14 07:39:10 INFO: [MetadataReader 114087710] Reading file: '/output/internal/genome_locations.tsv'
# 2021-03-14 07:39:10 INFO: [MetagenomeSimulationPipeline] Samples used for pooled assembly: '2021.03.14_07.34.03_sample_0'
# 2021-03-14 07:39:10 INFO: [Validator 10795378910] Creating pooled gold standard
# 2021-03-14 07:39:10 INFO: [Validator 10795378910] Merging bam files.
# 2021-03-14 07:39:10 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.14_07.34.03_sample_0/bam/Genome201.0.bam'
# 2021-03-14 07:39:10 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.14_07.34.03_sample_0/bam/Genome14.0.bam'
# 2021-03-14 07:39:10 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.14_07.34.03_sample_0/bam/Genome68.0.bam'
# 2021-03-14 07:39:10 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.14_07.34.03_sample_0/bam/Genome34.0.bam'
# 2021-03-14 07:39:10 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.14_07.34.03_sample_0/bam/Genome25.0.bam'
# 2021-03-14 07:39:10 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.14_07.34.03_sample_0/bam/Genome77.0.bam'
# 2021-03-14 07:39:10 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.14_07.34.03_sample_0/bam/Genome136.0.bam'
# 2021-03-14 07:39:10 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.14_07.34.03_sample_0/bam/Genome67.0.bam'
# 2021-03-14 07:39:10 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.14_07.34.03_sample_0/bam/Genome152.0.bam'
# 2021-03-14 07:39:10 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.14_07.34.03_sample_0/bam/Genome149.0.bam'
# 2021-03-14 07:39:10 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.14_07.34.03_sample_0/bam/Genome210.0.bam'
# 2021-03-14 07:39:10 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.14_07.34.03_sample_0/bam/Genome174.0.bam'
# 2021-03-14 07:39:10 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.14_07.34.03_sample_0/bam/Genome196.0.bam'
# 2021-03-14 07:39:10 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.14_07.34.03_sample_0/bam/Genome145.0.bam'
# 2021-03-14 07:39:10 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.14_07.34.03_sample_0/bam/Genome62.0.bam'
# 2021-03-14 07:39:10 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.14_07.34.03_sample_0/bam/Genome2.0.bam'
# 2021-03-14 07:39:10 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.14_07.34.03_sample_0/bam/Genome221.0.bam'
# 2021-03-14 07:39:10 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.14_07.34.03_sample_0/bam/Genome70.0.bam'
# 2021-03-14 07:39:10 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.14_07.34.03_sample_0/bam/Genome232.0.bam'
# 2021-03-14 07:39:10 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.14_07.34.03_sample_0/bam/Genome48.0.bam'
# 2021-03-14 07:39:10 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.14_07.34.03_sample_0/bam/Genome49.0.bam'
# 2021-03-14 07:39:10 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.14_07.34.03_sample_0/bam/Genome5.0.bam'
# 2021-03-14 07:39:10 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.14_07.34.03_sample_0/bam/Genome23.0.bam'
# 2021-03-14 07:39:10 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.14_07.34.03_sample_0/bam/Genome115.0.bam'
# 2021-03-14 07:39:33 INFO: [MetagenomeSimulationPipeline] Anonymize Data
# 2021-03-14 07:39:33 INFO: [FastaAnonymizer] Interweave shuffle and anonymize
# 2021-03-14 07:40:40 INFO: [MetadataReader 4631107874] Reading file: '/output/internal/genome_locations.tsv'
# 2021-03-14 07:40:41 INFO: [MetadataReader 14300761082] Reading file: '/output/internal/meta_data.tsv'
# 2021-03-14 07:40:41 INFO: [MetadataReader 87652392539] Reading file: '/tmp/tmpo1x7ji/tmpih1NHm'
# 2021-03-14 07:40:43 INFO: [FastaAnonymizer 66694448886] Shuffle and anonymize '/tmp/tmpo1x7ji/tmpT15BqK'
# 2021-03-14 07:40:50 INFO: [MetadataReader 4079751341] Reading file: '/output/internal/genome_locations.tsv'
# 2021-03-14 07:40:51 INFO: [MetadataReader 84063950941] Reading file: '/output/internal/meta_data.tsv'
# 2021-03-14 07:40:51 INFO: [MetadataReader 48704713275] Reading file: '/tmp/tmpo1x7ji/read_start_positionsXEkuBO'
# 2021-03-14 07:40:53 INFO: [MetadataReader 43119039112] Reading file: '/tmp/tmpo1x7ji/tmpeq8s6m'
# 2021-03-14 07:41:34 INFO: [FastaAnonymizer 64368966291] Shuffle and anonymize '/tmp/tmpo1x7ji/tmp1MRVoK'
# 2021-03-14 07:41:42 INFO: [MetadataReader 78717221707] Reading file: '/output/internal/genome_locations.tsv'
# 2021-03-14 07:41:42 INFO: [MetadataReader 89765374142] Reading file: '/output/internal/meta_data.tsv'
# 2021-03-14 07:41:42 INFO: [MetadataReader 98541404663] Reading file: '/tmp/tmpo1x7ji/read_start_positionsrT8kJ6'
# 2021-03-14 07:41:44 INFO: [MetadataReader 99062647065] Reading file: '/tmp/tmpo1x7ji/tmpxuCrDp'
# 2021-03-14 07:42:25 INFO: [MetagenomeSimulationPipeline] Compress Data
# 2021-03-14 07:42:26 INFO: [Compress 66056670849] Compressing 'tmpJRuYbX'
# 2021-03-14 07:42:26 INFO: [Compress 7407710481] Compressing 'anonymous_gs_mappingfbKiIM'
# 2021-03-14 07:42:26 INFO: [Compress 53471816818] Compressing 'tmpr3U_gc'
# 2021-03-14 07:42:26 INFO: [Compress 51358739710] Compressing 'anonymous_gsa_mappingu6nTTC'
# 2021-03-14 07:42:26 INFO: [Compress 53768138361] Compressing 'tmpz06rbC'
# 2021-03-14 07:42:26 INFO: [Compress 44067189498] Compressing 'anonymous_gsa_pooled_mappingBaPQrG'
# 2021-03-14 07:42:26 INFO: [Compress 44067189498] Done compressing 'gsa_pooled_mapping.tsv.gz' in 0:00:00s.
# 2021-03-14 07:42:26 INFO: [Compress 51358739710] Done compressing 'gsa_mapping.tsv.gz' in 0:00:00s.
# 2021-03-14 07:42:27 INFO: [Compress 7407710481] Done compressing 'reads_mapping.tsv.gz' in 0:00:02s.
# 2021-03-14 07:42:27 INFO: [Compress 53768138361] Done compressing 'anonymous_gsa_pooled.fasta.gz' in 0:00:02s.
# 2021-03-14 07:42:27 INFO: [Compress 53471816818] Done compressing 'anonymous_gsa.fasta.gz' in 0:00:02s.
# 2021-03-14 07:42:34 INFO: [Compress 66056670849] Done compressing 'anonymous_reads.fq.gz' in 0:00:09s.
# 2021-03-14 07:42:34 INFO: [MetagenomeSimulationPipeline] Metagenome simulation finished
# simulating complexity_sim_1_genera_250_genomes
# [sudo] password for pathinformatics: 2021-03-14 07:42:37 INFO: [MetagenomeSimulationPipeline] Metagenome simulation starting
# 2021-03-14 07:42:37 INFO: [MetagenomeSimulationPipeline] Validating Genomes
# 2021-03-14 07:42:37 INFO: [MetadataReader] Reading file: '/input/genome_to_id.tsv'
# 2021-03-14 07:47:20 INFO: [MetagenomeSimulationPipeline] Design Communities
# 2021-03-14 07:47:20 INFO: [CommunityDesign] Drawing strains.
# 2021-03-14 07:47:20 INFO: [MetadataReader 82380310288] Reading file: '/input/metadata.tsv'
# 2021-03-14 07:47:20 INFO: [MetadataReader 28782960663] Reading file: '/input/genome_to_id.tsv'
# 2021-03-14 07:47:20 INFO: [CommunityDesign] Validating raw sequence files!
# 2021-03-14 07:47:52 INFO: [NcbiTaxonomy] Building taxonomy tree...
# 2021-03-14 07:47:52 INFO: [NcbiTaxonomy] Reading 'nodes' file:	'/tmp/tmpoma2lH/NCBI/nodes.dmp'
# 2021-03-14 07:48:03 INFO: [NcbiTaxonomy] Reading 'names' file:	'/tmp/tmpoma2lH/NCBI/names.dmp'
# 2021-03-14 07:48:05 INFO: [NcbiTaxonomy] Reading 'merged' file:	'/tmp/tmpoma2lH/NCBI/merged.dmp'
# 2021-03-14 07:48:05 INFO: [NcbiTaxonomy] Done (13.0s)
# 2021-03-14 07:48:05 INFO: [MetagenomeSimulationPipeline] Move Genomes
# 2021-03-14 07:48:06 INFO: [MetagenomeSimulationPipeline] Read simulation
# 2021-03-14 07:48:06 INFO: [GenomePreparation 82430254076] Using 'mbarc' error profile.
# 2021-03-14 07:48:06 INFO: [GenomePreparation 82430254076] Reading distribution file
# 2021-03-14 07:48:06 INFO: [GenomePreparation 82430254076] Reading genome location file
# 2021-03-14 07:48:29 INFO: [GenomePreparation 82430254076] Genome 'Genome142.0' has sequences below minimum, creating filtered copy.
# 2021-03-14 07:48:37 INFO: [GenomePreparation 82430254076] Genome 'Genome22.0' has sequences below minimum, creating filtered copy.
# 2021-03-14 07:48:37 INFO: [GenomePreparation 82430254076] Simulating reads using ReadSimulationArtIllumina readsimulator...
# 2021-03-14 07:48:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome172.0: '/output/source_genomes/GCA_000508685.1_Ecoli_DORA_A_5_14_21_velvet_1.1_genomic.fna'
# 2021-03-14 07:48:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome223.0: '/output/source_genomes/GCA_012251505.1_PDT000468252.1_genomic.fna'
# 2021-03-14 07:48:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome29.0: '/output/source_genomes/GCA_012229025.1_PDT000300831.2_genomic.fna'
# 2021-03-14 07:48:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome34.0: '/output/source_genomes/GCA_013049715.1_PDT000290410.4_genomic.fna'
# 2021-03-14 07:48:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome25.0: '/output/source_genomes/GCA_902729235.2_easoj011_ecoli_genomic_umi_ont_r10_g324hac_genomic.fna'
# 2021-03-14 07:48:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome128.0: '/output/source_genomes/GCA_012248085.1_PDT000290413.2_genomic.fna'
# 2021-03-14 07:48:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome59.0: '/output/source_genomes/GCA_013039825.1_PDT000415768.1_genomic.fna'
# 2021-03-14 07:48:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome133.0: '/output/source_genomes/GCA_016955435.1_PDT000971175.1_genomic.fna'
# 2021-03-14 07:48:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome64.0: '/output/source_genomes/GCA_016954975.1_PDT000971222.1_genomic.fna'
# 2021-03-14 07:48:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome136.0: '/output/source_genomes/GCA_000432955.1_MGS4_genomic.fna'
# 2021-03-14 07:48:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome134.0: '/output/source_genomes/GCA_000614625.1_ASM61462v1_genomic.fna'
# ...
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.23
#
# The random seed for the run: 2029410300
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.389689X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpgTkE_V/2021.03.14_08.23.34_sample_0/reads/Genome22.01.fq
# 	 the 2nd reads: /tmp/tmpgTkE_V/2021.03.14_08.23.34_sample_0/reads/Genome22.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpgTkE_V/2021.03.14_08.23.34_sample_0/reads/Genome22.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.64
#
# The random seed for the run: 2139276349
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.236271X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpgTkE_V/2021.03.14_08.23.34_sample_0/reads/Genome40.01.fq
# 	 the 2nd reads: /tmp/tmpgTkE_V/2021.03.14_08.23.34_sample_0/reads/Genome40.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpgTkE_V/2021.03.14_08.23.34_sample_0/reads/Genome40.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 1.68
#
# The random seed for the run: 597928115
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            4.15379X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpgTkE_V/2021.03.14_08.23.34_sample_0/reads/Genome38.01.fq
# 	 the 2nd reads: /tmp/tmpgTkE_V/2021.03.14_08.23.34_sample_0/reads/Genome38.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpgTkE_V/2021.03.14_08.23.34_sample_0/reads/Genome38.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 2.63
#
# The random seed for the run: 2102807139
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            2.98483X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpgTkE_V/2021.03.14_08.23.34_sample_0/reads/Genome31.01.fq
# 	 the 2nd reads: /tmp/tmpgTkE_V/2021.03.14_08.23.34_sample_0/reads/Genome31.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpgTkE_V/2021.03.14_08.23.34_sample_0/reads/Genome31.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 2.88
#
# The random seed for the run: 1923521921
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            5.80563X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpgTkE_V/2021.03.14_08.23.34_sample_0/reads/Genome29.01.fq
# 	 the 2nd reads: /tmp/tmpgTkE_V/2021.03.14_08.23.34_sample_0/reads/Genome29.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpgTkE_V/2021.03.14_08.23.34_sample_0/reads/Genome29.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 2.59
#
# The random seed for the run: 387153331
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            5.57772X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpgTkE_V/2021.03.14_08.23.34_sample_0/reads/Genome3.01.fq
# 	 the 2nd reads: /tmp/tmpgTkE_V/2021.03.14_08.23.34_sample_0/reads/Genome3.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpgTkE_V/2021.03.14_08.23.34_sample_0/reads/Genome3.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 1.88
#
# The random seed for the run: 1203576411
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            2.60344X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpgTkE_V/2021.03.14_08.23.34_sample_0/reads/Genome8.01.fq
# 	 the 2nd reads: /tmp/tmpgTkE_V/2021.03.14_08.23.34_sample_0/reads/Genome8.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpgTkE_V/2021.03.14_08.23.34_sample_0/reads/Genome8.0.sam
#
# 2021-03-14 08:25:18 INFO: [GenomePreparation 64152656348] Simulating reads finished
# 2021-03-14 08:25:22 INFO: [MetagenomeSimulationPipeline] Generate gold standard assembly
# 2021-03-14 08:25:22 INFO: [MetadataReader 38994325909] Reading file: '/output/internal/genome_locations.tsv'
# 2021-03-14 08:25:48 INFO: [MetagenomeSimulationPipeline] Generate pooled strains gold standard assembly
# 2021-03-14 08:25:48 INFO: [MetadataReader 34289848075] Reading file: '/output/internal/genome_locations.tsv'
# 2021-03-14 08:25:48 INFO: [MetagenomeSimulationPipeline] Samples used for pooled assembly: '2021.03.14_08.23.34_sample_0'
# 2021-03-14 08:25:48 INFO: [Validator 5358345304] Creating pooled gold standard
# 2021-03-14 08:25:48 INFO: [Validator 5358345304] Merging bam files.
# 2021-03-14 08:25:48 WARNING: [Validator 5358345304] List contains only one file: '/output/2021.03.14_08.23.34_sample_0/bam/Genome11.0.bam'
# 2021-03-14 08:25:48 WARNING: [Validator 5358345304] List contains only one file: '/output/2021.03.14_08.23.34_sample_0/bam/Genome29.0.bam'
# 2021-03-14 08:25:48 WARNING: [Validator 5358345304] List contains only one file: '/output/2021.03.14_08.23.34_sample_0/bam/Genome42.0.bam'
# 2021-03-14 08:25:48 WARNING: [Validator 5358345304] List contains only one file: '/output/2021.03.14_08.23.34_sample_0/bam/Genome34.0.bam'
# 2021-03-14 08:25:48 WARNING: [Validator 5358345304] List contains only one file: '/output/2021.03.14_08.23.34_sample_0/bam/Genome31.0.bam'
# 2021-03-14 08:25:48 WARNING: [Validator 5358345304] List contains only one file: '/output/2021.03.14_08.23.34_sample_0/bam/Genome16.0.bam'
# 2021-03-14 08:25:48 WARNING: [Validator 5358345304] List contains only one file: '/output/2021.03.14_08.23.34_sample_0/bam/Genome24.0.bam'
# 2021-03-14 08:25:48 WARNING: [Validator 5358345304] List contains only one file: '/output/2021.03.14_08.23.34_sample_0/bam/Genome12.0.bam'
# 2021-03-14 08:25:48 WARNING: [Validator 5358345304] List contains only one file: '/output/2021.03.14_08.23.34_sample_0/bam/Genome47.0.bam'
# 2021-03-14 08:25:48 WARNING: [Validator 5358345304] List contains only one file: '/output/2021.03.14_08.23.34_sample_0/bam/Genome50.0.bam'
# 2021-03-14 08:25:48 WARNING: [Validator 5358345304] List contains only one file: '/output/2021.03.14_08.23.34_sample_0/bam/Genome21.0.bam'
# 2021-03-14 08:25:48 WARNING: [Validator 5358345304] List contains only one file: '/output/2021.03.14_08.23.34_sample_0/bam/Genome4.0.bam'
# 2021-03-14 08:25:48 WARNING: [Validator 5358345304] List contains only one file: '/output/2021.03.14_08.23.34_sample_0/bam/Genome49.0.bam'
# 2021-03-14 08:25:48 WARNING: [Validator 5358345304] List contains only one file: '/output/2021.03.14_08.23.34_sample_0/bam/Genome5.0.bam'
# 2021-03-14 08:25:48 WARNING: [Validator 5358345304] List contains only one file: '/output/2021.03.14_08.23.34_sample_0/bam/Genome3.0.bam'
# 2021-03-14 08:25:48 WARNING: [Validator 5358345304] List contains only one file: '/output/2021.03.14_08.23.34_sample_0/bam/Genome30.0.bam'
# 2021-03-14 08:25:48 WARNING: [Validator 5358345304] List contains only one file: '/output/2021.03.14_08.23.34_sample_0/bam/Genome39.0.bam'
# 2021-03-14 08:25:48 WARNING: [Validator 5358345304] List contains only one file: '/output/2021.03.14_08.23.34_sample_0/bam/Genome20.0.bam'
# 2021-03-14 08:25:48 WARNING: [Validator 5358345304] List contains only one file: '/output/2021.03.14_08.23.34_sample_0/bam/Genome38.0.bam'
# 2021-03-14 08:25:48 WARNING: [Validator 5358345304] List contains only one file: '/output/2021.03.14_08.23.34_sample_0/bam/Genome23.0.bam'
# 2021-03-14 08:25:48 WARNING: [Validator 5358345304] List contains only one file: '/output/2021.03.14_08.23.34_sample_0/bam/Genome36.0.bam'
# 2021-03-14 08:25:48 WARNING: [Validator 5358345304] List contains only one file: '/output/2021.03.14_08.23.34_sample_0/bam/Genome40.0.bam'
# 2021-03-14 08:25:48 WARNING: [Validator 5358345304] List contains only one file: '/output/2021.03.14_08.23.34_sample_0/bam/Genome8.0.bam'
# 2021-03-14 08:25:48 WARNING: [Validator 5358345304] List contains only one file: '/output/2021.03.14_08.23.34_sample_0/bam/Genome22.0.bam'
# 2021-03-14 08:26:13 INFO: [MetagenomeSimulationPipeline] Anonymize Data
# 2021-03-14 08:26:13 INFO: [FastaAnonymizer] Interweave shuffle and anonymize
# 2021-03-14 08:27:17 INFO: [MetadataReader 55801910510] Reading file: '/output/internal/genome_locations.tsv'
# 2021-03-14 08:27:18 INFO: [MetadataReader 35298217545] Reading file: '/output/internal/meta_data.tsv'
# 2021-03-14 08:27:18 INFO: [MetadataReader 50273713801] Reading file: '/tmp/tmpgTkE_V/tmp8o8GNu'
# 2021-03-14 08:27:20 INFO: [FastaAnonymizer 20754120427] Shuffle and anonymize '/tmp/tmpgTkE_V/tmpToiiJe'
# 2021-03-14 08:27:27 INFO: [MetadataReader 64547429207] Reading file: '/output/internal/genome_locations.tsv'
# 2021-03-14 08:27:28 INFO: [MetadataReader 10989772577] Reading file: '/output/internal/meta_data.tsv'
# 2021-03-14 08:27:28 INFO: [MetadataReader 53809671431] Reading file: '/tmp/tmpgTkE_V/read_start_positionsgcyQeQ'
# 2021-03-14 08:27:30 INFO: [MetadataReader 18168782768] Reading file: '/tmp/tmpgTkE_V/tmpM2UB3p'
# 2021-03-14 08:27:51 INFO: [FastaAnonymizer 92324153505] Shuffle and anonymize '/tmp/tmpgTkE_V/tmpa3a3Gg'
# 2021-03-14 08:27:57 INFO: [MetadataReader 83768748887] Reading file: '/output/internal/genome_locations.tsv'
# 2021-03-14 08:27:58 INFO: [MetadataReader 11249978774] Reading file: '/output/internal/meta_data.tsv'
# 2021-03-14 08:27:58 INFO: [MetadataReader 66861377693] Reading file: '/tmp/tmpgTkE_V/read_start_positionsh1RzYe'
# 2021-03-14 08:28:00 INFO: [MetadataReader 8017839927] Reading file: '/tmp/tmpgTkE_V/tmpOWujXy'
# 2021-03-14 08:28:21 INFO: [MetagenomeSimulationPipeline] Compress Data
# 2021-03-14 08:28:21 INFO: [Compress 63426972432] Compressing 'tmpTBLREf'
# 2021-03-14 08:28:21 INFO: [Compress 10444597134] Compressing 'anonymous_gs_mappingKsKPoB'
# 2021-03-14 08:28:21 INFO: [Compress 53527434578] Compressing 'tmp5eMbrf'
# 2021-03-14 08:28:21 INFO: [Compress 32725058174] Compressing 'anonymous_gsa_mappingxfiC7Q'
# 2021-03-14 08:28:21 INFO: [Compress 95488907652] Compressing 'tmpPgvcip'
# 2021-03-14 08:28:21 INFO: [Compress 32283605537] Compressing 'anonymous_gsa_pooled_mappingEzNsAY'
# 2021-03-14 08:28:21 INFO: [Compress 32283605537] Done compressing 'gsa_pooled_mapping.tsv.gz' in 0:00:00s.
# 2021-03-14 08:28:21 INFO: [Compress 32725058174] Done compressing 'gsa_mapping.tsv.gz' in 0:00:00s.
# 2021-03-14 08:28:23 INFO: [Compress 10444597134] Done compressing 'reads_mapping.tsv.gz' in 0:00:02s.
# 2021-03-14 08:28:23 INFO: [Compress 95488907652] Done compressing 'anonymous_gsa_pooled.fasta.gz' in 0:00:02s.
# 2021-03-14 08:28:23 INFO: [Compress 53527434578] Done compressing 'anonymous_gsa.fasta.gz' in 0:00:02s.
# 2021-03-14 08:28:30 INFO: [Compress 63426972432] Done compressing 'anonymous_reads.fq.gz' in 0:00:09s.
# 2021-03-14 08:28:30 INFO: [MetagenomeSimulationPipeline] Metagenome simulation finished

# %%
glob.glob('example_input_data/new_simulations/com*/*sample_0*/reads/*anonymous_reads*')
# Out:
# ['example_input_data/new_simulations/complexity_sim_10_genera_250_genomes/2021.03.14_07.34.03_sample_0/reads/anonymous_reads.fq.gz',
#  'example_input_data/new_simulations/complexity_sim_1_genera_250_genomes/2021.03.14_07.42.37_sample_0/reads/anonymous_reads.fq.gz',
#  'example_input_data/new_simulations/complexity_sim_1_genera_25_genomes/2021.03.14_07.51.47_sample_0/reads/anonymous_reads.fq.gz',
#  'example_input_data/new_simulations/complexity_sim_5_genera_50_genomes/2021.03.14_07.56.49_sample_0/reads/anonymous_reads.fq.gz',
#  'example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/2021.03.14_08.01.38_sample_0/reads/anonymous_reads.fq.gz',
#  'example_input_data/new_simulations/complexity_sim_1_genera_50_genomes/2021.03.14_08.06.23_sample_0/reads/anonymous_reads.fq.gz',
#  'example_input_data/new_simulations/complexity_sim_5_genera_250_genomes/2021.03.14_08.11.27_sample_0/reads/anonymous_reads.fq.gz',
#  'example_input_data/new_simulations/complexity_sim_5_genera_25_genomes/2021.03.14_08.19.20_sample_0/reads/anonymous_reads.fq.gz',
#  'example_input_data/new_simulations/complexity_sim_10_genera_50_genomes/2021.03.14_08.23.34_sample_0/reads/anonymous_reads.fq.gz']

# %% [markdown]
# # Now we just need to run the assemblies
#
# Note that many of these steps are described in greater detail in the `preparing_data` notebook.

# %%
BASE_DIR = os.getcwd()

# %%
for SIM_FASTA_FILE in glob.glob('example_input_data/new_simulations/complexity_sim*/*sample_0*'):
    input_contigs_fasta = os.path.join(BASE_DIR, f"{SIM_FASTA_FILE}/contigs/anonymous_gsa.fasta.gz")
    output_filtered_contigs_fasta = os.path.join(BASE_DIR, f"{SIM_FASTA_FILE}/contigs/anonymous_gsa_filtered.fasta.gz")

    with vamb.vambtools.Reader(input_contigs_fasta, 'rb') as inputfile:
        with open(output_filtered_contigs_fasta, 'w') as outputfile:
            print(inputfile)
            print(outputfile)
            vamb.vambtools.filtercontigs(inputfile, outputfile, minlength=2000)
# Out:
# <vamb.vambtools.Reader object at 0x7f0e2d159070>
# <_io.TextIOWrapper name='/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_250_genomes/2021.03.14_07.34.03_sample_0/contigs/anonymous_gsa_filtered.fasta.gz' mode='w' encoding='UTF-8'>
# <vamb.vambtools.Reader object at 0x7f0e2e6c3cd0>
# <_io.TextIOWrapper name='/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_1_genera_250_genomes/2021.03.14_07.42.37_sample_0/contigs/anonymous_gsa_filtered.fasta.gz' mode='w' encoding='UTF-8'>
# <vamb.vambtools.Reader object at 0x7f0e2d1598e0>
# <_io.TextIOWrapper name='/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_1_genera_25_genomes/2021.03.14_07.51.47_sample_0/contigs/anonymous_gsa_filtered.fasta.gz' mode='w' encoding='UTF-8'>
# <vamb.vambtools.Reader object at 0x7f0e2d159070>
# <_io.TextIOWrapper name='/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_5_genera_50_genomes/2021.03.14_07.56.49_sample_0/contigs/anonymous_gsa_filtered.fasta.gz' mode='w' encoding='UTF-8'>
# <vamb.vambtools.Reader object at 0x7f0e2d1594c0>
# <_io.TextIOWrapper name='/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/2021.03.14_08.01.38_sample_0/contigs/anonymous_gsa_filtered.fasta.gz' mode='w' encoding='UTF-8'>
# <vamb.vambtools.Reader object at 0x7f0e2d1598e0>
# <_io.TextIOWrapper name='/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_1_genera_50_genomes/2021.03.14_08.06.23_sample_0/contigs/anonymous_gsa_filtered.fasta.gz' mode='w' encoding='UTF-8'>
# <vamb.vambtools.Reader object at 0x7f0e2d159070>
# <_io.TextIOWrapper name='/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_5_genera_250_genomes/2021.03.14_08.11.27_sample_0/contigs/anonymous_gsa_filtered.fasta.gz' mode='w' encoding='UTF-8'>
# <vamb.vambtools.Reader object at 0x7f0e2d1594c0>
# <_io.TextIOWrapper name='/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_5_genera_25_genomes/2021.03.14_08.19.20_sample_0/contigs/anonymous_gsa_filtered.fasta.gz' mode='w' encoding='UTF-8'>
# <vamb.vambtools.Reader object at 0x7f0e2d1598e0>
# <_io.TextIOWrapper name='/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_50_genomes/2021.03.14_08.23.34_sample_0/contigs/anonymous_gsa_filtered.fasta.gz' mode='w' encoding='UTF-8'>

# %%
for SIM_FASTA_FILE in glob.glob('example_input_data/new_simulations/complexity_sim*/*sample_0*'):
    print('Processing:', SIM_FASTA_FILE)
    minimap2_input = f"{SIM_FASTA_FILE}/reads/anonymous_reads.fq.gz"
    minimap2_output = f"{SIM_FASTA_FILE}/assemblies/re_mapped.bam"

    minimap_index_location = f"{SIM_FASTA_FILE}/catalogue.mmi"
    
    output_filtered_contigs_fasta = os.path.join(BASE_DIR, f"{SIM_FASTA_FILE}/contigs/anonymous_gsa_filtered.fasta.gz")

    !~/miniconda3/envs/vamb_env/bin/minimap2 -d $minimap_index_location $output_filtered_contigs_fasta 
    
    print('minimap index location', minimap_index_location)

    if not os.path.exists(os.path.join(SIM_FASTA_FILE,'assemblies')):
        os.mkdir(os.path.join(SIM_FASTA_FILE,'assemblies'))

    !~/miniconda3/envs/vamb_env/bin/minimap2 \
        -t 10 \
        -N 50 \
        -ax sr $minimap_index_location \
        $minimap2_input | samtools view -F 3584 -b --threads 8 > $minimap2_output
# Out:
# Processing: example_input_data/new_simulations/complexity_sim_10_genera_250_genomes/2021.03.14_07.34.03_sample_0
# [M::mm_idx_gen::0.189*1.21] collected minimizers
# [M::mm_idx_gen::0.252*1.64] sorted minimizers
# [M::main::0.326*1.50] loaded/built the index for 774 target sequence(s)
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 774
# [M::mm_idx_stat::0.337*1.48] distinct minimizers: 1238312 (96.93% are singletons); average occurrences: 1.038; average spacing: 5.364
# [M::main] Version: 2.17-r941
# [M::main] CMD: /home/pathinformatics/miniconda3/envs/vamb_env/bin/minimap2 -d example_input_data/new_simulations/complexity_sim_10_genera_250_genomes/2021.03.14_07.34.03_sample_0/catalogue.mmi /home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_250_genomes/2021.03.14_07.34.03_sample_0/contigs/anonymous_gsa_filtered.fasta.gz
# [M::main] Real time: 0.342 sec; CPU: 0.503 sec; Peak RSS: 0.736 GB
# minimap index location example_input_data/new_simulations/complexity_sim_10_genera_250_genomes/2021.03.14_07.34.03_sample_0/catalogue.mmi
# [WARNING] Indexing parameters (-k, -w or -H) overridden by parameters used in the prebuilt index.
# [M::main::0.063*1.02] loaded/built the index for 774 target sequence(s)
# [M::mm_mapopt_update::0.063*1.02] mid_occ = 1000
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 774
# [M::mm_idx_stat::0.073*1.02] distinct minimizers: 1238312 (96.93% are singletons); average occurrences: 1.038; average spacing: 5.364
# [M::worker_pipeline::1.432*4.20] mapped 333334 sequences
# [M::worker_pipeline::2.156*4.84] mapped 329174 sequences
# [M::main] Version: 2.17-r941
# [M::main] CMD: /home/pathinformatics/miniconda3/envs/vamb_env/bin/minimap2 -t 10 -N 50 -ax sr example_input_data/new_simulations/complexity_sim_10_genera_250_genomes/2021.03.14_07.34.03_sample_0/catalogue.mmi example_input_data/new_simulations/complexity_sim_10_genera_250_genomes/2021.03.14_07.34.03_sample_0/reads/anonymous_reads.fq.gz
# [M::main] Real time: 2.165 sec; CPU: 10.447 sec; Peak RSS: 0.325 GB
# Processing: example_input_data/new_simulations/complexity_sim_1_genera_250_genomes/2021.03.14_07.42.37_sample_0
# [M::mm_idx_gen::0.149*1.21] collected minimizers
# [M::mm_idx_gen::0.205*1.69] sorted minimizers
# [M::main::0.238*1.59] loaded/built the index for 586 target sequence(s)
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 586
# [M::mm_idx_stat::0.249*1.57] distinct minimizers: 977379 (88.24% are singletons); average occurrences: 1.128; average spacing: 5.359
# [M::main] Version: 2.17-r941
# [M::main] CMD: /home/pathinformatics/miniconda3/envs/vamb_env/bin/minimap2 -d example_input_data/new_simulations/complexity_sim_1_genera_250_genomes/2021.03.14_07.42.37_sample_0/catalogue.mmi /home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_1_genera_250_genomes/2021.03.14_07.42.37_sample_0/contigs/anonymous_gsa_filtered.fasta.gz
# [M::main] Real time: 0.254 sec; CPU: 0.395 sec; Peak RSS: 0.736 GB
# minimap index location example_input_data/new_simulations/complexity_sim_1_genera_250_genomes/2021.03.14_07.42.37_sample_0/catalogue.mmi
# [WARNING] Indexing parameters (-k, -w or -H) overridden by parameters used in the prebuilt index.
# [M::main::0.067*1.02] loaded/built the index for 586 target sequence(s)
# [M::mm_mapopt_update::0.067*1.02] mid_occ = 1000
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 586
# [M::mm_idx_stat::0.077*1.02] distinct minimizers: 977379 (88.24% are singletons); average occurrences: 1.128; average spacing: 5.359
# [M::worker_pipeline::1.801*6.52] mapped 333334 sequences
# [M::worker_pipeline::2.486*6.18] mapped 330750 sequences
# [M::main] Version: 2.17-r941
# [M::main] CMD: /home/pathinformatics/miniconda3/envs/vamb_env/bin/minimap2 -t 10 -N 50 -ax sr example_input_data/new_simulations/complexity_sim_1_genera_250_genomes/2021.03.14_07.42.37_sample_0/catalogue.mmi example_input_data/new_simulations/complexity_sim_1_genera_250_genomes/2021.03.14_07.42.37_sample_0/reads/anonymous_reads.fq.gz
# [M::main] Real time: 2.491 sec; CPU: 15.363 sec; Peak RSS: 0.342 GB
# Processing: example_input_data/new_simulations/complexity_sim_1_genera_25_genomes/2021.03.14_07.51.47_sample_0
# [M::mm_idx_gen::0.235*1.14] collected minimizers
# [M::mm_idx_gen::0.326*1.66] sorted minimizers
# [M::main::0.369*1.58] loaded/built the index for 2051 target sequence(s)
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 2051
# [M::mm_idx_stat::0.382*1.56] distinct minimizers: 1264376 (62.07% are singletons); average occurrences: 1.488; average spacing: 5.368
# [M::main] Version: 2.17-r941
# [M::main] CMD: /home/pathinformatics/miniconda3/envs/vamb_env/bin/minimap2 -d example_input_data/new_simulations/complexity_sim_1_genera_25_genomes/2021.03.14_07.51.47_sample_0/catalogue.mmi /home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_1_genera_25_genomes/2021.03.14_07.51.47_sample_0/contigs/anonymous_gsa_filtered.fasta.gz
# [M::main] Real time: 0.387 sec; CPU: 0.600 sec; Peak RSS: 0.736 GB
# minimap index location example_input_data/new_simulations/complexity_sim_1_genera_25_genomes/2021.03.14_07.51.47_sample_0/catalogue.mmi
# [WARNING] Indexing parameters (-k, -w or -H) overridden by parameters used in the prebuilt index.
# [M::main::0.062*1.02] loaded/built the index for 2051 target sequence(s)
# [M::mm_mapopt_update::0.062*1.02] mid_occ = 1000
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 2051
# [M::mm_idx_stat::0.075*1.02] distinct minimizers: 1264376 (62.07% are singletons); average occurrences: 1.488; average spacing: 5.368
# [M::worker_pipeline::2.085*7.48] mapped 333334 sequences
# [M::worker_pipeline::2.978*7.02] mapped 330096 sequences
# [M::main] Version: 2.17-r941
# [M::main] CMD: /home/pathinformatics/miniconda3/envs/vamb_env/bin/minimap2 -t 10 -N 50 -ax sr example_input_data/new_simulations/complexity_sim_1_genera_25_genomes/2021.03.14_07.51.47_sample_0/catalogue.mmi example_input_data/new_simulations/complexity_sim_1_genera_25_genomes/2021.03.14_07.51.47_sample_0/reads/anonymous_reads.fq.gz
# [M::main] Real time: 2.986 sec; CPU: 20.902 sec; Peak RSS: 0.379 GB
# Processing: example_input_data/new_simulations/complexity_sim_5_genera_50_genomes/2021.03.14_07.56.49_sample_0
# [M::mm_idx_gen::0.285*1.12] collected minimizers
# [M::mm_idx_gen::0.379*1.58] sorted minimizers
# [M::main::0.446*1.49] loaded/built the index for 2516 target sequence(s)
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 2516
# [M::mm_idx_stat::0.467*1.47] distinct minimizers: 2162200 (95.69% are singletons); average occurrences: 1.051; average spacing: 5.368
# [M::main] Version: 2.17-r941
# [M::main] CMD: /home/pathinformatics/miniconda3/envs/vamb_env/bin/minimap2 -d example_input_data/new_simulations/complexity_sim_5_genera_50_genomes/2021.03.14_07.56.49_sample_0/catalogue.mmi /home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_5_genera_50_genomes/2021.03.14_07.56.49_sample_0/contigs/anonymous_gsa_filtered.fasta.gz
# [M::main] Real time: 0.473 sec; CPU: 0.693 sec; Peak RSS: 0.736 GB
# minimap index location example_input_data/new_simulations/complexity_sim_5_genera_50_genomes/2021.03.14_07.56.49_sample_0/catalogue.mmi
# [WARNING] Indexing parameters (-k, -w or -H) overridden by parameters used in the prebuilt index.
# [M::main::0.130*1.01] loaded/built the index for 2516 target sequence(s)
# [M::mm_mapopt_update::0.131*1.01] mid_occ = 1000
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 2516
# [M::mm_idx_stat::0.151*1.01] distinct minimizers: 2162200 (95.69% are singletons); average occurrences: 1.051; average spacing: 5.368
# [M::worker_pipeline::1.599*4.66] mapped 333334 sequences
# [M::worker_pipeline::2.297*5.11] mapped 328830 sequences
# [M::main] Version: 2.17-r941
# [M::main] CMD: /home/pathinformatics/miniconda3/envs/vamb_env/bin/minimap2 -t 10 -N 50 -ax sr example_input_data/new_simulations/complexity_sim_5_genera_50_genomes/2021.03.14_07.56.49_sample_0/catalogue.mmi example_input_data/new_simulations/complexity_sim_5_genera_50_genomes/2021.03.14_07.56.49_sample_0/reads/anonymous_reads.fq.gz
# [M::main] Real time: 2.306 sec; CPU: 11.744 sec; Peak RSS: 0.359 GB
# Processing: example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/2021.03.14_08.01.38_sample_0
# [M::mm_idx_gen::0.239*1.14] collected minimizers
# [M::mm_idx_gen::0.333*1.66] sorted minimizers
# [M::main::0.388*1.56] loaded/built the index for 1629 target sequence(s)
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1629
# [M::mm_idx_stat::0.406*1.54] distinct minimizers: 1703701 (86.60% are singletons); average occurrences: 1.162; average spacing: 5.366
# [M::main] Version: 2.17-r941
# [M::main] CMD: /home/pathinformatics/miniconda3/envs/vamb_env/bin/minimap2 -d example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/2021.03.14_08.01.38_sample_0/catalogue.mmi /home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/2021.03.14_08.01.38_sample_0/contigs/anonymous_gsa_filtered.fasta.gz
# [M::main] Real time: 0.412 sec; CPU: 0.631 sec; Peak RSS: 0.736 GB
# minimap index location example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/2021.03.14_08.01.38_sample_0/catalogue.mmi
# [WARNING] Indexing parameters (-k, -w or -H) overridden by parameters used in the prebuilt index.
# [M::main::0.102*1.01] loaded/built the index for 1629 target sequence(s)
# [M::mm_mapopt_update::0.102*1.01] mid_occ = 1000
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1629
# [M::mm_idx_stat::0.120*1.01] distinct minimizers: 1703701 (86.60% are singletons); average occurrences: 1.162; average spacing: 5.366
# [M::worker_pipeline::1.694*5.61] mapped 333334 sequences
# [M::worker_pipeline::2.452*5.70] mapped 329350 sequences
# [M::main] Version: 2.17-r941
# [M::main] CMD: /home/pathinformatics/miniconda3/envs/vamb_env/bin/minimap2 -t 10 -N 50 -ax sr example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/2021.03.14_08.01.38_sample_0/catalogue.mmi example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/2021.03.14_08.01.38_sample_0/reads/anonymous_reads.fq.gz
# [M::main] Real time: 2.459 sec; CPU: 13.982 sec; Peak RSS: 0.362 GB
# Processing: example_input_data/new_simulations/complexity_sim_1_genera_50_genomes/2021.03.14_08.06.23_sample_0
# [M::mm_idx_gen::0.259*1.12] collected minimizers
# [M::mm_idx_gen::0.339*1.56] sorted minimizers
# [M::main::0.435*1.44] loaded/built the index for 2895 target sequence(s)
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 2895
# [M::mm_idx_stat::0.454*1.42] distinct minimizers: 1263412 (56.77% are singletons); average occurrences: 1.611; average spacing: 5.375
# [M::main] Version: 2.17-r941
# [M::main] CMD: /home/pathinformatics/miniconda3/envs/vamb_env/bin/minimap2 -d example_input_data/new_simulations/complexity_sim_1_genera_50_genomes/2021.03.14_08.06.23_sample_0/catalogue.mmi /home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_1_genera_50_genomes/2021.03.14_08.06.23_sample_0/contigs/anonymous_gsa_filtered.fasta.gz
# [M::main] Real time: 0.460 sec; CPU: 0.652 sec; Peak RSS: 0.736 GB
# minimap index location example_input_data/new_simulations/complexity_sim_1_genera_50_genomes/2021.03.14_08.06.23_sample_0/catalogue.mmi
# [WARNING] Indexing parameters (-k, -w or -H) overridden by parameters used in the prebuilt index.
# [M::main::0.084*1.02] loaded/built the index for 2895 target sequence(s)
# [M::mm_mapopt_update::0.084*1.02] mid_occ = 1000
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 2895
# [M::mm_idx_stat::0.098*1.01] distinct minimizers: 1263412 (56.77% are singletons); average occurrences: 1.611; average spacing: 5.375
# [M::worker_pipeline::2.206*7.52] mapped 333334 sequences
# [M::worker_pipeline::3.194*7.06] mapped 331980 sequences
# [M::main] Version: 2.17-r941
# [M::main] CMD: /home/pathinformatics/miniconda3/envs/vamb_env/bin/minimap2 -t 10 -N 50 -ax sr example_input_data/new_simulations/complexity_sim_1_genera_50_genomes/2021.03.14_08.06.23_sample_0/catalogue.mmi example_input_data/new_simulations/complexity_sim_1_genera_50_genomes/2021.03.14_08.06.23_sample_0/reads/anonymous_reads.fq.gz
# [M::main] Real time: 3.201 sec; CPU: 22.574 sec; Peak RSS: 0.389 GB
# Processing: example_input_data/new_simulations/complexity_sim_5_genera_250_genomes/2021.03.14_08.11.27_sample_0
# [M::mm_idx_gen::0.186*1.18] collected minimizers
# [M::mm_idx_gen::0.251*1.65] sorted minimizers
# [M::main::0.326*1.50] loaded/built the index for 568 target sequence(s)
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 568
# [M::mm_idx_stat::0.336*1.48] distinct minimizers: 1280562 (96.72% are singletons); average occurrences: 1.040; average spacing: 5.356
# [M::main] Version: 2.17-r941
# [M::main] CMD: /home/pathinformatics/miniconda3/envs/vamb_env/bin/minimap2 -d example_input_data/new_simulations/complexity_sim_5_genera_250_genomes/2021.03.14_08.11.27_sample_0/catalogue.mmi /home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_5_genera_250_genomes/2021.03.14_08.11.27_sample_0/contigs/anonymous_gsa_filtered.fasta.gz
# [M::main] Real time: 0.341 sec; CPU: 0.503 sec; Peak RSS: 0.736 GB
# minimap index location example_input_data/new_simulations/complexity_sim_5_genera_250_genomes/2021.03.14_08.11.27_sample_0/catalogue.mmi
# [WARNING] Indexing parameters (-k, -w or -H) overridden by parameters used in the prebuilt index.
# [M::main::0.080*1.02] loaded/built the index for 568 target sequence(s)
# [M::mm_mapopt_update::0.080*1.02] mid_occ = 1000
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 568
# [M::mm_idx_stat::0.090*1.01] distinct minimizers: 1280562 (96.72% are singletons); average occurrences: 1.040; average spacing: 5.356
# [M::worker_pipeline::1.475*3.94] mapped 333334 sequences
# [M::worker_pipeline::2.189*4.58] mapped 327978 sequences
# [M::main] Version: 2.17-r941
# [M::main] CMD: /home/pathinformatics/miniconda3/envs/vamb_env/bin/minimap2 -t 10 -N 50 -ax sr example_input_data/new_simulations/complexity_sim_5_genera_250_genomes/2021.03.14_08.11.27_sample_0/catalogue.mmi example_input_data/new_simulations/complexity_sim_5_genera_250_genomes/2021.03.14_08.11.27_sample_0/reads/anonymous_reads.fq.gz
# [M::main] Real time: 2.195 sec; CPU: 10.024 sec; Peak RSS: 0.328 GB
# Processing: example_input_data/new_simulations/complexity_sim_5_genera_25_genomes/2021.03.14_08.19.20_sample_0
# [M::mm_idx_gen::0.239*1.14] collected minimizers
# [M::mm_idx_gen::0.336*1.67] sorted minimizers
# [M::main::0.397*1.57] loaded/built the index for 1768 target sequence(s)
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1768
# [M::mm_idx_stat::0.416*1.54] distinct minimizers: 1848394 (97.59% are singletons); average occurrences: 1.026; average spacing: 5.366
# [M::main] Version: 2.17-r941
# [M::main] CMD: /home/pathinformatics/miniconda3/envs/vamb_env/bin/minimap2 -d example_input_data/new_simulations/complexity_sim_5_genera_25_genomes/2021.03.14_08.19.20_sample_0/catalogue.mmi /home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_5_genera_25_genomes/2021.03.14_08.19.20_sample_0/contigs/anonymous_gsa_filtered.fasta.gz
# [M::main] Real time: 0.422 sec; CPU: 0.648 sec; Peak RSS: 0.736 GB
# minimap index location example_input_data/new_simulations/complexity_sim_5_genera_25_genomes/2021.03.14_08.19.20_sample_0/catalogue.mmi
# [WARNING] Indexing parameters (-k, -w or -H) overridden by parameters used in the prebuilt index.
# [M::main::0.106*1.01] loaded/built the index for 1768 target sequence(s)
# [M::mm_mapopt_update::0.106*1.01] mid_occ = 1000
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1768
# [M::mm_idx_stat::0.124*1.01] distinct minimizers: 1848394 (97.59% are singletons); average occurrences: 1.026; average spacing: 5.366
# [M::worker_pipeline::1.485*4.10] mapped 333334 sequences
# [M::worker_pipeline::2.240*4.72] mapped 324374 sequences
# [M::main] Version: 2.17-r941
# [M::main] CMD: /home/pathinformatics/miniconda3/envs/vamb_env/bin/minimap2 -t 10 -N 50 -ax sr example_input_data/new_simulations/complexity_sim_5_genera_25_genomes/2021.03.14_08.19.20_sample_0/catalogue.mmi example_input_data/new_simulations/complexity_sim_5_genera_25_genomes/2021.03.14_08.19.20_sample_0/reads/anonymous_reads.fq.gz
# [M::main] Real time: 2.247 sec; CPU: 10.577 sec; Peak RSS: 0.361 GB
# Processing: example_input_data/new_simulations/complexity_sim_10_genera_50_genomes/2021.03.14_08.23.34_sample_0
# [M::mm_idx_gen::0.257*1.13] collected minimizers
# [M::mm_idx_gen::0.340*1.58] sorted minimizers
# [M::main::0.402*1.49] loaded/built the index for 2425 target sequence(s)
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 2425
# [M::mm_idx_stat::0.422*1.47] distinct minimizers: 1973910 (97.77% are singletons); average occurrences: 1.030; average spacing: 5.370
# [M::main] Version: 2.17-r941
# [M::main] CMD: /home/pathinformatics/miniconda3/envs/vamb_env/bin/minimap2 -d example_input_data/new_simulations/complexity_sim_10_genera_50_genomes/2021.03.14_08.23.34_sample_0/catalogue.mmi /home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_50_genomes/2021.03.14_08.23.34_sample_0/contigs/anonymous_gsa_filtered.fasta.gz
# [M::main] Real time: 0.429 sec; CPU: 0.626 sec; Peak RSS: 0.736 GB
# minimap index location example_input_data/new_simulations/complexity_sim_10_genera_50_genomes/2021.03.14_08.23.34_sample_0/catalogue.mmi
# [WARNING] Indexing parameters (-k, -w or -H) overridden by parameters used in the prebuilt index.
# [M::main::0.116*1.01] loaded/built the index for 2425 target sequence(s)
# [M::mm_mapopt_update::0.116*1.01] mid_occ = 1000
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 2425
# [M::mm_idx_stat::0.135*1.01] distinct minimizers: 1973910 (97.77% are singletons); average occurrences: 1.030; average spacing: 5.370
# [M::worker_pipeline::1.456*4.03] mapped 333334 sequences
# [M::worker_pipeline::2.156*4.60] mapped 310130 sequences
# [M::main] Version: 2.17-r941
# [M::main] CMD: /home/pathinformatics/miniconda3/envs/vamb_env/bin/minimap2 -t 10 -N 50 -ax sr example_input_data/new_simulations/complexity_sim_10_genera_50_genomes/2021.03.14_08.23.34_sample_0/catalogue.mmi example_input_data/new_simulations/complexity_sim_10_genera_50_genomes/2021.03.14_08.23.34_sample_0/reads/anonymous_reads.fq.gz
# [M::main] Real time: 2.163 sec; CPU: 9.920 sec; Peak RSS: 0.346 GB

# %% [markdown]
# And we calculate the TNF and RPKM matrices

# %%
for SIM_FASTA_FILE in glob.glob('example_input_data/new_simulations/complexity_sim*/*sample_0*'):
    output_filtered_contigs_fasta = f"{SIM_FASTA_FILE}/contigs/anonymous_gsa_filtered.fasta.gz"
    
    # Use Reader to open plain or zipped files. File must be opened in binary mode
    with vamb.vambtools.Reader(output_filtered_contigs_fasta, 'rb') as inputfile:
        tnfs, contignames, lengths = vamb.parsecontigs.read_contigs(inputfile)
        
    sample_bamfile = glob.glob(f"{SIM_FASTA_FILE}/assemblies/re_mapped.bam")
    print("bamfile for rpkm:", sample_bamfile)
    
    rpkms = vamb.parsebam.read_bamfiles(sample_bamfile) 
    print('Type of rpkms:', type(rpkms), 'of dtype', rpkms.dtype)
    print('Shape of rpkms', rpkms.shape)
    
    print("tnfs shape:", tnfs.shape)
    
    
    vamb_inputs_base = os.path.join(SIM_FASTA_FILE,'vamb_inputs')
    
    
    if not os.path.exists(vamb_inputs_base):
        os.mkdir(vamb_inputs_base)

    with open(os.path.join(vamb_inputs_base, 'contignames.npz'), 'wb') as file:
        vamb.vambtools.write_npz(file, np.array(contignames))

    with open(os.path.join(vamb_inputs_base, 'lengths.npz'), 'wb') as file:
        vamb.vambtools.write_npz(file, lengths)

    with open(os.path.join(vamb_inputs_base, 'tnfs.npz'), 'wb') as file:
        vamb.vambtools.write_npz(file, tnfs)

    with open(os.path.join(vamb_inputs_base, 'rpkms.npz'), 'wb') as file:
        vamb.vambtools.write_npz(file, rpkms)
# Out:
# bamfile for rpkm: ['example_input_data/new_simulations/complexity_sim_10_genera_250_genomes/2021.03.14_07.34.03_sample_0/assemblies/re_mapped.bam']
# Type of rpkms: <class 'numpy.ndarray'> of dtype float32
# Shape of rpkms (774, 1)
# tnfs shape: (774, 103)
# bamfile for rpkm: ['example_input_data/new_simulations/complexity_sim_1_genera_250_genomes/2021.03.14_07.42.37_sample_0/assemblies/re_mapped.bam']
# Type of rpkms: <class 'numpy.ndarray'> of dtype float32
# Shape of rpkms (586, 1)
# tnfs shape: (586, 103)
# bamfile for rpkm: ['example_input_data/new_simulations/complexity_sim_1_genera_25_genomes/2021.03.14_07.51.47_sample_0/assemblies/re_mapped.bam']
# Type of rpkms: <class 'numpy.ndarray'> of dtype float32
# Shape of rpkms (2051, 1)
# tnfs shape: (2051, 103)
# bamfile for rpkm: ['example_input_data/new_simulations/complexity_sim_5_genera_50_genomes/2021.03.14_07.56.49_sample_0/assemblies/re_mapped.bam']
# Type of rpkms: <class 'numpy.ndarray'> of dtype float32
# Shape of rpkms (2516, 1)
# tnfs shape: (2516, 103)
# bamfile for rpkm: ['example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/2021.03.14_08.01.38_sample_0/assemblies/re_mapped.bam']
# Type of rpkms: <class 'numpy.ndarray'> of dtype float32
# Shape of rpkms (1629, 1)
# tnfs shape: (1629, 103)
# bamfile for rpkm: ['example_input_data/new_simulations/complexity_sim_1_genera_50_genomes/2021.03.14_08.06.23_sample_0/assemblies/re_mapped.bam']
# Type of rpkms: <class 'numpy.ndarray'> of dtype float32
# Shape of rpkms (2895, 1)
# tnfs shape: (2895, 103)
# bamfile for rpkm: ['example_input_data/new_simulations/complexity_sim_5_genera_250_genomes/2021.03.14_08.11.27_sample_0/assemblies/re_mapped.bam']
# Type of rpkms: <class 'numpy.ndarray'> of dtype float32
# Shape of rpkms (568, 1)
# tnfs shape: (568, 103)
# bamfile for rpkm: ['example_input_data/new_simulations/complexity_sim_5_genera_25_genomes/2021.03.14_08.19.20_sample_0/assemblies/re_mapped.bam']
# Type of rpkms: <class 'numpy.ndarray'> of dtype float32
# Shape of rpkms (1768, 1)
# tnfs shape: (1768, 103)
# bamfile for rpkm: ['example_input_data/new_simulations/complexity_sim_10_genera_50_genomes/2021.03.14_08.23.34_sample_0/assemblies/re_mapped.bam']
# Type of rpkms: <class 'numpy.ndarray'> of dtype float32
# Shape of rpkms (2425, 1)
# tnfs shape: (2425, 103)

# %%
f1, f2 = np.random.choice(glob.glob('example_input_data/new_simulations/complexity_sim*/*sample_0*/*assem*/*re_mapped*'), 2)

print(f1 == f2)

# !diff $f1 $f2
# Out:
# False
# Binary files example_input_data/new_simulations/complexity_sim_10_genera_250_genomes/2021.03.14_07.34.03_sample_0/assemblies/re_mapped.bam and example_input_data/new_simulations/complexity_sim_1_genera_25_genomes/2021.03.14_07.51.47_sample_0/assemblies/re_mapped.bam differ

# %%
pd.read_csv('experiment_beta1/experiment_stats_beta1.tsv', sep='\t')
# Out:
#    num_genera  num_genomes  num_bins  num_mappable_bins  mean_completeness  \
# 0          10          250        29                  7          35.367005
# 1           1          250       133                  9          11.004557
# 2           1           25       189                 14          16.133731
# 3           5           50        75                  8          49.573638
# 4          10           25       193                 20          10.836362
# 5           1           50        77                  5          35.000355
# 6           5          250        59                  6          31.815141
# 7           5           25       158                  9          29.103874
# 8          10           50       107                 22          15.176583
#
#    mean_contamination  beta  dropout
# 0            0.387696     1      0.2
# 1            0.410424     1      0.2
# 2            1.513042     1      0.2
# 3            5.219702     1      0.2
# 4            0.224332     1      0.2
# 5           12.480161     1      0.2
# 6            0.512513     1      0.2
# 7            2.806890     1      0.2
# 8            4.291655     1      0.2
