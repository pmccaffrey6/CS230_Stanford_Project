# %%
import pandas as pd
import numpy as np

import dendropy

import os

import pysam
import vamb

import glob

import pickle

# %% [markdown]
# # Purpose of this Notebook
#
# In order to test the relevant impact of tuning the beta parameter for out disentangled autoencoder, I want to set up some compelling experiments. These will consist of a small grid search methodology where we modify both the number of genomes in a simulation as well as the phylogenetic distance between those genomes. That strategy would look something like this:
#
#
#
# |     | 2   |  10 | 50  |
# |-----|-----|-----|-----|
# | 5   |     |     |     |
# | 50  |     |     |     |
# | 250 |     |     |     |
#
#
# In order do do this, I'm going to set up these simulations first by deciding how I'll collect input reference genomes of varying levels of phylogenetic similarity.

# %% [markdown]
# ## 1. Gathering Genomes and Adjusting Similarity
#
# We'll start by obtaining the complete list of bacterial genomes present in the NCBI Genome database:

# %%
# !wget ftp://ftp.ncbi.nlm.nih.gov/genomes/genbank/bacteria/assembly_summary.txt
# Out:
# --2021-03-14 00:32:06--  ftp://ftp.ncbi.nlm.nih.gov/genomes/genbank/bacteria/assembly_summary.txt
#            => ‘assembly_summary.txt’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.13, 130.14.250.12, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.13|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/genbank/bacteria ... done.
# ==> SIZE assembly_summary.txt ... 276853487
# ==> PASV ... done.    ==> RETR assembly_summary.txt ... done.
# Length: 276853487 (264M) (unauthoritative)
#
# assembly_summary.tx 100%[===================>] 264.03M  23.2MB/s    in 12s
#
# 2021-03-14 00:32:19 (21.4 MB/s) - ‘assembly_summary.txt’ saved [276853487]

# %%
all_ncbi_genomes = pd.read_csv('assembly_summary.txt', sep='\t', skiprows=1)
all_complete_genomes = all_ncbi_genomes
#all_complete_genomes = all_ncbi_genomes[all_ncbi_genomes['assembly_level']=='Complete Genome']
all_complete_genomes = all_complete_genomes[(~all_complete_genomes['organism_name'].str.contains('sp.')) & 
                                            (~all_complete_genomes['organism_name'].str.contains('endosymbiont')) & 
                                            (~all_complete_genomes['organism_name'].str.contains('candidate'))]
all_complete_genomes = all_complete_genomes[pd.notna(all_complete_genomes['excluded_from_refseq'])]

all_complete_genomes = all_complete_genomes[['# assembly_accession','wgs_master','taxid','organism_name',
                                             'infraspecific_name','ftp_path']].drop_duplicates()

all_complete_genomes = all_complete_genomes.groupby('organism_name').first().reset_index()
# Out:
# /home/pathinformatics/miniconda3/envs/vamb_env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
all_complete_genomes.head(2)
# Out:
#                             organism_name # assembly_accession  \
# 0            'Brassica napus' phytoplasma      GCA_003181115.1
# 1  'Candidatus Kapabacteria' thiocyanatum      GCA_001899175.1
#
#        wgs_master    taxid infraspecific_name  \
# 0  QGKT00000000.1   469009               None
# 1  MKVH00000000.1  1895771               None
#
#                                             ftp_path
# 0  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/003...
# 1  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/001...

# %% [markdown]
# Having this, I've also obtained a reference phylogenetic tree which we can use to group genome by differing levels of phylogenetic similarity. The particular tree I'll be using is one we obtained from the [Web Of Life (WOL)](https://biocore.github.io/wol/start) project. I read this in with dendropy and then convert this into a phylogenetic distance matrix `pdm`. This is calculated using the patristic distances between items in the tree and, thus, necessitates a pairwise calculation which can take quite a bit. Moreover, this creates a pretty big pickle file (several GB).

# %%
# with open('astral.cons.nid.e5p50.nwk', 'r') as treefile:
#     tree = dendropy.Tree.get(
#             data=treefile.read(),
#             schema="newick",
#             )
    
#     pdm = tree.phylogenetic_distance_matrix()

# %%
#with open('bacteria_pdm.pickle', 'wb') as f:
#    pickle.dump(pdm, f, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# I will then use this distance matrix to grab a collection of genomes relevant to each of our experiments. This will be a collection of genomes from 1 genus, from 5 genera, and from 10 genera. I'll first select which genera these are and then I'll create three specimens for each genera set: one with 25 genomes, one with 50 genomes, and one with 250 genomes genomes.
#
# So we start with our genera list which represent both common bacterial genera and things that are not totally unique giving us the ability to demonstrate similar vs un-similar genomes.

# %%
genus_set_1 = 'Escherichia'
genus_set_2, genus_set_3, genus_set_4, genus_set_5 = 'Vibrio', 'Bacteroides', 'Clostridium', 'Listeria'
genus_set_6, genus_set_7, genus_set_8, genus_set_9, genus_set_10 = 'Lactobacillus', 'Staphylococcus', 'Shigella', 'Pseudomonas', 'Bifidobacterium'

# %% [markdown]
# So finally, I can use these genera labels to create the actual genome lists to use for sample simulation.

# %%
for idx, genus_set in enumerate([[genus_set_1], 
                  [genus_set_1, genus_set_2, genus_set_3, genus_set_4, genus_set_5], 
                  [genus_set_1, genus_set_2, genus_set_3, genus_set_4, genus_set_5, genus_set_6, genus_set_7, genus_set_8, genus_set_9, genus_set_10]]):
    
    for num_genomes in [25, 50, 250]:
        if idx == 0:
            num_genera = 1
        else:
            num_genera = idx*5
        complexity_sim_folder = os.path.join(os.getcwd(), f"example_input_data/new_simulations/complexity_sim_{num_genera}_genera_{num_genomes}_genomes")
        if not os.path.exists(complexity_sim_folder):
            os.mkdir(complexity_sim_folder)
            os.mkdir(os.path.join(complexity_sim_folder, 'genomes'))

            for genus in genus_set:
                genus_subset = all_complete_genomes[all_complete_genomes['organism_name'].str.startswith(genus)]

                per_genus_sample_size = num_genomes/len(genus_set)
                genomes = genus_subset.sample(int(per_genus_sample_size))
                print(genus, per_genus_sample_size, genomes['ftp_path'].nunique())

                for ftp_path in genomes['ftp_path'].values:
                    genome_path = ftp_path + f"/{os.path.basename(ftp_path)}_genomic.fna.gz"
                    genome_folder = os.path.join(complexity_sim_folder, 'genomes')
                    # !wget $genome_path -P $genome_folder
# Out:
# Escherichia 2.5 2
# --2021-03-14 01:23:23--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/397/385/GCA_000397385.1_Ec13_E2F4_TOP293-4_120714/GCA_000397385.1_Ec13_E2F4_TOP293-4_120714_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000397385.1_Ec13_E2F4_TOP293-4_120714_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/000/397/385/GCA_000397385.1_Ec13_E2F4_TOP293-4_120714 ... done.
# ==> SIZE GCA_000397385.1_Ec13_E2F4_TOP293-4_120714_genomic.fna.gz ... 1626284
# ==> PASV ... done.    ==> RETR GCA_000397385.1_Ec13_E2F4_TOP293-4_120714_genomic.fna.gz ... done.
# Length: 1626284 (1.6M) (unauthoritative)
#
# GCA_000397385.1_Ec1 100%[===================>]   1.55M  3.33MB/s    in 0.5s
#
# 2021-03-14 01:23:24 (3.33 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000397385.1_Ec13_E2F4_TOP293-4_120714_genomic.fna.gz’ saved [1626284]
#
# --2021-03-14 01:23:24--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/011/855/365/GCA_011855365.1_PDT000259510.3/GCA_011855365.1_PDT000259510.3_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_011855365.1_PDT000259510.3_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/011/855/365/GCA_011855365.1_PDT000259510.3 ... done.
# ==> SIZE GCA_011855365.1_PDT000259510.3_genomic.fna.gz ... 1574940
# ==> PASV ... done.    ==> RETR GCA_011855365.1_PDT000259510.3_genomic.fna.gz ... done.
# Length: 1574940 (1.5M) (unauthoritative)
#
# GCA_011855365.1_PDT 100%[===================>]   1.50M  2.71MB/s    in 0.6s
#
# 2021-03-14 01:23:25 (2.71 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_011855365.1_PDT000259510.3_genomic.fna.gz’ saved [1574940]
#
# Vibrio 2.5 2
# --2021-03-14 01:23:26--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/001/597/655/GCA_001597655.1_ASM159765v1/GCA_001597655.1_ASM159765v1_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_001597655.1_ASM159765v1_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/001/597/655/GCA_001597655.1_ASM159765v1 ... done.
# ==> SIZE GCA_001597655.1_ASM159765v1_genomic.fna.gz ... 1399787
# ==> PASV ... done.    ==> RETR GCA_001597655.1_ASM159765v1_genomic.fna.gz ... done.
# Length: 1399787 (1.3M) (unauthoritative)
#
# GCA_001597655.1_ASM 100%[===================>]   1.33M  3.51MB/s    in 0.4s
#
# 2021-03-14 01:23:27 (3.51 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_001597655.1_ASM159765v1_genomic.fna.gz’ saved [1399787]
#
# --2021-03-14 01:23:27--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/269/765/GCA_000269765.1_ASM26976v1/GCA_000269765.1_ASM26976v1_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000269765.1_ASM26976v1_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/000/269/765/GCA_000269765.1_ASM26976v1 ... done.
# ==> SIZE GCA_000269765.1_ASM26976v1_genomic.fna.gz ... 1481534
# ==> PASV ... done.    ==> RETR GCA_000269765.1_ASM26976v1_genomic.fna.gz ... done.
# Length: 1481534 (1.4M) (unauthoritative)
#
# GCA_000269765.1_ASM 100%[===================>]   1.41M  3.66MB/s    in 0.4s
#
# 2021-03-14 01:23:28 (3.66 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000269765.1_ASM26976v1_genomic.fna.gz’ saved [1481534]
#
# Bacteroides 2.5 2
# --2021-03-14 01:23:28--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/438/035/GCA_000438035.1_MGS6/GCA_000438035.1_MGS6_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000438035.1_MGS6_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/000/438/035/GCA_000438035.1_MGS6 ... done.
# ==> SIZE GCA_000438035.1_MGS6_genomic.fna.gz ... 1151242
# ==> PASV ... done.    ==> RETR GCA_000438035.1_MGS6_genomic.fna.gz ... done.
# Length: 1151242 (1.1M) (unauthoritative)
#
# GCA_000438035.1_MGS 100%[===================>]   1.10M  2.56MB/s    in 0.4s
#
# 2021-03-14 01:23:29 (2.56 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000438035.1_MGS6_genomic.fna.gz’ saved [1151242]
#
# --2021-03-14 01:23:29--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/433/375/GCA_000433375.1_MGS32/GCA_000433375.1_MGS32_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000433375.1_MGS32_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/000/433/375/GCA_000433375.1_MGS32 ... done.
# ==> SIZE GCA_000433375.1_MGS32_genomic.fna.gz ... 1430411
# ==> PASV ... done.    ==> RETR GCA_000433375.1_MGS32_genomic.fna.gz ... done.
# Length: 1430411 (1.4M) (unauthoritative)
#
# GCA_000433375.1_MGS 100%[===================>]   1.36M  3.23MB/s    in 0.4s
#
# 2021-03-14 01:23:30 (3.23 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000433375.1_MGS32_genomic.fna.gz’ saved [1430411]
#
# Clostridium 2.5 2
# --2021-03-14 01:23:30--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/436/455/GCA_000436455.1_MGS132/GCA_000436455.1_MGS132_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000436455.1_MGS132_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/000/436/455/GCA_000436455.1_MGS132 ... done.
# ==> SIZE GCA_000436455.1_MGS132_genomic.fna.gz ... 1342123
# ==> PASV ... done.    ==> RETR GCA_000436455.1_MGS132_genomic.fna.gz ... done.
# Length: 1342123 (1.3M) (unauthoritative)
#
# GCA_000436455.1_MGS 100%[===================>]   1.28M  3.01MB/s    in 0.4s
#
# 2021-03-14 01:23:31 (3.01 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000436455.1_MGS132_genomic.fna.gz’ saved [1342123]
#
# --2021-03-14 01:23:31--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/016/902/235/GCA_016902235.1_ASM1690223v1/GCA_016902235.1_ASM1690223v1_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_016902235.1_ASM1690223v1_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/016/902/235/GCA_016902235.1_ASM1690223v1 ... done.
# ==> SIZE GCA_016902235.1_ASM1690223v1_genomic.fna.gz ... 678653
# ==> PASV ... done.    ==> RETR GCA_016902235.1_ASM1690223v1_genomic.fna.gz ... done.
# Length: 678653 (663K) (unauthoritative)
#
# GCA_016902235.1_ASM 100%[===================>] 662.75K  2.04MB/s    in 0.3s
#
# 2021-03-14 01:23:32 (2.04 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_016902235.1_ASM1690223v1_genomic.fna.gz’ saved [678653]
#
# Listeria 2.5 2
# --2021-03-14 01:23:33--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/004/710/765/GCA_004710765.1_PDT000030589.4/GCA_004710765.1_PDT000030589.4_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_004710765.1_PDT000030589.4_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/004/710/765/GCA_004710765.1_PDT000030589.4 ... done.
# ==> SIZE GCA_004710765.1_PDT000030589.4_genomic.fna.gz ... 858215
# ==> PASV ... done.    ==> RETR GCA_004710765.1_PDT000030589.4_genomic.fna.gz ... done.
# Length: 858215 (838K) (unauthoritative)
#
# GCA_004710765.1_PDT 100%[===================>] 838.10K  2.49MB/s    in 0.3s
#
# 2021-03-14 01:23:33 (2.49 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_004710765.1_PDT000030589.4_genomic.fna.gz’ saved [858215]
#
# --2021-03-14 01:23:34--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/567/965/GCA_000567965.1_ASM56796v1/GCA_000567965.1_ASM56796v1_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000567965.1_ASM56796v1_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/000/567/965/GCA_000567965.1_ASM56796v1 ... done.
# ==> SIZE GCA_000567965.1_ASM56796v1_genomic.fna.gz ... 879223
# ==> PASV ... done.    ==> RETR GCA_000567965.1_ASM56796v1_genomic.fna.gz ... done.
# Length: 879223 (859K) (unauthoritative)
#
# GCA_000567965.1_ASM 100%[===================>] 858.62K  2.39MB/s    in 0.4s
#
# 2021-03-14 01:23:35 (2.39 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000567965.1_ASM56796v1_genomic.fna.gz’ saved [879223]
#
# Lactobacillus 2.5 2
# --2021-03-14 01:23:35--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/001/311/525/GCA_001311525.1_ASM131152v1/GCA_001311525.1_ASM131152v1_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_001311525.1_ASM131152v1_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/001/311/525/GCA_001311525.1_ASM131152v1 ... done.
# ==> SIZE GCA_001311525.1_ASM131152v1_genomic.fna.gz ... 554526
# ==> PASV ... done.    ==> RETR GCA_001311525.1_ASM131152v1_genomic.fna.gz ... done.
# Length: 554526 (542K) (unauthoritative)
#
# GCA_001311525.1_ASM 100%[===================>] 541.53K  1.68MB/s    in 0.3s
#
# 2021-03-14 01:23:36 (1.68 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_001311525.1_ASM131152v1_genomic.fna.gz’ saved [554526]
#
# --2021-03-14 01:23:36--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/165/775/GCA_000165775.3_ASM16577v3/GCA_000165775.3_ASM16577v3_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000165775.3_ASM16577v3_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/000/165/775/GCA_000165775.3_ASM16577v3 ... done.
# ==> SIZE GCA_000165775.3_ASM16577v3_genomic.fna.gz ... 623427
# ==> PASV ... done.    ==> RETR GCA_000165775.3_ASM16577v3_genomic.fna.gz ... done.
# Length: 623427 (609K) (unauthoritative)
#
# GCA_000165775.3_ASM 100%[===================>] 608.82K  1.82MB/s    in 0.3s
#
# 2021-03-14 01:23:37 (1.82 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000165775.3_ASM16577v3_genomic.fna.gz’ saved [623427]
#
# Staphylococcus 2.5 2
# --2021-03-14 01:23:37--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/002/902/575/GCA_002902575.1_ASM290257v1/GCA_002902575.1_ASM290257v1_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_002902575.1_ASM290257v1_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/002/902/575/GCA_002902575.1_ASM290257v1 ... done.
# ==> SIZE GCA_002902575.1_ASM290257v1_genomic.fna.gz ... 704198
# ==> PASV ... done.    ==> RETR GCA_002902575.1_ASM290257v1_genomic.fna.gz ... done.
# Length: 704198 (688K) (unauthoritative)
#
# GCA_002902575.1_ASM 100%[===================>] 687.69K  1.93MB/s    in 0.3s
#
# 2021-03-14 01:23:38 (1.93 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_002902575.1_ASM290257v1_genomic.fna.gz’ saved [704198]
#
# --2021-03-14 01:23:38--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/555/645/GCA_000555645.1_Stap_aure_M0406_V1/GCA_000555645.1_Stap_aure_M0406_V1_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000555645.1_Stap_aure_M0406_V1_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/000/555/645/GCA_000555645.1_Stap_aure_M0406_V1 ... done.
# ==> SIZE GCA_000555645.1_Stap_aure_M0406_V1_genomic.fna.gz ... 919251
# ==> PASV ... done.    ==> RETR GCA_000555645.1_Stap_aure_M0406_V1_genomic.fna.gz ... done.
# Length: 919251 (898K) (unauthoritative)
#
# GCA_000555645.1_Sta 100%[===================>] 897.71K  2.20MB/s    in 0.4s
#
# 2021-03-14 01:23:39 (2.20 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000555645.1_Stap_aure_M0406_V1_genomic.fna.gz’ saved [919251]
#
# Shigella 2.5 2
# --2021-03-14 01:23:39--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/268/085/GCA_000268085.1_ASM26808v1/GCA_000268085.1_ASM26808v1_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000268085.1_ASM26808v1_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/000/268/085/GCA_000268085.1_ASM26808v1 ... done.
# ==> SIZE GCA_000268085.1_ASM26808v1_genomic.fna.gz ... 1415441
# ==> PASV ... done.    ==> RETR GCA_000268085.1_ASM26808v1_genomic.fna.gz ... done.
# Length: 1415441 (1.3M) (unauthoritative)
#
# GCA_000268085.1_ASM 100%[===================>]   1.35M  3.04MB/s    in 0.4s
#
# 2021-03-14 01:23:40 (3.04 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000268085.1_ASM26808v1_genomic.fna.gz’ saved [1415441]
#
# --2021-03-14 01:23:41--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/268/165/GCA_000268165.1_ASM26816v1/GCA_000268165.1_ASM26816v1_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000268165.1_ASM26816v1_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/000/268/165/GCA_000268165.1_ASM26816v1 ... done.
# ==> SIZE GCA_000268165.1_ASM26816v1_genomic.fna.gz ... 1325670
# ==> PASV ... done.    ==> RETR GCA_000268165.1_ASM26816v1_genomic.fna.gz ... done.
# Length: 1325670 (1.3M) (unauthoritative)
#
# GCA_000268165.1_ASM 100%[===================>]   1.26M  2.67MB/s    in 0.5s
#
# 2021-03-14 01:23:42 (2.67 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000268165.1_ASM26816v1_genomic.fna.gz’ saved [1325670]
#
# Pseudomonas 2.5 2
# --2021-03-14 01:23:42--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/953/455/GCA_000953455.1_Ppseudo_Pac/GCA_000953455.1_Ppseudo_Pac_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000953455.1_Ppseudo_Pac_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/000/953/455/GCA_000953455.1_Ppseudo_Pac ... done.
# ==> SIZE GCA_000953455.1_Ppseudo_Pac_genomic.fna.gz ... 1366143
# ==> PASV ... done.    ==> RETR GCA_000953455.1_Ppseudo_Pac_genomic.fna.gz ... done.
# Length: 1366143 (1.3M) (unauthoritative)
#
# GCA_000953455.1_Pps 100%[===================>]   1.30M  2.99MB/s    in 0.4s
#
# 2021-03-14 01:23:43 (2.99 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000953455.1_Ppseudo_Pac_genomic.fna.gz’ saved [1366143]
#
# --2021-03-14 01:23:43--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/009/911/885/GCA_009911885.1_ASM991188v1/GCA_009911885.1_ASM991188v1_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_009911885.1_ASM991188v1_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/009/911/885/GCA_009911885.1_ASM991188v1 ... done.
# ==> SIZE GCA_009911885.1_ASM991188v1_genomic.fna.gz ... 104893
# ==> PASV ... done.    ==> RETR GCA_009911885.1_ASM991188v1_genomic.fna.gz ... done.
# Length: 104893 (102K) (unauthoritative)
#
# GCA_009911885.1_ASM 100%[===================>] 102.43K  --.-KB/s    in 0.1s
#
# 2021-03-14 01:23:44 (742 KB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_009911885.1_ASM991188v1_genomic.fna.gz’ saved [104893]
#
# Bifidobacterium 2.5 2
# --2021-03-14 01:23:44--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/002/311/215/GCA_002311215.1_ASM231121v1/GCA_002311215.1_ASM231121v1_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_002311215.1_ASM231121v1_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/002/311/215/GCA_002311215.1_ASM231121v1 ... done.
# ==> SIZE GCA_002311215.1_ASM231121v1_genomic.fna.gz ... 523383
# ==> PASV ... done.    ==> RETR GCA_002311215.1_ASM231121v1_genomic.fna.gz ... done.
# Length: 523383 (511K) (unauthoritative)
#
# GCA_002311215.1_ASM 100%[===================>] 511.12K  1.57MB/s    in 0.3s
#
# 2021-03-14 01:23:45 (1.57 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_002311215.1_ASM231121v1_genomic.fna.gz’ saved [523383]
#
# --2021-03-14 01:23:45--  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/435/235/GCA_000435235.1_MGS119/GCA_000435235.1_MGS119_genomic.fna.gz
#            => ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000435235.1_MGS119_genomic.fna.gz’
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /genomes/all/GCA/000/435/235/GCA_000435235.1_MGS119 ... done.
# ==> SIZE GCA_000435235.1_MGS119_genomic.fna.gz ... 570236
# ==> PASV ... done.    ==> RETR GCA_000435235.1_MGS119_genomic.fna.gz ... done.
# Length: 570236 (557K) (unauthoritative)
#
# GCA_000435235.1_MGS 100%[===================>] 556.87K  1.74MB/s    in 0.3s
#
# 2021-03-14 01:23:46 (1.74 MB/s) - ‘/home/pathinformatics/jupyter_projects/vamb/stanford_cs230_project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/genomes/GCA_000435235.1_MGS119_genomic.fna.gz’ saved [570236]

# %% [markdown]
# I'll also just verify that we got the right number of genomes downloaded and the right number of genera represented in each of these experiments.

# %%
for idx, genus_set in enumerate([[genus_set_1], 
                  [genus_set_1, genus_set_2, genus_set_3, genus_set_4, genus_set_5], 
                  [genus_set_1, genus_set_2, genus_set_3, genus_set_4, genus_set_5, genus_set_6, genus_set_7, genus_set_8, genus_set_9, genus_set_10]]):
    
    for num_genomes in [25, 50, 250]:
        param_thing = f"{len(genus_set)}_genera_{num_genomes}_genomes"
        print(param_thing)

        print(len(glob.glob(f"example_input_data/new_simulations/complexity_sim_{param_thing}/genomes/*")) )

        targets = ['_'.join(i.split('/')[-1].strip('.fna.gz').split('_')[:2]) for 
                   i in glob.glob(f"example_input_data/new_simulations/complexity_sim_{param_thing}/genomes/*")]
        
        assert len(targets) == num_genomes

        all_complete_genomes[all_complete_genomes['# assembly_accession'].isin(targets)]['organism_name'].str.contains(genus_set_1).all()
        
        assert len(set(genus_set).intersection(
            set([i.split(' ')[0] for 
                 i in all_complete_genomes[all_complete_genomes['# assembly_accession'].isin(targets)]['organism_name'].values]))) == len(genus_set)
# Out:
# 1_genera_25_genomes
# 25
# 1_genera_50_genomes
# 50
# 1_genera_250_genomes
# 250
# 5_genera_25_genomes
# 25
# 5_genera_50_genomes
# 50
# 5_genera_250_genomes
# 250
# 10_genera_25_genomes
# 25
# 10_genera_50_genomes
# 50
# 10_genera_250_genomes
# 250

# %% [markdown]
# We also have to set up the genomes and metadata tsv files for simulation

# %%
for complexity_experiment in glob.glob('example_input_data/new_simulations/complexity*'):
    experiment_name = os.path.basename(complexity_experiment)
    
    for fna_file in glob.glob(f"example_input_data/new_simulations/{experiment_name}/genomes/*.gz"):
        # !gzip -d $fna_file
    
    genomes = glob.glob(os.path.join(complexity_experiment,'genomes','*'))
    genomes_mod = [os.path.join('/input/genomes',os.path.basename(i)) for i in genomes]
    
    df = pd.DataFrame(genomes_mod)
    df['genome_ID'] = [ f"Genome{float(i+1)}" for i in range(len(df))]
    df = df[['genome_ID',0]]
    df.to_csv(os.path.join(complexity_experiment,'genome_to_id.tsv'), sep='\t', header=False, index=False)
    
    metadata_df = df
    metadata_df['novelty_category'] = 'known_strain'
    metadata_df['NCBI_ID'] = metadata_df[0].str.split('/', expand=True)[3].str.split('_', expand=True)[[0,1]].agg('_'.join, axis=1)
    
    metadata_df = metadata_df.merge(all_complete_genomes, left_on='NCBI_ID', 
                      right_on='# assembly_accession', 
                      how='inner')
    metadata_df['NCBI_ID'] = metadata_df['ftp_path'].str.split('/', expand=True)[9].str.strip('.fna.gz')
    
    metadata_df = metadata_df[['genome_ID','NCBI_ID','taxid','novelty_category']].rename(columns={'NCBI_ID':'OTU','taxid':'NCBI_ID',})
    metadata_df['NCBI_ID'] = 2
    
    metadata_df.to_csv(os.path.join(complexity_experiment,'metadata.tsv'), sep='\t', index=False)

# %% [markdown]
# And now I can run this to create the simulated samples

# %%
experiments = [os.path.basename(i) for i in glob.glob('example_input_data/new_simulations/complexity*')]

for experiment in experiments:
    if len(glob.glob(os.path.join('example_input_data/new_simulations',experiment,'*','reads','anonymous*'))) == 0:
        print('simulating',experiment)
        
        input_folder = os.path.join(os.getcwd(), f"example_input_data/new_simulations/{experiment}")
        output_folder = os.path.join(os.getcwd(), f"example_input_data/new_simulations/{experiment}")

        input_directory = f"{input_folder}:/input:rw"
        output_directory = f"{output_folder}:/output:rw"

        # !echo awhf98aq | sudo -S docker run --rm -v $input_directory -v $output_directory  \
            cami/camisim:latest  metagenomesimulation.py /input/mini_config.ini
# Out:
# simulating complexity_sim_1_genera_250_genomes
# Password:2021-03-13 09:38:14 INFO: [MetagenomeSimulationPipeline] Metagenome simulation starting
# 2021-03-13 09:38:14 INFO: [MetagenomeSimulationPipeline] Validating Genomes
# 2021-03-13 09:38:14 INFO: [MetadataReader] Reading file: '/input/genome_to_id.tsv'
# 2021-03-13 09:43:56 INFO: [MetagenomeSimulationPipeline] Design Communities
# 2021-03-13 09:43:56 INFO: [CommunityDesign] Drawing strains.
# 2021-03-13 09:43:56 INFO: [MetadataReader 82380310288] Reading file: '/input/metadata.tsv'
# 2021-03-13 09:43:56 INFO: [MetadataReader 28782960663] Reading file: '/input/genome_to_id.tsv'
# 2021-03-13 09:43:56 INFO: [CommunityDesign] Validating raw sequence files!
# 2021-03-13 09:44:34 INFO: [NcbiTaxonomy] Building taxonomy tree...
# 2021-03-13 09:44:34 INFO: [NcbiTaxonomy] Reading 'nodes' file:	'/tmp/tmpHCLv64/NCBI/nodes.dmp'
# 2021-03-13 09:44:50 INFO: [NcbiTaxonomy] Reading 'names' file:	'/tmp/tmpHCLv64/NCBI/names.dmp'
# 2021-03-13 09:44:53 INFO: [NcbiTaxonomy] Reading 'merged' file:	'/tmp/tmpHCLv64/NCBI/merged.dmp'
# 2021-03-13 09:44:53 INFO: [NcbiTaxonomy] Done (19.0s)
# 2021-03-13 09:44:53 INFO: [MetagenomeSimulationPipeline] Move Genomes
# 2021-03-13 09:45:00 INFO: [MetagenomeSimulationPipeline] Read simulation
# 2021-03-13 09:45:00 INFO: [GenomePreparation 82430254076] Using 'mbarc' error profile.
# 2021-03-13 09:45:00 INFO: [GenomePreparation 82430254076] Reading distribution file
# 2021-03-13 09:45:00 INFO: [GenomePreparation 82430254076] Reading genome location file
# 2021-03-13 09:45:11 INFO: [GenomePreparation 82430254076] Genome 'Genome119.0' has sequences below minimum, creating filtered copy.
# 2021-03-13 09:45:17 INFO: [GenomePreparation 82430254076] Genome 'Genome28.0' has sequences below minimum, creating filtered copy.
# 2021-03-13 09:45:24 INFO: [GenomePreparation 82430254076] Genome 'Genome124.0' has sequences below minimum, creating filtered copy.
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads using ReadSimulationArtIllumina readsimulator...
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome33.0: '/output/source_genomes/GCA_002741215.1_ASM274121v1_genomic.fna'
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome201.0: '/output/source_genomes/GCA_013049715.1_PDT000290410.4_genomic.fna'
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome15.0: '/output/source_genomes/GCA_016954795.1_PDT000971232.1_genomic.fna'
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome188.0: '/output/source_genomes/GCA_011855365.1_PDT000259510.3_genomic.fna'
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome12.0: '/output/source_genomes/GCA_012246945.1_PDT000290529.2_genomic.fna'
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome216.0: '/output/source_genomes/GCA_000176655.2_ASM17665v2_genomic.fna'
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome77.0: '/output/source_genomes/GCA_013076425.1_PDT000186183.4_genomic.fna'
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome119.0: '/tmp/tmpubQJEs/tmpIIljmM'
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome189.0: '/output/source_genomes/GCA_902729235.2_easoj011_ecoli_genomic_umi_ont_r10_g324hac_genomic.fna'
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome28.0: '/tmp/tmpubQJEs/tmpIgf6wJ'
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome207.0: '/output/source_genomes/GCA_012246885.1_PDT000290429.2_genomic.fna'
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome219.0: '/output/source_genomes/GCA_009002655.1_ASM900265v1_genomic.fna'
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome104.0: '/output/source_genomes/GCA_000249835.2_ASM24983v2_genomic.fna'
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome74.0: '/output/source_genomes/GCA_012247285.1_PDT000290389.2_genomic.fna'
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome124.0: '/tmp/tmpubQJEs/tmpQCl6xZ'
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome231.0: '/output/source_genomes/GCA_016954935.1_PDT000971224.1_genomic.fna'
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome52.0: '/output/source_genomes/GCA_016956075.1_PDT000971141.1_genomic.fna'
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome205.0: '/output/source_genomes/GCA_016955215.1_PDT000971186.1_genomic.fna'
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome2.0: '/output/source_genomes/GCA_016956155.1_PDT000971137.1_genomic.fna'
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome93.0: '/output/source_genomes/GCA_016956115.1_PDT000971138.1_genomic.fna'
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome140.0: '/output/source_genomes/GCA_012247505.1_PDT000290375.2_genomic.fna'
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome23.0: '/output/source_genomes/GCA_016955775.1_PDT000971156.1_genomic.fna'
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome171.0: '/output/source_genomes/GCA_000601175.1_ASM60117v1_genomic.fna'
# 2021-03-13 09:45:37 INFO: [GenomePreparation 82430254076] Simulating reads from Genome227.0: '/output/source_genomes/GCA_003382705.1_ASM338270v1_genomic.fna'
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.15
#
# The random seed for the run: 1594031057
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0510977X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome119.01.fq
# 	 the 2nd reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome119.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome119.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.18
#
# The random seed for the run: 50971974
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0485703X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome77.01.fq
# 	 the 2nd reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome77.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome77.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.15
#
# The random seed for the run: 1044513605
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0196252X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome216.01.fq
# 	 the 2nd reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome216.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome216.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.26
#
# The random seed for the run: 507207848
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0740688X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome33.01.fq
# 	 the 2nd reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome33.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome33.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.27
#
# The random seed for the run: 393287511
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.105018X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome12.01.fq
# 	 the 2nd reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome12.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome12.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.14
#
# The random seed for the run: 1414977469
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0444804X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome207.01.fq
# 	 the 2nd reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome207.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome207.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.14
#
# The random seed for the run: 1937464905
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0156039X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome104.01.fq
# 	 the 2nd reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome104.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome104.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.13
#
# The random seed for the run: 411957455
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0247527X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome74.01.fq
# 	 the 2nd reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome74.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome74.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.33
#
# The random seed for the run: 2130432890
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.167137X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome219.01.fq
# 	 the 2nd reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome219.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome219.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.99
#
# The random seed for the run: 1093218188
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.639141X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome15.01.fq
# 	 the 2nd reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome15.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome15.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.7
#
# The random seed for the run: 1027999508
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.459421X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome28.01.fq
# 	 the 2nd reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome28.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome28.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.21
#
# The random seed for the run: 1669488642
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0755899X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome205.01.fq
# 	 the 2nd reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome205.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome205.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.14
#
# The random seed for the run: 263232151
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.0350771X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome93.01.fq
# 	 the 2nd reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome93.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome93.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 1.81
#
# The random seed for the run: 963059643
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            1.23057X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome188.01.fq
# 	 the 2nd reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome188.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome188.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.99
#
# The random seed for the run: 460212766
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.66195X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome231.01.fq
# 	 the 2nd reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome231.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome231.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.7
#
# The random seed for the run: 1097061061
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.44101X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome52.01.fq
# 	 the 2nd reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome52.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome52.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.12
#
# The random seed for the run: 215267604
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.010146X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome140.01.fq
# 	 the 2nd reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome140.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome140.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 2.06
#
# The random seed for the run: 941171800
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.375408X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome189.01.fq
# 	 the 2nd reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome189.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome189.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.47
#
# The random seed for the run: 370300383
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.304572X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome23.01.fq
# 	 the 2nd reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome23.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome23.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.55
#
# The random seed for the run: 642284040
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.400652X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome227.01.fq
# 	 the 2nd reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome227.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome227.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 2.46
#
# The random seed for the run: 1795828534
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            1.84548X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome201.01.fq
# 	 the 2nd reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome201.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome201.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 2.2
#
# The random seed for the run: 670345468
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            1.70513X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome124.01.fq
# 	 the 2nd reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome124.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome124.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 2.08
#
# The random seed for the run: 2029296162
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            1.79664X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome2.01.fq
# 	 the 2nd reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome2.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome2.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 7.63
#
# The random seed for the run: 1940362427
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            7.50844X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome171.01.fq
# 	 the 2nd reads: /tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome171.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpubQJEs/2021.03.13_09.38.14_sample_0/reads/Genome171.0.sam
#
# 2021-03-13 09:45:48 INFO: [GenomePreparation 82430254076] Simulating reads finished
# 2021-03-13 09:46:00 INFO: [MetagenomeSimulationPipeline] Generate gold standard assembly
# 2021-03-13 09:46:00 INFO: [MetadataReader 87205974322] Reading file: '/output/internal/genome_locations.tsv'
# 2021-03-13 09:46:56 INFO: [MetagenomeSimulationPipeline] Generate pooled strains gold standard assembly
# 2021-03-13 09:46:56 INFO: [MetadataReader 114087710] Reading file: '/output/internal/genome_locations.tsv'
# 2021-03-13 09:46:56 INFO: [MetagenomeSimulationPipeline] Samples used for pooled assembly: '2021.03.13_09.38.14_sample_0'
# 2021-03-13 09:46:56 INFO: [Validator 10795378910] Creating pooled gold standard
# 2021-03-13 09:46:56 INFO: [Validator 10795378910] Merging bam files.
# 2021-03-13 09:46:56 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_09.38.14_sample_0/bam/Genome15.0.bam'
# 2021-03-13 09:46:56 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_09.38.14_sample_0/bam/Genome119.0.bam'
# 2021-03-13 09:46:56 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_09.38.14_sample_0/bam/Genome33.0.bam'
# 2021-03-13 09:46:56 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_09.38.14_sample_0/bam/Genome188.0.bam'
# 2021-03-13 09:46:56 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_09.38.14_sample_0/bam/Genome12.0.bam'
# 2021-03-13 09:46:56 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_09.38.14_sample_0/bam/Genome216.0.bam'
# 2021-03-13 09:46:56 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_09.38.14_sample_0/bam/Genome77.0.bam'
# 2021-03-13 09:46:56 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_09.38.14_sample_0/bam/Genome201.0.bam'
# 2021-03-13 09:46:56 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_09.38.14_sample_0/bam/Genome189.0.bam'
# 2021-03-13 09:46:56 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_09.38.14_sample_0/bam/Genome28.0.bam'
# 2021-03-13 09:46:56 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_09.38.14_sample_0/bam/Genome207.0.bam'
# 2021-03-13 09:46:56 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_09.38.14_sample_0/bam/Genome219.0.bam'
# 2021-03-13 09:46:56 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_09.38.14_sample_0/bam/Genome104.0.bam'
# 2021-03-13 09:46:56 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_09.38.14_sample_0/bam/Genome74.0.bam'
# 2021-03-13 09:46:56 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_09.38.14_sample_0/bam/Genome124.0.bam'
# 2021-03-13 09:46:56 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_09.38.14_sample_0/bam/Genome231.0.bam'
# 2021-03-13 09:46:56 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_09.38.14_sample_0/bam/Genome52.0.bam'
# 2021-03-13 09:46:56 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_09.38.14_sample_0/bam/Genome205.0.bam'
# 2021-03-13 09:46:56 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_09.38.14_sample_0/bam/Genome2.0.bam'
# 2021-03-13 09:46:56 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_09.38.14_sample_0/bam/Genome93.0.bam'
# 2021-03-13 09:46:56 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_09.38.14_sample_0/bam/Genome140.0.bam'
# 2021-03-13 09:46:56 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_09.38.14_sample_0/bam/Genome23.0.bam'
# 2021-03-13 09:46:56 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_09.38.14_sample_0/bam/Genome171.0.bam'
# 2021-03-13 09:46:56 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_09.38.14_sample_0/bam/Genome227.0.bam'
# 2021-03-13 09:47:51 INFO: [MetagenomeSimulationPipeline] Anonymize Data
# 2021-03-13 09:47:51 INFO: [FastaAnonymizer] Interweave shuffle and anonymize
# 2021-03-13 09:49:22 INFO: [MetadataReader 4631107874] Reading file: '/output/internal/genome_locations.tsv'
# 2021-03-13 09:49:24 INFO: [MetadataReader 14300761082] Reading file: '/output/internal/meta_data.tsv'
# 2021-03-13 09:49:24 INFO: [MetadataReader 87652392539] Reading file: '/tmp/tmpubQJEs/tmp8uuFRR'
# 2021-03-13 09:49:28 INFO: [FastaAnonymizer 66694448886] Shuffle and anonymize '/tmp/tmpubQJEs/tmpSVl6Tl'
# 2021-03-13 09:49:39 INFO: [MetadataReader 4079751341] Reading file: '/output/internal/genome_locations.tsv'
# 2021-03-13 09:49:41 INFO: [MetadataReader 84063950941] Reading file: '/output/internal/meta_data.tsv'
# 2021-03-13 09:49:41 INFO: [MetadataReader 48704713275] Reading file: '/tmp/tmpubQJEs/read_start_positionszJeg7h'
# 2021-03-13 09:49:43 INFO: [MetadataReader 43119039112] Reading file: '/tmp/tmpubQJEs/tmpKfC1AT'
# 2021-03-13 09:50:07 INFO: [FastaAnonymizer 64368966291] Shuffle and anonymize '/tmp/tmpubQJEs/tmppKsGmI'
# 2021-03-13 09:50:17 INFO: [MetadataReader 78717221707] Reading file: '/output/internal/genome_locations.tsv'
# 2021-03-13 09:50:19 INFO: [MetadataReader 89765374142] Reading file: '/output/internal/meta_data.tsv'
# 2021-03-13 09:50:19 INFO: [MetadataReader 98541404663] Reading file: '/tmp/tmpubQJEs/read_start_positions6b0aIB'
# 2021-03-13 09:50:22 INFO: [MetadataReader 99062647065] Reading file: '/tmp/tmpubQJEs/tmpL0Aivy'
# 2021-03-13 09:50:46 INFO: [MetagenomeSimulationPipeline] Compress Data
# 2021-03-13 09:50:46 INFO: [Compress 27146481853] Compressing 'tmpGYjKKm'
# 2021-03-13 09:50:46 INFO: [Compress 5059325991] Compressing 'anonymous_gsa_mapping_rCBXz'
# 2021-03-13 09:50:46 INFO: [Compress 3713287912] Compressing 'tmpksrBcK'
# 2021-03-13 09:50:46 INFO: [Compress 28761400014] Compressing 'anonymous_gs_mappingxrPQ0j'
# 2021-03-13 09:50:46 INFO: [Compress 57512415149] Compressing 'tmpoXw22Q'
# 2021-03-13 09:50:46 INFO: [Compress 74155927945] Compressing 'anonymous_gsa_pooled_mappingBXHB3i'
# 2021-03-13 09:50:47 INFO: [Compress 5059325991] Done compressing 'gsa_mapping.tsv.gz' in 0:00:01s.
# 2021-03-13 09:50:47 INFO: [Compress 74155927945] Done compressing 'gsa_pooled_mapping.tsv.gz' in 0:00:01s.
# 2021-03-13 09:50:49 INFO: [Compress 28761400014] Done compressing 'reads_mapping.tsv.gz' in 0:00:03s.
# 2021-03-13 09:50:50 INFO: [Compress 27146481853] Done compressing 'anonymous_gsa_pooled.fasta.gz' in 0:00:04s.
# 2021-03-13 09:50:50 INFO: [Compress 57512415149] Done compressing 'anonymous_gsa.fasta.gz' in 0:00:04s.
# 2021-03-13 09:51:02 INFO: [Compress 3713287912] Done compressing 'anonymous_reads.fq.gz' in 0:00:16s.
# 2021-03-13 09:51:02 INFO: [MetagenomeSimulationPipeline] Metagenome simulation finished
# simulating complexity_sim_5_genera_25_genomes
# Password:2021-03-13 09:51:05 INFO: [MetagenomeSimulationPipeline] Metagenome simulation starting
# 2021-03-13 09:51:05 INFO: [MetagenomeSimulationPipeline] Validating Genomes
# 2021-03-13 09:51:05 INFO: [MetadataReader] Reading file: '/input/genome_to_id.tsv'
# 2021-03-13 09:51:33 INFO: [MetagenomeSimulationPipeline] Design Communities
# 2021-03-13 09:51:33 INFO: [CommunityDesign] Drawing strains.
# 2021-03-13 09:51:33 INFO: [MetadataReader 82380310288] Reading file: '/input/metadata.tsv'
# 2021-03-13 09:51:33 INFO: [MetadataReader 25595780401] Reading file: '/input/genome_to_id.tsv'
# 2021-03-13 09:51:33 INFO: [CommunityDesign] Validating raw sequence files!
# 2021-03-13 09:52:01 INFO: [NcbiTaxonomy] Building taxonomy tree...
# 2021-03-13 09:52:01 INFO: [NcbiTaxonomy] Reading 'nodes' file:	'/tmp/tmpxWHBq3/NCBI/nodes.dmp'
# 2021-03-13 09:52:17 INFO: [NcbiTaxonomy] Reading 'names' file:	'/tmp/tmpxWHBq3/NCBI/names.dmp'
# 2021-03-13 09:52:20 INFO: [NcbiTaxonomy] Reading 'merged' file:	'/tmp/tmpxWHBq3/NCBI/merged.dmp'
# 2021-03-13 09:52:20 INFO: [NcbiTaxonomy] Done (19.0s)
# 2021-03-13 09:52:20 INFO: [MetagenomeSimulationPipeline] Move Genomes
# 2021-03-13 09:52:24 INFO: [MetagenomeSimulationPipeline] Read simulation
# 2021-03-13 09:52:24 INFO: [GenomePreparation 70514612869] Using 'mbarc' error profile.
# 2021-03-13 09:52:24 INFO: [GenomePreparation 70514612869] Reading distribution file
# 2021-03-13 09:52:24 INFO: [GenomePreparation 70514612869] Reading genome location file
# 2021-03-13 09:52:46 INFO: [GenomePreparation 70514612869] Genome 'Genome7.0' has sequences below minimum, creating filtered copy.
# 2021-03-13 09:52:48 INFO: [GenomePreparation 70514612869] Genome 'Genome13.0' has sequences below minimum, creating filtered copy.
# 2021-03-13 09:52:51 INFO: [GenomePreparation 70514612869] Genome 'Genome8.0' has sequences below minimum, creating filtered copy.
# 2021-03-13 09:52:52 INFO: [GenomePreparation 70514612869] Simulating reads using ReadSimulationArtIllumina readsimulator...
# 2021-03-13 09:52:52 INFO: [GenomePreparation 70514612869] Simulating reads from Genome15.0: '/output/source_genomes/GCA_000436655.1_MGS160_genomic.fna'
# 2021-03-13 09:52:52 INFO: [GenomePreparation 70514612869] Simulating reads from Genome14.0: '/output/source_genomes/GCA_003318175.1_ASM331817v1_genomic.fna'
# 2021-03-13 09:52:52 INFO: [GenomePreparation 70514612869] Simulating reads from Genome11.0: '/output/source_genomes/GCA_013014285.1_PDT000430776.1_genomic.fna'
# 2021-03-13 09:52:52 INFO: [GenomePreparation 70514612869] Simulating reads from Genome24.0: '/output/source_genomes/GCA_000436135.1_MGS222_genomic.fna'
# 2021-03-13 09:52:52 INFO: [GenomePreparation 70514612869] Simulating reads from Genome25.0: '/output/source_genomes/GCA_000705295.1_V.cholerae_O1_biovar_El_Tor_str._M-1293_genomic.fna'
# 2021-03-13 09:52:52 INFO: [GenomePreparation 70514612869] Simulating reads from Genome18.0: '/output/source_genomes/GCA_004710365.1_PDT000000906.5_genomic.fna'
# 2021-03-13 09:52:52 INFO: [GenomePreparation 70514612869] Simulating reads from Genome17.0: '/output/source_genomes/GCA_004710385.1_PDT000000905.5_genomic.fna'
# 2021-03-13 09:52:52 INFO: [GenomePreparation 70514612869] Simulating reads from Genome16.0: '/output/source_genomes/GCA_013407315.1_ASM1340731v1_genomic.fna'
# 2021-03-13 09:52:52 INFO: [GenomePreparation 70514612869] Simulating reads from Genome19.0: '/output/source_genomes/GCA_016955495.1_PDT000971171.1_genomic.fna'
# 2021-03-13 09:52:52 INFO: [GenomePreparation 70514612869] Simulating reads from Genome2.0: '/output/source_genomes/GCA_000431175.1_MGS59_genomic.fna'
# ...
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 2.28
#
# The random seed for the run: 50971974
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            3.42173X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpnEsCS5/2021.03.13_10.42.02_sample_0/reads/Genome75.01.fq
# 	 the 2nd reads: /tmp/tmpnEsCS5/2021.03.13_10.42.02_sample_0/reads/Genome75.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpnEsCS5/2021.03.13_10.42.02_sample_0/reads/Genome75.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 0.63
#
# The random seed for the run: 215267604
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            1.26069X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpnEsCS5/2021.03.13_10.42.02_sample_0/reads/Genome240.01.fq
# 	 the 2nd reads: /tmp/tmpnEsCS5/2021.03.13_10.42.02_sample_0/reads/Genome240.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpnEsCS5/2021.03.13_10.42.02_sample_0/reads/Genome240.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 3.58
#
# The random seed for the run: 1594031057
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            2.34364X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpnEsCS5/2021.03.13_10.42.02_sample_0/reads/Genome74.01.fq
# 	 the 2nd reads: /tmp/tmpnEsCS5/2021.03.13_10.42.02_sample_0/reads/Genome74.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpnEsCS5/2021.03.13_10.42.02_sample_0/reads/Genome74.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 1.13
#
# The random seed for the run: 370300383
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            0.839908X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpnEsCS5/2021.03.13_10.42.02_sample_0/reads/Genome99.01.fq
# 	 the 2nd reads: /tmp/tmpnEsCS5/2021.03.13_10.42.02_sample_0/reads/Genome99.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpnEsCS5/2021.03.13_10.42.02_sample_0/reads/Genome99.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 3.41
#
# The random seed for the run: 1414977469
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            3.51474X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpnEsCS5/2021.03.13_10.42.02_sample_0/reads/Genome191.01.fq
# 	 the 2nd reads: /tmp/tmpnEsCS5/2021.03.13_10.42.02_sample_0/reads/Genome191.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpnEsCS5/2021.03.13_10.42.02_sample_0/reads/Genome191.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 4.43
#
# The random seed for the run: 1093218188
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            14.2999X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpnEsCS5/2021.03.13_10.42.02_sample_0/reads/Genome59.01.fq
# 	 the 2nd reads: /tmp/tmpnEsCS5/2021.03.13_10.42.02_sample_0/reads/Genome59.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpnEsCS5/2021.03.13_10.42.02_sample_0/reads/Genome59.0.sam
#
# =======================================ART======================================
#                             ART_Illumina (2008-2015)
#                             Q Version 2.3.6 (Mar 9, 2015)
#                      Contact: Weichun Huang at whduke@gmail.com
# ================================================================================
#
#                           Paired-end sequencing simulation
#
# Total CPU time used: 1.51
#
# The random seed for the run: 642284040
#
# Parameters used during run
# 	Read Length:	150
# 	Genome masking 'N' cutoff frequency: 	1 in 150
# 	Fold Coverage:            1.21725X
# 	Mean Fragment Length:     270
# 	Standard Deviation:       27
# 	Profile Type:             Combined
# 	ID Tag:
#
# Quality Profile(s)
# 	First Read:   /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R1.txt (user's profile)
# 	Second Read:  /usr/local/bin/tools/art_illumina-2.3.6/profiles/ART_MBARC-26_HiSeq_R2.txt (user's profile)
#
# Output files
#
#   FASTQ Sequence Files:
# 	 the 1st reads: /tmp/tmpnEsCS5/2021.03.13_10.42.02_sample_0/reads/Genome187.01.fq
# 	 the 2nd reads: /tmp/tmpnEsCS5/2021.03.13_10.42.02_sample_0/reads/Genome187.02.fq
#
#   SAM Alignment File:
# 	/tmp/tmpnEsCS5/2021.03.13_10.42.02_sample_0/reads/Genome187.0.sam
#
# 2021-03-13 10:47:49 INFO: [GenomePreparation 82430254076] Simulating reads finished
# 2021-03-13 10:47:58 INFO: [MetagenomeSimulationPipeline] Generate gold standard assembly
# 2021-03-13 10:47:58 INFO: [MetadataReader 87205974322] Reading file: '/output/internal/genome_locations.tsv'
# 2021-03-13 10:48:47 INFO: [MetagenomeSimulationPipeline] Generate pooled strains gold standard assembly
# 2021-03-13 10:48:47 INFO: [MetadataReader 114087710] Reading file: '/output/internal/genome_locations.tsv'
# 2021-03-13 10:48:47 INFO: [MetagenomeSimulationPipeline] Samples used for pooled assembly: '2021.03.13_10.42.02_sample_0'
# 2021-03-13 10:48:47 INFO: [Validator 10795378910] Creating pooled gold standard
# 2021-03-13 10:48:47 INFO: [Validator 10795378910] Merging bam files.
# 2021-03-13 10:48:47 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_10.42.02_sample_0/bam/Genome33.0.bam'
# 2021-03-13 10:48:47 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_10.42.02_sample_0/bam/Genome128.0.bam'
# 2021-03-13 10:48:48 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_10.42.02_sample_0/bam/Genome59.0.bam'
# 2021-03-13 10:48:48 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_10.42.02_sample_0/bam/Genome103.0.bam'
# 2021-03-13 10:48:48 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_10.42.02_sample_0/bam/Genome150.0.bam'
# 2021-03-13 10:48:48 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_10.42.02_sample_0/bam/Genome137.0.bam'
# 2021-03-13 10:48:48 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_10.42.02_sample_0/bam/Genome75.0.bam'
# 2021-03-13 10:48:48 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_10.42.02_sample_0/bam/Genome74.0.bam'
# 2021-03-13 10:48:48 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_10.42.02_sample_0/bam/Genome149.0.bam'
# 2021-03-13 10:48:48 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_10.42.02_sample_0/bam/Genome72.0.bam'
# 2021-03-13 10:48:48 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_10.42.02_sample_0/bam/Genome191.0.bam'
# 2021-03-13 10:48:48 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_10.42.02_sample_0/bam/Genome234.0.bam'
# 2021-03-13 10:48:48 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_10.42.02_sample_0/bam/Genome196.0.bam'
# 2021-03-13 10:48:48 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_10.42.02_sample_0/bam/Genome244.0.bam'
# 2021-03-13 10:48:48 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_10.42.02_sample_0/bam/Genome169.0.bam'
# 2021-03-13 10:48:48 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_10.42.02_sample_0/bam/Genome142.0.bam'
# 2021-03-13 10:48:48 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_10.42.02_sample_0/bam/Genome246.0.bam'
# 2021-03-13 10:48:48 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_10.42.02_sample_0/bam/Genome5.0.bam'
# 2021-03-13 10:48:48 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_10.42.02_sample_0/bam/Genome223.0.bam'
# 2021-03-13 10:48:48 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_10.42.02_sample_0/bam/Genome170.0.bam'
# 2021-03-13 10:48:48 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_10.42.02_sample_0/bam/Genome240.0.bam'
# 2021-03-13 10:48:48 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_10.42.02_sample_0/bam/Genome99.0.bam'
# 2021-03-13 10:48:48 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_10.42.02_sample_0/bam/Genome10.0.bam'
# 2021-03-13 10:48:48 WARNING: [Validator 10795378910] List contains only one file: '/output/2021.03.13_10.42.02_sample_0/bam/Genome187.0.bam'
# 2021-03-13 10:49:37 INFO: [MetagenomeSimulationPipeline] Anonymize Data
# 2021-03-13 10:49:37 INFO: [FastaAnonymizer] Interweave shuffle and anonymize
# 2021-03-13 10:51:06 INFO: [MetadataReader 4631107874] Reading file: '/output/internal/genome_locations.tsv'
# 2021-03-13 10:51:07 INFO: [MetadataReader 14300761082] Reading file: '/output/internal/meta_data.tsv'
# 2021-03-13 10:51:07 INFO: [MetadataReader 87652392539] Reading file: '/tmp/tmpnEsCS5/tmp_fHln8'
# 2021-03-13 10:51:11 INFO: [FastaAnonymizer 66694448886] Shuffle and anonymize '/tmp/tmpnEsCS5/tmpnULO5e'
# 2021-03-13 10:51:20 INFO: [MetadataReader 4079751341] Reading file: '/output/internal/genome_locations.tsv'
# 2021-03-13 10:51:22 INFO: [MetadataReader 84063950941] Reading file: '/output/internal/meta_data.tsv'
# 2021-03-13 10:51:22 INFO: [MetadataReader 48704713275] Reading file: '/tmp/tmpnEsCS5/read_start_positionsaNHNuy'
# 2021-03-13 10:51:24 INFO: [MetadataReader 43119039112] Reading file: '/tmp/tmpnEsCS5/tmpyjWOe8'
# 2021-03-13 10:51:52 INFO: [FastaAnonymizer 64368966291] Shuffle and anonymize '/tmp/tmpnEsCS5/tmplRvn_v'
# 2021-03-13 10:52:01 INFO: [MetadataReader 78717221707] Reading file: '/output/internal/genome_locations.tsv'
# 2021-03-13 10:52:02 INFO: [MetadataReader 89765374142] Reading file: '/output/internal/meta_data.tsv'
# 2021-03-13 10:52:02 INFO: [MetadataReader 98541404663] Reading file: '/tmp/tmpnEsCS5/read_start_positions2fZ_O5'
# 2021-03-13 10:52:05 INFO: [MetadataReader 99062647065] Reading file: '/tmp/tmpnEsCS5/tmpGC2h5z'
# 2021-03-13 10:52:33 INFO: [MetagenomeSimulationPipeline] Compress Data
# 2021-03-13 10:52:33 INFO: [Compress 3477227465] Compressing 'tmpzLJDxr'
# 2021-03-13 10:52:33 INFO: [Compress 75517615449] Compressing 'anonymous_gs_mappingJhYfVd'
# 2021-03-13 10:52:33 INFO: [Compress 84564194976] Compressing 'anonymous_gsa_mappingqaevyV'
# 2021-03-13 10:52:33 INFO: [Compress 63224641871] Compressing 'tmpCQJQSr'
# 2021-03-13 10:52:33 INFO: [Compress 11567118738] Compressing 'tmpcUE3an'
# 2021-03-13 10:52:33 INFO: [Compress 9085777069] Compressing 'anonymous_gsa_pooled_mappingx1bPKa'
# 2021-03-13 10:52:33 INFO: [Compress 9085777069] Done compressing 'gsa_pooled_mapping.tsv.gz' in 0:00:00s.
# 2021-03-13 10:52:33 INFO: [Compress 84564194976] Done compressing 'gsa_mapping.tsv.gz' in 0:00:00s.
# 2021-03-13 10:52:36 INFO: [Compress 75517615449] Done compressing 'reads_mapping.tsv.gz' in 0:00:03s.
# 2021-03-13 10:52:36 INFO: [Compress 63224641871] Done compressing 'anonymous_gsa_pooled.fasta.gz' in 0:00:04s.
# 2021-03-13 10:52:36 INFO: [Compress 3477227465] Done compressing 'anonymous_gsa.fasta.gz' in 0:00:04s.
# 2021-03-13 10:52:49 INFO: [Compress 11567118738] Done compressing 'anonymous_reads.fq.gz' in 0:00:16s.
# 2021-03-13 10:52:49 INFO: [MetagenomeSimulationPipeline] Metagenome simulation finished

# %%
glob.glob('example_input_data/new_simulations/com*/*sample_0*/reads/*anonymous_reads*')
# Out:
# ['example_input_data/new_simulations/complexity_sim_1_genera_250_genomes/2021.03.13_09.38.14_sample_0/reads/anonymous_reads.fq.gz',
#  'example_input_data/new_simulations/complexity_sim_1_genera_25_genomes/2021.03.13_09.21.48_sample_0/reads/anonymous_reads.fq.gz',
#  'example_input_data/new_simulations/complexity_sim_5_genera_25_genomes/2021.03.13_09.51.05_sample_0/reads/anonymous_reads.fq.gz',
#  'example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/2021.03.13_09.59.34_sample_0/reads/anonymous_reads.fq.gz',
#  'example_input_data/new_simulations/complexity_sim_1_genera_50_genomes/2021.03.13_10.06.07_sample_0/reads/anonymous_reads.fq.gz',
#  'example_input_data/new_simulations/complexity_sim_10_genera_50_genomes/2021.03.13_10.16.05_sample_0/reads/anonymous_reads.fq.gz',
#  'example_input_data/new_simulations/complexity_sim_5_genera_50_genomes/2021.03.13_10.23.50_sample_0/reads/anonymous_reads.fq.gz',
#  'example_input_data/new_simulations/complexity_sim_5_genera_250_genomes/2021.03.13_10.30.57_sample_0/reads/anonymous_reads.fq.gz',
#  'example_input_data/new_simulations/complexity_sim_10_genera_250_genomes/2021.03.13_10.42.02_sample_0/reads/anonymous_reads.fq.gz']

# %% [markdown]
# # Now we just need to run the assemblies
#
# Note that many of these steps are described in greater detail in the `preparing_data` notebook.

# %%
BASE_DIR = os.getcwd()

# %%
for SIM_FASTA_FILE in glob.glob('example_input_data/new_simulations/complexity_sim*/*sample_0*'):
    input_contigs_fasta = os.path.join(BASE_DIR, f"{SIM_FASTA_FILE}/contigs/anonymous_gsa.fasta.gz")
    output_filtered_contigs_fasta = os.path.join(BASE_DIR, f"{SIM_FASTA_FILE}/contigs/anonymous_gsa_filtered.fasta.gz")

    with vamb.vambtools.Reader(input_contigs_fasta, 'rb') as inputfile:
        with open(output_filtered_contigs_fasta, 'w') as outputfile:
            print(inputfile)
            print(outputfile)
            vamb.vambtools.filtercontigs(inputfile, outputfile, minlength=2000)
# Out:
# <vamb.vambtools.Reader object at 0x7feb547b9cd0>
# <_io.TextIOWrapper name='/Users/pmccaffrey/jupyter_projects/CS230_Stanford_Project/example_input_data/new_simulations/complexity_sim_1_genera_250_genomes/2021.03.13_09.38.14_sample_0/contigs/anonymous_gsa_filtered.fasta.gz' mode='w' encoding='UTF-8'>
# <vamb.vambtools.Reader object at 0x7feb58957110>
# <_io.TextIOWrapper name='/Users/pmccaffrey/jupyter_projects/CS230_Stanford_Project/example_input_data/new_simulations/complexity_sim_1_genera_25_genomes/2021.03.13_09.21.48_sample_0/contigs/anonymous_gsa_filtered.fasta.gz' mode='w' encoding='UTF-8'>
# <vamb.vambtools.Reader object at 0x7feb547b9190>
# <_io.TextIOWrapper name='/Users/pmccaffrey/jupyter_projects/CS230_Stanford_Project/example_input_data/new_simulations/complexity_sim_5_genera_25_genomes/2021.03.13_09.51.05_sample_0/contigs/anonymous_gsa_filtered.fasta.gz' mode='w' encoding='UTF-8'>
# <vamb.vambtools.Reader object at 0x7feb547b9cd0>
# <_io.TextIOWrapper name='/Users/pmccaffrey/jupyter_projects/CS230_Stanford_Project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/2021.03.13_09.59.34_sample_0/contigs/anonymous_gsa_filtered.fasta.gz' mode='w' encoding='UTF-8'>
# <vamb.vambtools.Reader object at 0x7feb58957110>
# <_io.TextIOWrapper name='/Users/pmccaffrey/jupyter_projects/CS230_Stanford_Project/example_input_data/new_simulations/complexity_sim_1_genera_50_genomes/2021.03.13_10.06.07_sample_0/contigs/anonymous_gsa_filtered.fasta.gz' mode='w' encoding='UTF-8'>
# <vamb.vambtools.Reader object at 0x7feb547b9190>
# <_io.TextIOWrapper name='/Users/pmccaffrey/jupyter_projects/CS230_Stanford_Project/example_input_data/new_simulations/complexity_sim_10_genera_50_genomes/2021.03.13_10.16.05_sample_0/contigs/anonymous_gsa_filtered.fasta.gz' mode='w' encoding='UTF-8'>
# <vamb.vambtools.Reader object at 0x7feb54660dd0>
# <_io.TextIOWrapper name='/Users/pmccaffrey/jupyter_projects/CS230_Stanford_Project/example_input_data/new_simulations/complexity_sim_5_genera_50_genomes/2021.03.13_10.23.50_sample_0/contigs/anonymous_gsa_filtered.fasta.gz' mode='w' encoding='UTF-8'>
# <vamb.vambtools.Reader object at 0x7feb58957110>
# <_io.TextIOWrapper name='/Users/pmccaffrey/jupyter_projects/CS230_Stanford_Project/example_input_data/new_simulations/complexity_sim_5_genera_250_genomes/2021.03.13_10.30.57_sample_0/contigs/anonymous_gsa_filtered.fasta.gz' mode='w' encoding='UTF-8'>
# <vamb.vambtools.Reader object at 0x7feb547b9190>
# <_io.TextIOWrapper name='/Users/pmccaffrey/jupyter_projects/CS230_Stanford_Project/example_input_data/new_simulations/complexity_sim_10_genera_250_genomes/2021.03.13_10.42.02_sample_0/contigs/anonymous_gsa_filtered.fasta.gz' mode='w' encoding='UTF-8'>

# %%
for SIM_FASTA_FILE in glob.glob('example_input_data/new_simulations/complexity_sim*/*sample_0*'):
    print('Processing:', SIM_FASTA_FILE)
    minimap2_input = f"{SIM_FASTA_FILE}/reads/anonymous_reads.fq.gz"
    minimap2_output = f"{SIM_FASTA_FILE}/assemblies/re_mapped.bam"

    minimap_index_location = f"{SIM_FASTA_FILE}/catalogue.mmi"
    
    output_filtered_contigs_fasta = os.path.join(BASE_DIR, f"{SIM_FASTA_FILE}/contigs/anonymous_gsa_filtered.fasta.gz")

    !~/anaconda3/envs/vamb_env/bin/minimap2 -d $minimap_index_location $output_filtered_contigs_fasta 
    
    print('minimap index location', minimap_index_location)

    if not os.path.exists(os.path.join(SIM_FASTA_FILE,'assemblies')):
        os.mkdir(os.path.join(SIM_FASTA_FILE,'assemblies'))

    !~/anaconda3/envs/vamb_env/bin/minimap2 \
        -t 10 \
        -N 50 \
        -ax sr $minimap_index_location \
        $minimap2_input | samtools view -F 3584 -b --threads 8 > $minimap2_output
# Out:
# Processing: example_input_data/new_simulations/complexity_sim_1_genera_250_genomes/2021.03.13_09.38.14_sample_0
# [M::mm_idx_gen::0.186*1.08] collected minimizers
# [M::mm_idx_gen::0.236*1.48] sorted minimizers
# [M::main::0.323*1.35] loaded/built the index for 583 target sequence(s)
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 583
# [M::mm_idx_stat::0.338*1.33] distinct minimizers: 1000598 (89.04% are singletons); average occurrences: 1.137; average spacing: 5.361
# [M::main] Version: 2.17-r941
# [M::main] CMD: /Users/pmccaffrey/anaconda3/envs/vamb_env/bin/minimap2 -d example_input_data/new_simulations/complexity_sim_1_genera_250_genomes/2021.03.13_09.38.14_sample_0/catalogue.mmi /Users/pmccaffrey/jupyter_projects/CS230_Stanford_Project/example_input_data/new_simulations/complexity_sim_1_genera_250_genomes/2021.03.13_09.38.14_sample_0/contigs/anonymous_gsa_filtered.fasta.gz
# [M::main] Real time: 0.351 sec; CPU: 0.462 sec; Peak RSS: 0.081 GB
# minimap index location example_input_data/new_simulations/complexity_sim_1_genera_250_genomes/2021.03.13_09.38.14_sample_0/catalogue.mmi
# [WARNING] Indexing parameters (-k, -w or -H) overridden by parameters used in the prebuilt index.
# [M::main::0.101*1.02] loaded/built the index for 583 target sequence(s)
# [M::mm_mapopt_update::0.101*1.02] mid_occ = 1000
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 583
# [M::mm_idx_stat::0.114*1.02] distinct minimizers: 1000598 (89.04% are singletons); average occurrences: 1.137; average spacing: 5.361
# [M::worker_pipeline::3.013*6.48] mapped 333334 sequences
# [M::worker_pipeline::3.903*6.12] mapped 330738 sequences
# [M::main] Version: 2.17-r941
# [M::main] CMD: /Users/pmccaffrey/anaconda3/envs/vamb_env/bin/minimap2 -t 10 -N 50 -ax sr example_input_data/new_simulations/complexity_sim_1_genera_250_genomes/2021.03.13_09.38.14_sample_0/catalogue.mmi example_input_data/new_simulations/complexity_sim_1_genera_250_genomes/2021.03.13_09.38.14_sample_0/reads/anonymous_reads.fq.gz
# [M::main] Real time: 3.912 sec; CPU: 23.883 sec; Peak RSS: 0.336 GB
# Processing: example_input_data/new_simulations/complexity_sim_1_genera_25_genomes/2021.03.13_09.21.48_sample_0
# [M::mm_idx_gen::0.271*1.04] collected minimizers
# [M::mm_idx_gen::0.334*1.41] sorted minimizers
# [M::main::0.450*1.30] loaded/built the index for 2095 target sequence(s)
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 2095
# [M::mm_idx_stat::0.471*1.29] distinct minimizers: 1270132 (58.47% are singletons); average occurrences: 1.528; average spacing: 5.373
# [M::main] Version: 2.17-r941
# [M::main] CMD: /Users/pmccaffrey/anaconda3/envs/vamb_env/bin/minimap2 -d example_input_data/new_simulations/complexity_sim_1_genera_25_genomes/2021.03.13_09.21.48_sample_0/catalogue.mmi /Users/pmccaffrey/jupyter_projects/CS230_Stanford_Project/example_input_data/new_simulations/complexity_sim_1_genera_25_genomes/2021.03.13_09.21.48_sample_0/contigs/anonymous_gsa_filtered.fasta.gz
# [M::main] Real time: 0.488 sec; CPU: 0.623 sec; Peak RSS: 0.101 GB
# minimap index location example_input_data/new_simulations/complexity_sim_1_genera_25_genomes/2021.03.13_09.21.48_sample_0/catalogue.mmi
# [WARNING] Indexing parameters (-k, -w or -H) overridden by parameters used in the prebuilt index.
# [M::main::0.113*1.02] loaded/built the index for 2095 target sequence(s)
# [M::mm_mapopt_update::0.113*1.02] mid_occ = 1000
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 2095
# [M::mm_idx_stat::0.130*1.02] distinct minimizers: 1270132 (58.47% are singletons); average occurrences: 1.528; average spacing: 5.373
# [M::worker_pipeline::3.472*7.43] mapped 333334 sequences
# [M::worker_pipeline::4.585*6.96] mapped 330624 sequences
# [M::main] Version: 2.17-r941
# [M::main] CMD: /Users/pmccaffrey/anaconda3/envs/vamb_env/bin/minimap2 -t 10 -N 50 -ax sr example_input_data/new_simulations/complexity_sim_1_genera_25_genomes/2021.03.13_09.21.48_sample_0/catalogue.mmi example_input_data/new_simulations/complexity_sim_1_genera_25_genomes/2021.03.13_09.21.48_sample_0/reads/anonymous_reads.fq.gz
# [M::main] Real time: 4.597 sec; CPU: 31.908 sec; Peak RSS: 0.385 GB
# Processing: example_input_data/new_simulations/complexity_sim_5_genera_25_genomes/2021.03.13_09.51.05_sample_0
# [M::mm_idx_gen::0.289*1.04] collected minimizers
# [M::mm_idx_gen::0.356*1.41] sorted minimizers
# [M::main::0.513*1.26] loaded/built the index for 2071 target sequence(s)
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 2071
# [M::mm_idx_stat::0.540*1.25] distinct minimizers: 2003541 (97.40% are singletons); average occurrences: 1.029; average spacing: 5.367
# [M::main] Version: 2.17-r941
# [M::main] CMD: /Users/pmccaffrey/anaconda3/envs/vamb_env/bin/minimap2 -d example_input_data/new_simulations/complexity_sim_5_genera_25_genomes/2021.03.13_09.51.05_sample_0/catalogue.mmi /Users/pmccaffrey/jupyter_projects/CS230_Stanford_Project/example_input_data/new_simulations/complexity_sim_5_genera_25_genomes/2021.03.13_09.51.05_sample_0/contigs/anonymous_gsa_filtered.fasta.gz
# [M::main] Real time: 0.565 sec; CPU: 0.697 sec; Peak RSS: 0.128 GB
# minimap index location example_input_data/new_simulations/complexity_sim_5_genera_25_genomes/2021.03.13_09.51.05_sample_0/catalogue.mmi
# [WARNING] Indexing parameters (-k, -w or -H) overridden by parameters used in the prebuilt index.
# [M::main::0.177*1.01] loaded/built the index for 2071 target sequence(s)
# [M::mm_mapopt_update::0.177*1.01] mid_occ = 1000
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 2071
# [M::mm_idx_stat::0.206*1.01] distinct minimizers: 2003541 (97.40% are singletons); average occurrences: 1.029; average spacing: 5.367
# [M::worker_pipeline::2.117*4.09] mapped 333334 sequences
# [M::worker_pipeline::3.107*4.73] mapped 330644 sequences
# [M::main] Version: 2.17-r941
# [M::main] CMD: /Users/pmccaffrey/anaconda3/envs/vamb_env/bin/minimap2 -t 10 -N 50 -ax sr example_input_data/new_simulations/complexity_sim_5_genera_25_genomes/2021.03.13_09.51.05_sample_0/catalogue.mmi example_input_data/new_simulations/complexity_sim_5_genera_25_genomes/2021.03.13_09.51.05_sample_0/reads/anonymous_reads.fq.gz
# [M::main] Real time: 3.118 sec; CPU: 14.708 sec; Peak RSS: 0.295 GB
# Processing: example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/2021.03.13_09.59.34_sample_0
# [M::mm_idx_gen::0.252*1.05] collected minimizers
# [M::mm_idx_gen::0.318*1.45] sorted minimizers
# [M::main::0.456*1.29] loaded/built the index for 1977 target sequence(s)
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1977
# [M::mm_idx_stat::0.477*1.28] distinct minimizers: 1558062 (85.04% are singletons); average occurrences: 1.173; average spacing: 5.368
# [M::main] Version: 2.17-r941
# [M::main] CMD: /Users/pmccaffrey/anaconda3/envs/vamb_env/bin/minimap2 -d example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/2021.03.13_09.59.34_sample_0/catalogue.mmi /Users/pmccaffrey/jupyter_projects/CS230_Stanford_Project/example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/2021.03.13_09.59.34_sample_0/contigs/anonymous_gsa_filtered.fasta.gz
# [M::main] Real time: 0.491 sec; CPU: 0.625 sec; Peak RSS: 0.090 GB
# minimap index location example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/2021.03.13_09.59.34_sample_0/catalogue.mmi
# [WARNING] Indexing parameters (-k, -w or -H) overridden by parameters used in the prebuilt index.
# [M::main::0.132*1.01] loaded/built the index for 1977 target sequence(s)
# [M::mm_mapopt_update::0.132*1.01] mid_occ = 1000
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1977
# [M::mm_idx_stat::0.152*1.01] distinct minimizers: 1558062 (85.04% are singletons); average occurrences: 1.173; average spacing: 5.368
# [M::worker_pipeline::2.905*6.21] mapped 333334 sequences
# [M::worker_pipeline::3.790*5.94] mapped 324724 sequences
# [M::main] Version: 2.17-r941
# [M::main] CMD: /Users/pmccaffrey/anaconda3/envs/vamb_env/bin/minimap2 -t 10 -N 50 -ax sr example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/2021.03.13_09.59.34_sample_0/catalogue.mmi example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/2021.03.13_09.59.34_sample_0/reads/anonymous_reads.fq.gz
# [M::main] Real time: 3.800 sec; CPU: 22.516 sec; Peak RSS: 0.331 GB
# Processing: example_input_data/new_simulations/complexity_sim_1_genera_50_genomes/2021.03.13_10.06.07_sample_0
# [M::mm_idx_gen::0.258*1.04] collected minimizers
# [M::mm_idx_gen::0.328*1.45] sorted minimizers
# [M::main::0.441*1.33] loaded/built the index for 2741 target sequence(s)
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 2741
# [M::mm_idx_stat::0.460*1.32] distinct minimizers: 1185349 (63.60% are singletons); average occurrences: 1.492; average spacing: 5.379
# [M::main] Version: 2.17-r941
# [M::main] CMD: /Users/pmccaffrey/anaconda3/envs/vamb_env/bin/minimap2 -d example_input_data/new_simulations/complexity_sim_1_genera_50_genomes/2021.03.13_10.06.07_sample_0/catalogue.mmi /Users/pmccaffrey/jupyter_projects/CS230_Stanford_Project/example_input_data/new_simulations/complexity_sim_1_genera_50_genomes/2021.03.13_10.06.07_sample_0/contigs/anonymous_gsa_filtered.fasta.gz
# [M::main] Real time: 0.471 sec; CPU: 0.618 sec; Peak RSS: 0.090 GB
# minimap index location example_input_data/new_simulations/complexity_sim_1_genera_50_genomes/2021.03.13_10.06.07_sample_0/catalogue.mmi
# [WARNING] Indexing parameters (-k, -w or -H) overridden by parameters used in the prebuilt index.
# [M::main::0.107*1.02] loaded/built the index for 2741 target sequence(s)
# [M::mm_mapopt_update::0.107*1.02] mid_occ = 1000
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 2741
# [M::mm_idx_stat::0.123*1.02] distinct minimizers: 1185349 (63.60% are singletons); average occurrences: 1.492; average spacing: 5.379
# [M::worker_pipeline::3.492*7.16] mapped 333334 sequences
# [M::worker_pipeline::4.524*6.72] mapped 329860 sequences
# [M::main] Version: 2.17-r941
# [M::main] CMD: /Users/pmccaffrey/anaconda3/envs/vamb_env/bin/minimap2 -t 10 -N 50 -ax sr example_input_data/new_simulations/complexity_sim_1_genera_50_genomes/2021.03.13_10.06.07_sample_0/catalogue.mmi example_input_data/new_simulations/complexity_sim_1_genera_50_genomes/2021.03.13_10.06.07_sample_0/reads/anonymous_reads.fq.gz
# [M::main] Real time: 4.535 sec; CPU: 30.430 sec; Peak RSS: 0.376 GB
# Processing: example_input_data/new_simulations/complexity_sim_10_genera_50_genomes/2021.03.13_10.16.05_sample_0
# [M::mm_idx_gen::0.293*1.04] collected minimizers
# [M::mm_idx_gen::0.366*1.43] sorted minimizers
# [M::main::0.514*1.30] loaded/built the index for 2887 target sequence(s)
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 2887
# [M::mm_idx_stat::0.541*1.29] distinct minimizers: 2010190 (96.61% are singletons); average occurrences: 1.042; average spacing: 5.377
# [M::main] Version: 2.17-r941
# [M::main] CMD: /Users/pmccaffrey/anaconda3/envs/vamb_env/bin/minimap2 -d example_input_data/new_simulations/complexity_sim_10_genera_50_genomes/2021.03.13_10.16.05_sample_0/catalogue.mmi /Users/pmccaffrey/jupyter_projects/CS230_Stanford_Project/example_input_data/new_simulations/complexity_sim_10_genera_50_genomes/2021.03.13_10.16.05_sample_0/contigs/anonymous_gsa_filtered.fasta.gz
# [M::main] Real time: 0.555 sec; CPU: 0.709 sec; Peak RSS: 0.138 GB
# minimap index location example_input_data/new_simulations/complexity_sim_10_genera_50_genomes/2021.03.13_10.16.05_sample_0/catalogue.mmi
# [WARNING] Indexing parameters (-k, -w or -H) overridden by parameters used in the prebuilt index.
# [M::main::0.173*1.01] loaded/built the index for 2887 target sequence(s)
# [M::mm_mapopt_update::0.173*1.01] mid_occ = 1000
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 2887
# [M::mm_idx_stat::0.198*1.01] distinct minimizers: 2010190 (96.61% are singletons); average occurrences: 1.042; average spacing: 5.377
# [M::worker_pipeline::2.071*4.10] mapped 333334 sequences
# [M::worker_pipeline::3.047*4.76] mapped 322550 sequences
# [M::main] Version: 2.17-r941
# [M::main] CMD: /Users/pmccaffrey/anaconda3/envs/vamb_env/bin/minimap2 -t 10 -N 50 -ax sr example_input_data/new_simulations/complexity_sim_10_genera_50_genomes/2021.03.13_10.16.05_sample_0/catalogue.mmi example_input_data/new_simulations/complexity_sim_10_genera_50_genomes/2021.03.13_10.16.05_sample_0/reads/anonymous_reads.fq.gz
# [M::main] Real time: 3.058 sec; CPU: 14.528 sec; Peak RSS: 0.293 GB
# Processing: example_input_data/new_simulations/complexity_sim_5_genera_50_genomes/2021.03.13_10.23.50_sample_0
# [M::mm_idx_gen::0.316*1.04] collected minimizers
# [M::mm_idx_gen::0.391*1.41] sorted minimizers
# [M::main::0.552*1.28] loaded/built the index for 2425 target sequence(s)
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 2425
# [M::mm_idx_stat::0.581*1.27] distinct minimizers: 2097622 (92.28% are singletons); average occurrences: 1.089; average spacing: 5.366
# [M::main] Version: 2.17-r941
# [M::main] CMD: /Users/pmccaffrey/anaconda3/envs/vamb_env/bin/minimap2 -d example_input_data/new_simulations/complexity_sim_5_genera_50_genomes/2021.03.13_10.23.50_sample_0/catalogue.mmi /Users/pmccaffrey/jupyter_projects/CS230_Stanford_Project/example_input_data/new_simulations/complexity_sim_5_genera_50_genomes/2021.03.13_10.23.50_sample_0/contigs/anonymous_gsa_filtered.fasta.gz
# [M::main] Real time: 0.598 sec; CPU: 0.754 sec; Peak RSS: 0.145 GB
# minimap index location example_input_data/new_simulations/complexity_sim_5_genera_50_genomes/2021.03.13_10.23.50_sample_0/catalogue.mmi
# [WARNING] Indexing parameters (-k, -w or -H) overridden by parameters used in the prebuilt index.
# [M::main::0.181*1.01] loaded/built the index for 2425 target sequence(s)
# [M::mm_mapopt_update::0.181*1.01] mid_occ = 1000
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 2425
# [M::mm_idx_stat::0.209*1.01] distinct minimizers: 2097622 (92.28% are singletons); average occurrences: 1.089; average spacing: 5.366
# [M::worker_pipeline::2.602*5.28] mapped 333334 sequences
# [M::worker_pipeline::3.723*5.53] mapped 328388 sequences
# [M::main] Version: 2.17-r941
# [M::main] CMD: /Users/pmccaffrey/anaconda3/envs/vamb_env/bin/minimap2 -t 10 -N 50 -ax sr example_input_data/new_simulations/complexity_sim_5_genera_50_genomes/2021.03.13_10.23.50_sample_0/catalogue.mmi example_input_data/new_simulations/complexity_sim_5_genera_50_genomes/2021.03.13_10.23.50_sample_0/reads/anonymous_reads.fq.gz
# [M::main] Real time: 3.733 sec; CPU: 20.599 sec; Peak RSS: 0.330 GB
# Processing: example_input_data/new_simulations/complexity_sim_5_genera_250_genomes/2021.03.13_10.30.57_sample_0
# [M::mm_idx_gen::0.193*1.06] collected minimizers
# [M::mm_idx_gen::0.249*1.48] sorted minimizers
# [M::main::0.357*1.33] loaded/built the index for 1522 target sequence(s)
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1522
# [M::mm_idx_stat::0.370*1.32] distinct minimizers: 1261927 (98.22% are singletons); average occurrences: 1.020; average spacing: 5.365
# [M::main] Version: 2.17-r941
# [M::main] CMD: /Users/pmccaffrey/anaconda3/envs/vamb_env/bin/minimap2 -d example_input_data/new_simulations/complexity_sim_5_genera_250_genomes/2021.03.13_10.30.57_sample_0/catalogue.mmi /Users/pmccaffrey/jupyter_projects/CS230_Stanford_Project/example_input_data/new_simulations/complexity_sim_5_genera_250_genomes/2021.03.13_10.30.57_sample_0/contigs/anonymous_gsa_filtered.fasta.gz
# [M::main] Real time: 0.383 sec; CPU: 0.499 sec; Peak RSS: 0.074 GB
# minimap index location example_input_data/new_simulations/complexity_sim_5_genera_250_genomes/2021.03.13_10.30.57_sample_0/catalogue.mmi
# [WARNING] Indexing parameters (-k, -w or -H) overridden by parameters used in the prebuilt index.
# [M::main::0.102*1.02] loaded/built the index for 1522 target sequence(s)
# [M::mm_mapopt_update::0.102*1.02] mid_occ = 1000
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1522
# [M::mm_idx_stat::0.113*1.02] distinct minimizers: 1261927 (98.22% are singletons); average occurrences: 1.020; average spacing: 5.365
# [M::worker_pipeline::1.909*4.07] mapped 333334 sequences
# [M::worker_pipeline::2.978*4.64] mapped 330322 sequences
# [M::main] Version: 2.17-r941
# [M::main] CMD: /Users/pmccaffrey/anaconda3/envs/vamb_env/bin/minimap2 -t 10 -N 50 -ax sr example_input_data/new_simulations/complexity_sim_5_genera_250_genomes/2021.03.13_10.30.57_sample_0/catalogue.mmi example_input_data/new_simulations/complexity_sim_5_genera_250_genomes/2021.03.13_10.30.57_sample_0/reads/anonymous_reads.fq.gz
# [M::main] Real time: 2.989 sec; CPU: 13.815 sec; Peak RSS: 0.251 GB
# Processing: example_input_data/new_simulations/complexity_sim_10_genera_250_genomes/2021.03.13_10.42.02_sample_0
# [M::mm_idx_gen::0.195*1.07] collected minimizers
# [M::mm_idx_gen::0.242*1.44] sorted minimizers
# [M::main::0.355*1.28] loaded/built the index for 1602 target sequence(s)
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1602
# [M::mm_idx_stat::0.371*1.27] distinct minimizers: 1194737 (98.33% are singletons); average occurrences: 1.018; average spacing: 5.379
# [M::main] Version: 2.17-r941
# [M::main] CMD: /Users/pmccaffrey/anaconda3/envs/vamb_env/bin/minimap2 -d example_input_data/new_simulations/complexity_sim_10_genera_250_genomes/2021.03.13_10.42.02_sample_0/catalogue.mmi /Users/pmccaffrey/jupyter_projects/CS230_Stanford_Project/example_input_data/new_simulations/complexity_sim_10_genera_250_genomes/2021.03.13_10.42.02_sample_0/contigs/anonymous_gsa_filtered.fasta.gz
# [M::main] Real time: 0.385 sec; CPU: 0.486 sec; Peak RSS: 0.074 GB
# minimap index location example_input_data/new_simulations/complexity_sim_10_genera_250_genomes/2021.03.13_10.42.02_sample_0/catalogue.mmi
# [WARNING] Indexing parameters (-k, -w or -H) overridden by parameters used in the prebuilt index.
# [M::main::0.112*1.02] loaded/built the index for 1602 target sequence(s)
# [M::mm_mapopt_update::0.112*1.02] mid_occ = 1000
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1602
# [M::mm_idx_stat::0.127*1.01] distinct minimizers: 1194737 (98.33% are singletons); average occurrences: 1.018; average spacing: 5.379
# [M::worker_pipeline::2.078*3.65] mapped 333334 sequences
# [M::worker_pipeline::3.130*4.15] mapped 320314 sequences
# [M::main] Version: 2.17-r941
# [M::main] CMD: /Users/pmccaffrey/anaconda3/envs/vamb_env/bin/minimap2 -t 10 -N 50 -ax sr example_input_data/new_simulations/complexity_sim_10_genera_250_genomes/2021.03.13_10.42.02_sample_0/catalogue.mmi example_input_data/new_simulations/complexity_sim_10_genera_250_genomes/2021.03.13_10.42.02_sample_0/reads/anonymous_reads.fq.gz
# [M::main] Real time: 3.137 sec; CPU: 12.983 sec; Peak RSS: 0.244 GB

# %% [markdown]
# And we calculate the TNF and RPKM matrices

# %%
for SIM_FASTA_FILE in glob.glob('example_input_data/new_simulations/complexity_sim*/*sample_0*'):
    output_filtered_contigs_fasta = f"{SIM_FASTA_FILE}/contigs/anonymous_gsa_filtered.fasta.gz"
    
    # Use Reader to open plain or zipped files. File must be opened in binary mode
    with vamb.vambtools.Reader(output_filtered_contigs_fasta, 'rb') as inputfile:
        tnfs, contignames, lengths = vamb.parsecontigs.read_contigs(inputfile)
        
    sample_bamfile = glob.glob(f"{SIM_FASTA_FILE}/assemblies/re_mapped.bam")
    print("bamfile for rpkm:", sample_bamfile)
    
    rpkms = vamb.parsebam.read_bamfiles(sample_bamfile) 
    print('Type of rpkms:', type(rpkms), 'of dtype', rpkms.dtype)
    print('Shape of rpkms', rpkms.shape)
    
    print("tnfs shape:", tnfs.shape)
    
    
    vamb_inputs_base = os.path.join(SIM_FASTA_FILE,'vamb_inputs')
    
    
    if not os.path.exists(vamb_inputs_base):
        os.mkdir(vamb_inputs_base)

    with open(os.path.join(vamb_inputs_base, 'contignames.npz'), 'wb') as file:
        vamb.vambtools.write_npz(file, np.array(contignames))

    with open(os.path.join(vamb_inputs_base, 'lengths.npz'), 'wb') as file:
        vamb.vambtools.write_npz(file, lengths)

    with open(os.path.join(vamb_inputs_base, 'tnfs.npz'), 'wb') as file:
        vamb.vambtools.write_npz(file, tnfs)

    with open(os.path.join(vamb_inputs_base, 'rpkms.npz'), 'wb') as file:
        vamb.vambtools.write_npz(file, rpkms)
# Out:
# bamfile for rpkm: ['example_input_data/new_simulations/complexity_sim_1_genera_250_genomes/2021.03.13_09.38.14_sample_0/assemblies/re_mapped.bam']
# Type of rpkms: <class 'numpy.ndarray'> of dtype float32
# Shape of rpkms (583, 1)
# tnfs shape: (583, 103)
# bamfile for rpkm: ['example_input_data/new_simulations/complexity_sim_1_genera_25_genomes/2021.03.13_09.21.48_sample_0/assemblies/re_mapped.bam']
# Type of rpkms: <class 'numpy.ndarray'> of dtype float32
# Shape of rpkms (2095, 1)
# tnfs shape: (2095, 103)
# bamfile for rpkm: ['example_input_data/new_simulations/complexity_sim_5_genera_25_genomes/2021.03.13_09.51.05_sample_0/assemblies/re_mapped.bam']
# Type of rpkms: <class 'numpy.ndarray'> of dtype float32
# Shape of rpkms (2071, 1)
# tnfs shape: (2071, 103)
# bamfile for rpkm: ['example_input_data/new_simulations/complexity_sim_10_genera_25_genomes/2021.03.13_09.59.34_sample_0/assemblies/re_mapped.bam']
# Type of rpkms: <class 'numpy.ndarray'> of dtype float32
# Shape of rpkms (1977, 1)
# tnfs shape: (1977, 103)
# bamfile for rpkm: ['example_input_data/new_simulations/complexity_sim_1_genera_50_genomes/2021.03.13_10.06.07_sample_0/assemblies/re_mapped.bam']
# Type of rpkms: <class 'numpy.ndarray'> of dtype float32
# Shape of rpkms (2741, 1)
# tnfs shape: (2741, 103)
# bamfile for rpkm: ['example_input_data/new_simulations/complexity_sim_10_genera_50_genomes/2021.03.13_10.16.05_sample_0/assemblies/re_mapped.bam']
# Type of rpkms: <class 'numpy.ndarray'> of dtype float32
# Shape of rpkms (2887, 1)
# tnfs shape: (2887, 103)
# bamfile for rpkm: ['example_input_data/new_simulations/complexity_sim_5_genera_50_genomes/2021.03.13_10.23.50_sample_0/assemblies/re_mapped.bam']
# Type of rpkms: <class 'numpy.ndarray'> of dtype float32
# Shape of rpkms (2425, 1)
# tnfs shape: (2425, 103)
# bamfile for rpkm: ['example_input_data/new_simulations/complexity_sim_5_genera_250_genomes/2021.03.13_10.30.57_sample_0/assemblies/re_mapped.bam']
# Type of rpkms: <class 'numpy.ndarray'> of dtype float32
# Shape of rpkms (1522, 1)
# tnfs shape: (1522, 103)
# bamfile for rpkm: ['example_input_data/new_simulations/complexity_sim_10_genera_250_genomes/2021.03.13_10.42.02_sample_0/assemblies/re_mapped.bam']
# Type of rpkms: <class 'numpy.ndarray'> of dtype float32
# Shape of rpkms (1602, 1)
# tnfs shape: (1602, 103)

# %%
f1, f2 = np.random.choice(glob.glob('example_input_data/new_simulations/complexity_sim*/*sample_0*/*assem*/*re_mapped*'), 2)

print(f1 == f2)

# !diff $f1 $f2
# Out:
# False
# Binary files example_input_data/new_simulations/complexity_sim_10_genera_50_genomes/2021.03.13_10.16.05_sample_0/assemblies/re_mapped.bam and example_input_data/new_simulations/complexity_sim_1_genera_250_genomes/2021.03.13_09.38.14_sample_0/assemblies/re_mapped.bam differ
